# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import pandas as pd
import numpy as np
from collections import Counter
from plotnine import ggplot, aes, geom_bar, coord_flip, labs, theme_classic, scale_y_continuous, scale_color_discrete, guides, geom_col, scale_fill_manual 
import seaborn as sns
from upsetplot import from_memberships, UpSet
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
# Out:
# /home/djl294/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
### Read the unique identifier files from FoldSeek and HMMER search, display overlap as venn diagram

def read_identifiers(file):
    with open(file, 'r') as f:
        lis = []
        lines = f.readlines()
        for line in lines:
            identifier = line.strip()
            lis.append(identifier)
        return set(lis)
        


# Read identifiers from the two files
fs_identifiers = read_identifiers("FS_tacc_Qcov80.u") # Target accessions of foldseekk hits (after quality filtering)
hmmer_identifiers = read_identifiers("HMMER_tacc.u")# Target accessions of hmmer hits (after quality filtering)


# Create a Venn diagram
venn2([fs_identifiers, hmmer_identifiers], ('', ''), set_colors=("Blue", "steelblue"))


# Display the plot
plt.title("")
plt.savefig("Foldseek_HMMER_venn.svg")
plt.show()

# %%
with open("combined_tacc_FSQcov80.u", 'r' ) as f:
    non_redun_list = []
    lines = f.readlines()
    for line in lines:
        acc = line.strip()
        non_redun_list.append(acc)

print(non_redun_list)
# Out:
# ['A0A009H1Z0', 'A0A009HCT7', 'A0A009HRD8', 'A0A009I523', 'A0A009N468', 'A0A009N6V0', 'A0A009PD57', 'A0A009QCK8', 'A0A009R8H0', 'A0A009RT57', 'A0A009SI62', 'A0A009TGX8', 'A0A009YTH9', 'A0A009ZCB5', 'A0A010INF0', 'A0A010JMD3', 'A0A010RN88', 'A0A011MJ67', 'A0A011UXL5', 'A0A011VUM0', 'A0A013T945', 'A0A013TCJ8', 'A0A013TSB9', 'A0A013UUB9', 'A0A014KZH8', 'A0A014L8W3', 'A0A014MBQ3', 'A0A014ME04', 'A0A014MEZ2', 'A0A014Q9J3', 'A0A016XD06', 'A0A016XKK4', 'A0A017HPD5', 'A0A017RWW7', 'A0A017T4D9', 'A0A021VSG6', 'A0A021X158', 'A0A021X2N5', 'A0A022FWJ5', 'A0A022G2K5', 'A0A022GKV3', 'A0A022J069', 'A0A022J4K3', 'A0A022MDJ3', 'A0A022MDU0', 'A0A022MH87', 'A0A022PFT7', 'A0A023BSF7', 'A0A023CVN5', 'A0A023D1X9', 'A0A023DEV7', 'A0A023X4L8', 'A0A024E5B7', 'A0A024H5T4', 'A0A024HH19', 'A0A024HIJ7', 'A0A024HN66', 'A0A024L7E2', 'A0A024QEY5', 'A0A031FVN4', 'A0A031G0T6', 'A0A031G830', 'A0A031IC33', 'A0A031IP61', 'A0A031IUD7', 'A0A031J2X1', 'A0A031LYC4', 'A0A037ZGW4', 'A0A051TS54', 'A0A051TYU7', 'A0A058ZK49', 'A0A059DL83', 'A0A059F9W8', 'A0A059KNG9', 'A0A059KRX4', 'A0A059L839', 'A0A059L9G3', 'A0A059VUS5', 'A0A059WQ78', 'A0A059ZJX3', 'A0A060I0A4', 'A0A060I300', 'A0A060I4W5', 'A0A060M7A0', 'A0A060QHN3', 'A0A060ZDC6', 'A0A060ZNL3', 'A0A060ZP
'A0A085AB74', 'A0A085F161', 'A0A085FGM0', 'A0A085FUD9', 'A0A085G1G7', 'A0A085G6N3', 'A0A085GC05', 'A0A085GHM1', 'A0A085GHS6', 'A0A085JKG8', 'A0A085LG21', 'A0A085RG86', 'A0A085UVG4', 'A0A085W662', 'A0A085ZEB1', 'A0A085ZKQ5', 'A0A085ZZV4', 'A0A086A7R0', 'A0A086AI78', 'A0A086B1T7', 'A0A086BLE8', 'A0A086BLE9', 'A0A086BLJ3', 'A0A086D195', 'A0A086FNU9', 'A0A086MP78', 'A0A086MQ47', 'A0A086N3Z2', 'A0A086N710', 'A0A086XVS8', 'A0A086Z1W8', 'A0A086ZF21', 'A0A086ZLH3', 'A0A086ZLU8', 'A0A086ZQZ5', 'A0A086ZTC4', 'A0A087A6T5', 'A0A087AHD6', 'A0A087AN00', 'A0A087AP32', 'A0A087BAW5', 'A0A087BED7', 'A0A087BPI1', 'A0A087BRD1', 'A0A087C4Q1', 'A0A087CLV0', 'A0A087CVX1', 'A0A087CYB6', 'A0A087CZE3', 'A0A087DBD1', 'A0A087DJ22', 'A0A087DLE9', 'A0A087DRC9', 'A0A087E301', 'A0A087E877', 'A0A087ECW3', 'A0A087KX53', 'A0A087N4 ...

# %%
### Read and graph uniprot protein name annotations for each MIF

# Load data
names = pd.read_csv("combined_uniprot_protnames_Qcov80.u", sep="\t", header=None)

# Count occurrences of each protein name
protein_counts = names[1].value_counts()

# Optional: Limit to top N to avoid clutter
top_n = 20
protein_counts_top = protein_counts.nlargest(top_n)
other_count = protein_counts.iloc[top_n:].sum()
protein_counts_top['Other'] = other_count

# Plot horizontal bar chart
plt.figure(figsize=(20, 10))
protein_counts_top.sort_values().plot.barh(color='skyblue', fontsize=16)  # sort for visual clarity

plt.xlabel("Count")
#plt.title("Top Protein Names in Dataset", fontsize=16)
plt.tight_layout()
plt.savefig("protein_names_bar.svg")
plt.show()

print(protein_counts_top)
# Out:
# 1
# 5-carboxymethyl-2-hydroxymuconate isomerase                                                                  2844
# Tautomerase family protein                                                                                   2638
# 4-oxalocrotonate tautomerase                                                                                 2549
# L-dopachrome isomerase (EC 5.3.2.1) (EC 5.3.3.12) (L-dopachrome tautomerase) (Phenylpyruvate tautomerase)    1195
# 5-carboxymethyl-2-hydroxymuconate Delta-isomerase                                                             960
# Tautomerase enzyme                                                                                            848
# Tautomerase                                                                                                   721
# Uncharacterized protein                                                                                       674
# 5-carboxymethyl-2-hydroxymuconate Delta-isomerase (EC 5.3.3.10)                                               505
# DUF1904 domain-containing protein                                                                             502
# Phenylpyruvate tautomerase PptA (4-oxalocrotonate tautomerase family)                                         476
# Isomerase                                                                                                     359
# 4-oxalocrotonate tautomerase-like domain-containing protein                                                   271
# Tautomerase-like protein                                                                                      260
# 4-oxalocrotonate tautomerase domain-containing protein                                                        259
# Phenylpyruvate tautomerase PptA, 4-oxalocrotonate tautomerase family                                          241
# 4-oxalocrotonate tautomerase family protein                                                                   225
# Tautomerase cis-CaaD-like domain-containing protein                                                           217
# DUF1904 family protein                                                                                        210
# 5-carboxymethyl-2-hydroxymuconate delta-isomerase                                                             164
# Other                                                                                                        2176
# Name: count, dtype: int64

# %%
## Get Taxa  data for each accesion


acc2taxid = {}
df_taxa = pd.read_csv("tmp.tacc2txid.u", sep="\t",header=None) #target accession to NCBI_identifier mapping, from UniProts Mapping Tool


#Turn UniProt Mapping to Python Dict
for index, row in df_taxa.iterrows():
    acc = row[0]
    tax_id = row[1]
    acc2taxid[acc] = tax_id
acc2taxid
# Out:
# {'A0A009H1Z0': 1310608,
#  'A0A009HCT7': 1310608,
#  'A0A009HRD8': 1310613,
#  'A0A009I523': 1310613,
#  'A0A009N468': 1310652,
#  'A0A009N6V0': 1310652,
#  'A0A009PD57': 1310607,
#  'A0A009QCK8': 1310607,
#  'A0A009R8H0': 1310637,
#  'A0A009RT57': 1310637,
#  'A0A009SI62': 1310630,
#  'A0A009TGX8': 1310630,
#  'A0A009YTH9': 1310601,
#  'A0A009ZCB5': 1310601,
#  'A0A010INF0': 1310681,
#  'A0A010JMD3': 1310681,
#  'A0A010RN88': 1042209,
#  'A0A011MJ67': 85402,
#  'A0A011UXL5': 1341156,
#  'A0A011VUM0': 1341156,
#  'A0A013T945': 1310791,
#  'A0A013TCJ8': 1310791,
#  'A0A013TSB9': 1310764,
#  'A0A013UUB9': 1310764,
#  'A0A014KZH8': 1158056,
#  'A0A014L8W3': 1158056,
#  'A0A014MBQ3': 69222,
#  'A0A014ME04': 1158056,
#  'A0A014MEZ2': 1158056,
#  'A0A014Q9J3': 1457173,
#  'A0A016XD06': 1458275,
#  'A0A016XKK4': 1458275,
#  'A0A017HPD5': 442562,
#  'A0A017RWW7': 1403537,
#  'A0A017T4D9': 1192034,
#  'A0A021VSG6': 948458,
#  'A0A021X158': 1410620,
#  'A0A021X2N5': 1410620,
#  'A0A022FWJ5': 574750,
#  'A0A022G2K5': 574750,
#  'A0A022GKV3': 574750,
#  'A0A022J069': 1310723,
#  'A0A022J4K3': 1310723,
#  'A0A022MDJ3': 1470557,
#  'A0A022MDU0': 1470557,
#  'A0A022MH87': 1470557,
#  'A0A022PFT7': 2805098,
#  'A0A023BSF7': 1317122,
#  'A0A023CVN5': 1423806,
#  'A0A023D1X9': 1231351,
#  'A0A023DEV7': 1220594,
#  'A0A023X4L8': 42256,
#  'A0A024E5B7': 1147786,
#  'A0A024H5T4': 861266,
#  'A0A024HH19': 1301098,
#  'A0A024HIJ7': 1301098,
#  'A0A024HN66': 1301098,
#  'A0A024L7E2': 562,
#  'A0A024QEY5': 1462526,
#  'A0A031FVN4': 273677,
#  'A0A031G0T6': 1470589,
#  'A0A031G830': 1470589,
#  'A0A031IC33': 1470592,
#  'A0A031IP61': 1470593,
#  'A0A031IUD7': 1470593,
#  'A0A031J2X1': 1470593,
#  'A0A031LYC4': 466088,
#  'A0A037ZGW4': 1454373,
#  'A0A051TS54': 1324261,
#  'A0A051TYU7': 1324261,
#  'A0A058ZK49': 1461693,
#  'A0A059DL83': 1280944,
#  'A0A059F9W8': 1280952,
#  'A0A059KNG9': 1286631,
#  'A0A059KRX4': 1286631,
#  'A0A059L839': 1419583,
#  'A0A059L9G3': 1419583,
#  'A0A059VUS5': 1971,
#  'A0A059WQ78': 77133,
#  'A0A059ZJX3': 470,
#  'A0A060I0A4': 1432050,
#  'A0A060I300': 1432050,
#  'A0A060I4W5': 1432050,
#  'A0A060M7A0': 1246626,
#  'A0A060QHN3': 91915,
#  'A0A060ZDC6': 576784,
#  'A0A060ZNL3': 576784,
#  'A0A060ZPW1': 576784,
#  'A0A060ZWJ1': 576784,
#  'A0A061A285': 576784,
#  'A0A061JS76': 1218352,
#  'A0A061JVI9': 1218352,
#  'A0A061NEY0': 1460649,
#  'A0A061NGY1': 1460634,
#  'A0A061NMW9': 1460634,
#  'A0A061NZC9': 1460635,
#  'A0A061P830': 1460636,
#  'A0A061PCL1': 1460636,
#  'A0A061ST83': 83219,
#  'A0A061SWM6': 83219,
#  'A0A062GLE5': 1310685,
#  'A0A062GSM9': 1310685,
#  'A0A062IJ32': 1310697,
#  'A0A062IMT2': 1310697,
#  'A0A062UJE8': 1280946,
#  'A0A062VCH4': 1280954,
#  'A0A063Y4P0': 267850,
#  'A0A063YQR4': 1482739,
#  'A0A066RJX4': 1654360,
#  'A0A066RSX5': 1654360,
#  'A0A066TBT4': 3120254,
#  'A0A066UCN7': 743974,
#  'A0A066UQ93': 212667,
#  'A0A066UZ63': 212667,
#  'A0A066YH34': 1348663,
#  'A0A066Z6Z2': 1348663,
#  'A0A066Z8Y8': 1348663,
#  'A0A066ZQM3': 28885,
#  'A0A067BH39': 1481663,
#  'A0A067Z2L5': 1288313,
#  'A0A068NNG0': 661478,
#  'A0A068QSF8': 351671,
#  'A0A068SMN0': 1028800,
#  'A0A068SP51': 1028800,
#  'A0A068T3X3': 1028801,
#  'A0A068THI9': 1028801,
#  'A0A068YMW5': 1504672,
#  'A0A069AWA8': 1496,
#  'A0A069D1H6': 1329250,
#  'A0A069E5H1': 1280949,
#  'A0A069I1K8': 1470558,
#  'A0A069I592': 1470558,
#  'A0A069I817': 1470558,
#  'A0A069IG28': 1470558,
#  'A0A069IKR9': 1470558,
#  'A0A069INU2': 1495854,
#  'A0A069P8Q9': 1071679,
#  'A0A069PEA1': 60547,
#  'A0A069PJD5': 60547,
#  'A0A069PPJ4': 60547,
#  'A0A069Q2Z8': 287,
#  'A0A069RFV0': 1121324,
#  'A0A071LSG8': 1224318,
#  'A0A071M4Q4': 95486,
#  'A0A071MC55': 95486,
#  'A0A071MCE1': 95486,
#  'A0A071MEQ0': 95486,
#  'A0A071MF79': 95486,
#  'A0A071MKL8': 95486,
#  'A0A071ML38': 95486,
#  'A0A071MRR9': 95486,
#  'A0A072H8A2': 670,
#  'A0A072N637': 1137280,
#  'A0A072NJ63': 1348973,
#  'A0A073J262': 1402135,
#  'A0A073K075': 1598,
#  'A0A073KEC1': 574375,
#  'A0A074J685': 1353528,
#  'A0A074LUR1': 1157490,
#  'A0A0H2LWZ8': 34073,
#  'A0A0H2M8D0': 34073,
#  'A0A0H2MGA6': 1489064,
#  'A0A0H2MGS3': 1489064,
#  'A0A0H2MK11': 1647102,
#  'A0A0H2MTH6': 1489064,
#  'A0A0H2MX72': 1647102,
#  'A0A0H2NAP9': 1647102,
#  'A0A0H2WBH1': 243160,
#  'A0A0H2WBZ1': 243160,
#  'A0A0H2WR47': 295319,
#  'A0A0H2XXS1': 331271,
#  'A0A0H2XYT0': 331271,
#  'A0A0H2Y0W4': 331271,
#  'A0A0H2YK54': 377628,
#  'A0A0H2ZA53': 208963,
#  'A0A0H2ZFU1': 208963,
#  'A0A0H3A3S7': 243243,
#  'A0A0H3AGU1': 345073,
#  'A0A0H3AM57': 345073,
#  'A0A0H3AUB4': 444178,
#  'A0A0H3B3U9': 502800,
#  'A0A0H3BWS6': 423368,
#  'A0A0H3CFA8': 716541,
#  'A0A0H3E833': 702459,
#  'A0A0H3F9R1': 2703885,
#  'A0A0H3FES2': 2703885,
#  'A0A0H3FHE3': 2703885,
#  'A0A0H3FJ33': 2703885,
#  'A0A0H3FNI1': 1028307,
#  'A0A0H3GC19': 204722,
#  'A0A0H3GPQ0': 1125630,
#  'A0A0H3GR74': 1125630,
#  'A0A0H3GSF1': 1125630,
#  'A0A0H3H5D2': 1006551,
#  'A0A0H3HDZ7': 1006551,
#  'A0A0H3HSZ7': 884204,
#  'A0A0H3HZ17': 884204,
#  'A0A0H3JAW9': 1262449,
#  'A0A0H3K6C5': 269084,
#  'A0A0H3KPK5': 395019,
#  'A0A0H3KQY3': 395019,
#  'A0A0H3KT69': 395019,
#  'A0A0H3L3X7': 932677,
#  'A0A0H3LHY8': 257310,
#  'A0A0H3LXL3': 257310,
#  'A0A0H3MZ16': 645462,
#  'A0A0H3NJZ7': 216597,
#  'A0A0H3PD76': 375177,
#  'A0A0H3WT63': 656179,
#  'A0A0H3WTU0': 656179,
#  'A0A0H3XJZ4': 315358,
#  'A0A0H4BZD9': 1577075,
#  'A0A0H4IWC1': 1623450,
#  'A0A0H5A894': 200450,
#  'A0A0H5ADT0': 200450,
#  'A0A0H5CYS1': 1653480,
#  'A0A0H5D5G1': 481446,
#  'A0A0H5NG18': 37329,
#  'A0A0H5NHU0': 37329,
#  'A0A0H5P302': 37329,
#  'A0A0H5RLF8': 146018,
#  'A0A0H5SUZ0': 1564487,
#  'A0A0H7DB44': 666,
#  'A0A0I2G3G5': 624,
#  'A0A0J0UP34': 680496,
#  'A0A0J0V7W6': 1659191,
#  'A0A0J0ZVB8': 1409923,
#  'A0A0J1A9W1': 1409923,
#  'A0A0J1BNL8': 1663685,
#  'A0A0J1BQR6': 1660349,
#  'A0A0J1CSP9': 908627,
#  'A0A0J1CUM9': 908627,
#  'A0A0J1D153': 908627,
#  'A0A0J1FMI5': 476652,
#  'A0A0J1G3C5': 908627,
#  'A0A0J1G3E5': 1504536,
#  'A0A0J1GIA0': 754436,
#  'A0A0J1GJA7': 754436,
#  'A0A0K2W6B0': 69974,
#  'A0A0K2ZRZ3': 227946,
#  'A0A0K2ZTK1': 1195923,
#  'A0A0K3A283': 1195923,
#  'A0A0K3A303': 487906,
#  'A0A0K3BSG5': 703222,
#  'A0A0K6GX55': 375574,
#  'A0A0K6HNU6': 466044,
#  'A0A0K6HZQ9': 339866,
#  'A0A0K6HZY2': 339866,
#  'A0A0K6I0B1': 339866,
#  'A0A0K6IHK1': 1137284,
#  'A0A0K6IHP5': 1137284,
#  'A0A0K6IM19': 1137284,
#  'A0A0K8MJA8': 157463,
#  'A0A0K8P1G1': 1547922,
#  'A0A0K8PBM3': 146537,
#  'A0A0K8PGH2': 146537,
#  'A0A0K8Q5A5': 1588022,
#  'A0A0K8QM43': 1475481,
#  'A0A0K9GCA8': 1679169,
#  'A0A0K9H8D7': 1679168,
#  'A0A0K9UR04': 412614,
#  'A0A0K9UVC9': 412614,
#  'A0A0K9XAM3': 1678637,
#  ...}

# %%
### Get taxonomy summary file for each MIF NCBI id and combine into one dataframe; save output so we don't have to repeat
"""

cols = [
    "Query", "Taxid", "Tax name", "Authority", "Rank", "Basionym", "Basionym authority",
    "Curator common name", "Has type material", "Group name", "Superkingdom name", "Superkingdom taxid",
    "Kingdom name", "Kingdom taxid", "Phylum name", "Phylum taxid", "Class name", "Class taxid",
    "Order name", "Order taxid", "Family name", "Family taxid", "Genus name", "Genus taxid",
    "Species name", "Species taxid", "Scientific name is formal"
]

# List to collect each DataFrame for better performance
df_list = []
accs = []
exceptions = []

for key, value in acc2taxid.items():
    try:
        path = f'/workdir/djl294/NCBI_tax_MIF/{value}/ncbi_dataset/data/taxonomy_summary.tsv'
        summary_df = pd.read_csv(path, sep="\t")
        summary_df["ACC"] = key  # Add ACC column directly here
        df_list.append(summary_df)
        accs.append(key)
    except Exception as e:
        print(f'{value} error: {e}')
        exceptions.append(value)

# Concatenate all DataFrames and write to CSV
combined_taxa_df = pd.concat(df_list, ignore_index=True)
combined_taxa_df.to_csv("combined_taxa_output.csv", index=False)

# Optional: show or return the DataFrame if desired
combined_taxa_df

"""

combined_taxa_df = pd.read_csv("combined_taxa_output.csv")

# Remove redundant ID's
combined_taxa_df
# Out:
#          Query    Taxid                          Tax name         Authority  \
# 0      1310608  1310608         Acinetobacter sp. 1295259               NaN
# 1      1310608  1310608         Acinetobacter sp. 1295259               NaN
# 2      1310613  1310613   Acinetobacter baumannii 1295743               NaN
# 3      1310613  1310613   Acinetobacter baumannii 1295743               NaN
# 4      1310652  1310652         Acinetobacter sp. 1475718               NaN
# ...        ...      ...                               ...               ...
# 18279   936563   936563            Fusobacterium sp. CM22               NaN
# 18280  1032505  1032505           Fusobacterium sp. OBRC1               NaN
# 18281   936561   936561             Fusobacterium sp. CM1               NaN
# 18282   396014   396014  Brachybacterium phenoliresistens  Chou et al. 2007
# 18283   396014   396014  Brachybacterium phenoliresistens  Chou et al. 2007
#
#           Rank Basionym Basionym authority Curator common name  \
# 0      SPECIES      NaN                NaN                 NaN
# 1      SPECIES      NaN                NaN                 NaN
# 2       STRAIN      NaN                NaN                 NaN
# 3       STRAIN      NaN                NaN                 NaN
# 4      SPECIES      NaN                NaN                 NaN
# ...        ...      ...                ...                 ...
# 18279  SPECIES      NaN                NaN                 NaN
# 18280  SPECIES      NaN                NaN                 NaN
# 18281  SPECIES      NaN                NaN                 NaN
# 18282  SPECIES      NaN                NaN                 NaN
# 18283  SPECIES      NaN                NaN                 NaN
#
#       Has type material                       Group name  ...  \
# 0                    no                 g-proteobacteria  ...
# 1                    no                 g-proteobacteria  ...
# 2                    no                 g-proteobacteria  ...
# 3                    no                 g-proteobacteria  ...
# 4                    no                 g-proteobacteria  ...
# ...                 ...                              ...  ...
# 18279                no                     fusobacteria  ...
# 18280                no                     fusobacteria  ...
# 18281                no                     fusobacteria  ...
# 18282               yes  high G+C Gram-positive bacteria  ...
# 18283               yes  high G+C Gram-positive bacteria  ...
#
#             Order name  Order taxid       Family name  Family taxid  \
# 0         Moraxellales    2887326.0     Moraxellaceae         468.0
# 1         Moraxellales    2887326.0     Moraxellaceae         468.0
# 2         Moraxellales    2887326.0     Moraxellaceae         468.0
# 3         Moraxellales    2887326.0     Moraxellaceae         468.0
# 4         Moraxellales    2887326.0     Moraxellaceae         468.0
# ...                ...          ...               ...           ...
# 18279  Fusobacteriales     203491.0  Fusobacteriaceae      203492.0
# 18280  Fusobacteriales     203491.0  Fusobacteriaceae      203492.0
# 18281  Fusobacteriales     203491.0  Fusobacteriaceae      203492.0
# 18282    Micrococcales      85006.0  Dermabacteraceae       85020.0
# 18283    Micrococcales      85006.0  Dermabacteraceae       85020.0
#
#             Genus name  Genus taxid                      Species name  \
# 0        Acinetobacter        469.0         Acinetobacter sp. 1295259
# 1        Acinetobacter        469.0         Acinetobacter sp. 1295259
# 2        Acinetobacter        469.0           Acinetobacter baumannii
# 3        Acinetobacter        469.0           Acinetobacter baumannii
# 4        Acinetobacter        469.0         Acinetobacter sp. 1475718
# ...                ...          ...                               ...
# 18279    Fusobacterium        848.0            Fusobacterium sp. CM22
# 18280    Fusobacterium        848.0           Fusobacterium sp. OBRC1
# 18281    Fusobacterium        848.0             Fusobacterium sp. CM1
# 18282  Brachybacterium      43668.0  Brachybacterium phenoliresistens
# 18283  Brachybacterium      43668.0  Brachybacterium phenoliresistens
#
#        Species taxid Scientific name is formal         ACC
# 0            1310608                     False  A0A009H1Z0
# 1            1310608                     False  A0A009HCT7
# 2                470                     False  A0A009HRD8
# 3                470                     False  A0A009I523
# 4            1310652                     False  A0A009N468
# ...              ...                       ...         ...
# 18279         936563                     False      X8GZX3
# 18280        1032505                     False      X8HN85
# 18281         936561                     False      X8I072
# 18282         396014                      True      Z9JR86
# 18283         396014                      True      Z9JWI8
#
# [18284 rows x 28 columns]

# %%
### For a given taxanomic level, make a sub-dataframe for plotting

def get_taxa_ratios(df, Target_Taxa):
    Target_Taxa_List = []
    level_index = df.columns.get_loc(Target_Taxa)
    for i, row in df.iterrows():
        tax_name = row[level_index]
        Target_Taxa_List.append(tax_name)
        
          
    counts = Counter(Target_Taxa_List)
    #print(Target_Taxa_List)

    total_counts = sum(list(counts.values()))
    
    
    
    percent_dict = {}
    for key, value in counts.items():
        percent = value/total_counts * 100
        percent_dict[key] = percent
    #print(percent_dict)
        
    n = len(percent_dict.keys())
    Levels = [Target_Taxa] * n
    sub_df = pd.DataFrame({
        "Level": Levels,
        "Label": percent_dict.keys(),
        "Perc": percent_dict.values()
    })
    
    return sub_df
    


phylum_plot_df = get_taxa_ratios(combined_taxa_df, "Phylum name")
  
print(phylum_plot_df)
    
    
    
family_plot_df = get_taxa_ratios(combined_taxa_df, "Family name")
  
print(family_plot_df)
    
genus_plot_df = get_taxa_ratios(combined_taxa_df, "Genus name")
  
print(genus_plot_df)

species_plot_df = get_taxa_ratios(combined_taxa_df, "Species name")
  
print(species_plot_df)
# Out:
# /tmp/ipykernel_1199619/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#           Level                              Label       Perc
# 0   Phylum name                     Pseudomonadota  60.719755
# 1   Phylum name                          Bacillota  10.342376
# 2   Phylum name                     Actinomycetota  18.185299
# 3   Phylum name                        Myxococcota   0.448480
# 4   Phylum name                       Bacteroidota   2.565084
# ..          ...                                ...        ...
# 66  Phylum name                     Fibrobacterota   0.016408
# 67  Phylum name                    Fidelibacterota   0.005469
# 68  Phylum name  Candidatus Handelsmaniibacteriota   0.005469
# 69  Phylum name        Candidatus Rifleibacteriota   0.005469
# 70  Phylum name                      Chrysiogenota   0.005469
#
# [71 rows x 3 columns]
# /tmp/ipykernel_1199619/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#            Level                       Label      Perc
# 0    Family name               Moraxellaceae  2.816670
# 1    Family name            Pseudomonadaceae  6.278714
# 2    Family name             Pasteurellaceae  0.579742
# 3    Family name            Oscillospiraceae  0.541457
# 4    Family name           Streptomycetaceae  6.278714
# ..           ...                         ...       ...
# 415  Family name          Geitlerinemataceae  0.005469
# 416  Family name               Xenococcaceae  0.005469
# 417  Family name  Candidatus Korobacteraceae  0.005469
# 418  Family name          Symbiobacteriaceae  0.005469
# 419  Family name             Microthrixaceae  0.005469
#
# [420 rows x 3 columns]
# /tmp/ipykernel_1199619/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#            Level                     Label      Perc
# 0     Genus name             Acinetobacter  2.362722
# 1     Genus name               Pseudomonas  6.038066
# 2     Genus name                Mannheimia  0.043754
# 3     Genus name              Ruminococcus  0.213301
# 4     Genus name              Streptomyces  5.895865
# ...          ...                       ...       ...
# 1446  Genus name  Candidatus Competibacter  0.010939
# 1447  Genus name          Commensalibacter  0.005469
# 1448  Genus name           Intrasporangium  0.005469
# 1449  Genus name               Imhoffiella  0.005469
# 1450  Genus name         Agrilactobacillus  0.005469
#
# [1451 rows x 3 columns]
# /tmp/ipykernel_1199619/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#              Level                             Label      Perc
# 0     Species name         Acinetobacter sp. 1295259  0.010939
# 1     Species name           Acinetobacter baumannii  0.267994
# 2     Species name         Acinetobacter sp. 1475718  0.010939
# 3     Species name          Acinetobacter sp. 809848  0.010939
# 4     Species name          Acinetobacter sp. 479375  0.010939
# ...            ...                               ...       ...
# 8285  Species name           Marinomonas ushuaiensis  0.010939
# 8286  Species name            Fusobacterium sp. CM22  0.005469
# 8287  Species name           Fusobacterium sp. OBRC1  0.005469
# 8288  Species name             Fusobacterium sp. CM1  0.005469
# 8289  Species name  Brachybacterium phenoliresistens  0.010939
#
# [8290 rows x 3 columns]

# %%
def plot_taxa_distribution(df, top_n=5, title_prefix=''):
    # Ensure 'Perc' is numeric
    df['Perc'] = pd.to_numeric(df['Perc'], errors='coerce')
    df = df.dropna(subset=['Perc'])

    valid_df = df.dropna(subset=['Label'])
    nan_label_perc = df[df['Label'].isna()]['Perc'].sum()

    df_sorted = valid_df.sort_values('Perc', ascending=False).reset_index(drop=True)
    top_df = df_sorted.iloc[:top_n].copy()
    other_perc = df_sorted.iloc[top_n:]['Perc'].sum() + nan_label_perc

    if other_perc > 0:
        other_row = pd.DataFrame([{
            'Level': top_df['Level'].iloc[0] if 'Level' in top_df.columns else '',
            'Label': 'Other',
            'Perc': other_perc
        }])
        top_df = pd.concat([top_df, other_row], ignore_index=True)

    # Define a consistent color palette
    colors = sns.color_palette('pastel', n_colors=len(top_df))
    
    # Polar Pie-style Plot (no label clutter, legend instead)
    plt.figure(figsize=(8, 6))
    ax = plt.subplot(111, polar=True)
    perc = top_df['Perc']
    labels = top_df['Label']
    total = perc.sum()
    angles = perc.cumsum() / total * 2 * np.pi
    widths = perc / total * 2 * np.pi
    start_angles = np.concatenate(([0], angles[:-1]))

    bars = ax.bar(x=start_angles + widths / 2, height=1, width=widths,
                  bottom=0.0, linewidth=1, edgecolor='white', color=colors)

    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(f'{title_prefix}Taxa Distribution (Pie Chart)', y=1.1)

    # Add legend with percentages
    legend_labels = [f"{label}: {value:.1f}%" for label, value in zip(labels, perc)]
    ax.legend(bars, legend_labels, loc='center left', bbox_to_anchor=(1.05, 0.5), fontsize=15)

    plt.tight_layout()
    out_pie = f'{title_prefix}_pie.svg'
    plt.savefig(out_pie)
    plt.show()

    # Horizontal Bar Chart using same colors
    plt.figure(figsize=(10, 6))
    sns.barplot(data=top_df, y='Label', x='Perc', palette=colors)
    plt.xlabel('Percentage')
    plt.title(f'{title_prefix}Taxa Distribution (Bar Chart)')
    plt.tight_layout()
    plt.show()

    return top_df

# %%
plot_taxa_distribution(genus_plot_df, top_n=5, title_prefix='Genus')
# Out:
#         Level           Label       Perc
# 0  Genus name     Pseudomonas   6.038066
# 1  Genus name    Streptomyces   5.895865
# 2  Genus name    Burkholderia   2.936994
# 3  Genus name  Bradyrhizobium   2.756508
# 4  Genus name   Mesorhizobium   2.384599
# 5  Genus name           Other  79.987968

# %%
# Original deeplocpro run
df_deeplocpro = pd.read_csv("deeplocpro_out/results_20250726-030536.csv")

# Run with added results from qcov80 run
df_deeplocpro_newqcov80 = pd.read_csv("deeplocpro_out_newqcov80/results_20250801-145618.csv")  # Replace with actual filename

# Concatenate the two DataFrames
df_deeplocpro = pd.concat([df_deeplocpro, df_deeplocpro_newqcov80], ignore_index=True)

# Extract accession numbers for "Extracellular" proteins
deeplocpro_secreted = []
for i, r in df_deeplocpro.iterrows():
    acc = str(r['ACC']).split("|")[1]
    if r['Localization'] == "Extracellular":
        print(acc)
        deeplocpro_secreted.append(acc)
        
deeplocpro_secreted = list(set(deeplocpro_secreted))        
print(len(deeplocpro_secreted))
# Out:
# A0A071MCE1
# A0A0G1K7I5
# A0A0G1RRC5
# A0A0J5ZZK7
# A0A106DBC2
# A0A107QBE1
# A0A1J4RVD8
# A0A1W7D0T3
# A0A2A4CKA2
# A0A2A4R048
# A0A2H0DT84
# A0A2H0VK31
# A0A2W4LB07
# A0A364GZR7
# A0A3D4CNU7
# A0A3M2KYU5
# A0A3N8HZI0
# A0A3P0MLW5
# A0A3P0NKS1
# A0A495YQF8
# A0A4R4AFZ5
# A0A6L3NEU5
# A0A6P2GE12
# A0A6P3B8N2
# A0A7C9BQH6
# A0A7T1MH78
# A0A7T6VLR4
# A0A853B724
# B4EL67
# W0E6T2
# A0A1B1K7R9
# A0A1G0X3Z4
# A0A1H9E726
# A0A1M5JVI2
# A0A1Q3H4W8
# A0A3Q9KB29
# A0A522QTT4
# A0A6L9EX20
# A0A6P2J7C1
# A0A7H1B137
# H5WP24
# 41

# %%
### Parse the output from DEEPTMHMM, if any residues are outside of the cell, print the whole per-residue localization
def parse_file_into_blocks(filename):
    with open(filename, 'r') as file:
        block = []
        for counter, line in enumerate(file, start=1):
            block.append(line.rstrip('\n'))  # Append the line without the newline character
            if counter % 3 == 0:
                yield block
                block = []
        
        # If there are remaining lines that do not form a complete block at the end
        if block:
            yield block

            
            
            
deeptmhmm_outside = []
#Parse First deeptmhmm run
blocks = []
for block in parse_file_into_blocks("deeptmhmm_results/predicted_topologies.3line"):
    id_string = str(block[0].split(" |")[0]).split(">")[1]
    residue_locs = block[2]
    if 'O' in residue_locs:
        print(id_string, residue_locs)
        acc = id_string.split("|")[1]
        deeptmhmm_outside.append(acc)

        
# parse second deeptmhmmrun with added results from qcov80 run               
blocks = []    
for block in parse_file_into_blocks("deeptmhmm_results_newqcov80/predicted_topologies.3line"):
    id_string = str(block[0].split(" |")[0]).split(">")[1]
    residue_locs = block[2]
    if 'O' in residue_locs:
        print(id_string, residue_locs)
        acc = id_string.split("|")[1]
        deeptmhmm_outside.append(acc)
        
        
print(deeptmhmm_outside)       
print(len(deeptmhmm_outside))
# Out:
# tr|A0A1B1K7R9|A0A1B1K7R9_RHOOP 
# tr|A0A1M6NB40|A0A1M6NB40_9BRAD SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# tr|A0A443YHU1|A0A443YHU1_9BACT ...
# tr|A0A496UGQ0|A0A496UGQ0_UNCFE SSSSSSSSSSSSSSSSSSSSSSSOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# tr|A0A6N6N5J6|A0A6N6N5J6_9BACT ...
# tr|A0A6V8LVP4|A0A6V8LVP4_9BACT ...
# tr|A0A7C1HUT6|A0A7C1HUT6_9BACT ...
# tr|A0A7K3NH57|A0A7K3NH57_9BACT ...
# tr|E6VTG4|E6VTG4_PSEA9 ...
# ['A0A1B1K7R9', 'A0A1M6NB40', 'A0A443YHU1', 'A0A496UGQ0', 'A0A6N6N5J6', 'A0A6V8LVP4', 'A0A7C1HUT6', 'A0A7K3NH57', 'E6VTG4']
# 9

# %%
#Read in the secreted uniprot identifiers
uniprot_secreted = []
with open("MIFs_UniProt_Secreted", 'r') as f:
    lines = f.readlines()
    for line in lines:
        acc = line.strip()
        uniprot_secreted.append(acc)
        
#Read in the secreted uniprot identifiers from qcov80 run        
with open("MIFs_UniProt_Secreted_newqcov80", 'r') as f:
    lines = f.readlines()
    for line in lines:
        acc = line.strip()
        uniprot_secreted.append(acc)
        
print(uniprot_secreted)  
print(len(uniprot_secreted))
# Out:
# ['A0A011VUM0', 'A0A076HQJ4', 'A0A076JKV6', 'A0A078KTQ4', 'A0A084JL76', 'A0A086Z1W8', 'A0A086ZF21', 'A0A087AHD6', 'A0A087AN00', 'A0A087AP32', 'A0A087BRD1', 'A0A087C4Q1', 'A0A087CVX1', 'A0A087CYB6', 'A0A087CZE3', 'A0A087DRC9', 'A0A087E301', 'A0A087VSX0', 'A0A089PFU3', 'A0A096B5Q1', 'A0A096B5W9', 'A0A0A0BCX7', 'A0A0A1GR13', 'A0A0A1VZT2', 'A0A0A1ZAT1', 'A0A0A1ZYB9', 'A0A0A2A886', 'A0A0A2A8L2', 'A0A0A2AHU2', 'A0A0A2B5J2', 'A0A0A2BCY2', 'A0A0A2BGG5', 'A0A0A2BN57', 'A0A0A2C661', 'A0A0A2CF60', 'A0A0A6PHM1', 'A0A0A7I3P3', 'A0A0A7I624', 'A0A0B5QUH5', 'A0A0C1QV00', 'A0A0C1YCU0', 'A0A0D6AJX7', 'A0A0D6KNU9', 'A0A0D8IUR7', 'A0A0D8ZXV6', 'A0A0E2Z6W9', 'A0A0E3JMW4', 'A0A0F0CN72', 'A0A0F3IKW6', 'A0A0F4L0F5', 'A0A0F4L4M4', 'A0A0G3G3A4', 'A0A0H3E833', 'A0A0H3K6C5', 'A0A0H5SUZ0', 'A0A0J1G3E5', 'A0A0J8FDB6', 'A0A0J9C317', 'A0A0K1S7V7', 'A0A0M0VL25', 'A0A0M1JXU5', 'A0A0M2PQX8', 'A0A0N0V262', 'A0A0N8KMQ4', 'A0A0P7ZA40', 'A0A0P9EMF1', 'A0A0R2XLC5', 'A0A0S2HXF2', 'A0A0S2MG90', 'A0A0S2TE81', 'A0A0S3U0K2', 'A0A0S8BL48', 'A0A0S8EVJ7', 'A0A0S8F3S2', 'A0A0T5YSR4', 'A0A0T7BML8', 'A0A0V7ZQ50', 'A0A126QMZ1', 'A0A126T5F5', 'A0A133KK40', 'A0A133NNS5', 'A0A133P353', 'A0A135Z478', 'A0A139D449', 'A0A139WUB0', 'A0A140K6H9', 'A0A148N4Q0', 'A0A163CUL6', 'A0A163FA17', 'A0A163YBA3', 'A0A164A3T8', 'A0A172U531', 'A0A173WWE7', 'A0A173X0M8', 'A0A174I0G3', 'A0A174SF79', 'A0A174VR89', 'A0A174XN37', 'A0A174Z1I5', 'A0A177LY58', 'A0A177M7G0', 'A0A177NDG5', 'A0A177NFR7', 
PN0', 'A0A1U7I4D0', 'A0A1U7J9V1', 'A0A1U7NBY2', 'A0A1V1PGV1', 'A0A1V3A0X6', 'A0A1V3JIM7', 'A0A1V3NL71', 'A0A1V4BSU2', 'A0A1V4IZ21', 'A0A1V4MU53', 'A0A1V5GLA3', 'A0A1V5L9T7', 'A0A1V5NLG8', 'A0A1V5S6P1', 'A0A1V5V7H9', 'A0A1V5WHZ1', 'A0A1V5XPG0', 'A0A1V6HFV6', 'A0A1V8M9M7', 'A0A1V8PRZ8', 'A0A1W1X2N6', 'A0A1W9LBW8', 'A0A1W9X203', 'A0A1X2FXF0', 'A0A1X7CJ20', 'A0A1Y0RTF9', 'A0A1Y1CN56', 'A0A1Y3WCU0', 'A0A1Y3XQD5', 'A0A1Y4EWL6', 'A0A1Y4I959', 'A0A1Y4J0V7', 'A0A1Y4J3W6', 'A0A1Y4KXD2', 'A0A1Y4SXT1', 'A0A1Y4T9W9', 'A0A1Y5DL89', 'A0A1Y5F282', 'A0A1Z3HM62', 'A0A1Z4GHB6', 'A0A1Z4ICU9', 'A0A1Z4KX29', 'A0A1Z4LV63', 'A0A1Z4N4V9', 'A0A1Z4NDI0', 'A0A1Z4QFH8', 'A0A1Z4QXY7', 'A0A1Z4RQL1', 'A0A1Z5HAP9', 'A0A1Z7WS55', 'A0A1Z8NNZ0', 'A0A1Z8UIG6', 'A0A1Z9AGM8', 'A0A1Z9LHP9', 'A0A218PXA8', 'A0A218QL89', 'A0A231VN06', 'A0A235HP39', 'A0A235IAR1', 'A0A235J5M2', 'A0A239REU0', 'A0A250L024', 'A0A251WC ...
# 1195

# %%
#Parse the original signalP output , print the prediction types
df_signalp = pd.read_csv('signal_p/prediction_results.txt', sep="\t", skiprows=1)
#Parse the signalP output from  from qcov80 run  , print the prediction types
df_signalp_newqcov80 = pd.read_csv('signal_p_newqcov80/prediction_results.txt', sep="\t", skiprows=1)

df_signalp = pd.concat([df_signalp, df_signalp_newqcov80], ignore_index=True)



signal_p_positive = []
signal_p_positive_dict = {}
for i, r in df_signalp.iterrows():
    if r['Prediction'] != "OTHER":
        ACC = r['# ID'].split("|")[1]
        print(ACC, r['Prediction'])
        signal_p_positive.append(ACC)
        signal_p_positive_dict[ACC] = r['Prediction']


print(len(signal_p_positive))
# Out:
# A0A1M5XW76 TAT
# A0A1M6NB40 TAT
# A0A317CF94 SP
# A0A496UGQ0 SP
# A0A6N6N5J6 SP
# A0A6V8LVP4 SP
# A0A7C1HUT6 SP
# E6VTG4 SP
# 8

# %%
# Define set labels and sets 
labels = ['DeepLocPro', 'UniProt', 'DeepTMHMM', 'SignalP'] 
sets = [ set(deeplocpro_secreted), set(uniprot_secreted), set(deeptmhmm_outside), set(signal_p_positive) ] 

# Get union of all accessions 
all_accsl_accs_secreted = set.union(*sets) 

#Remove redundant entries from previous
all_accsl_accs_secreted = all_accsl_accs_secreted.intersection(non_redun_list)

# Build memberships using label names 
memberships = [] 
for acc in all_accs: 
    membership = [labels[i] for i, s in enumerate(sets) if acc in s] 
    memberships.append(membership) 
        
# Create the data for the UpSet plot 
data = from_memberships(memberships) 

# Plot 
upset = UpSet(data, subset_size='count', show_counts=True) 
upset.plot()
plt.suptitle("Overlap of Secretion Prediction Methods", fontsize=14) 
plt.savefig("Secretion_Prediction_UpSet.svg") 
plt.show()
# Out:
# /home/djl294/anaconda3/lib/python3.10/site-packages/upsetplot/data.py:303: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /home/djl294/anaconda3/lib/python3.10/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# /home/djl294/anaconda3/lib/python3.10/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# /home/djl294/anaconda3/lib/python3.10/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# /home/djl294/anaconda3/lib/python3.10/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
### Create a subset of the taxanomy df above for extracellular/secreted proteins



combined_taxa_df_secreted = pd.DataFrame()  

for i, r in combined_taxa_df.iterrows():
    if r['ACC'] in all_accsl_accs_secreted:
        combined_taxa_df_secreted = pd.concat([combined_taxa_df_secreted, r.to_frame().T], ignore_index=True)
        
combined_taxa_df_secreted
# Out:
#         Query    Taxid                                          Tax name  \
# 0     1341156  1341156                            Ruminococcus albus SY3
# 1       95486    95486                          Burkholderia cenocepacia
# 2      585425   585425                        Synechococcus sp. KORDI-52
# 3        1680     1680                      Bifidobacterium adolescentis
# 4       29343    29343                           [Clostridium] cellulosi
# ...       ...      ...                                               ...
# 1236  1400863  1400863  Candidatus Competibacter denitrificans Run_A_D11
# 1237  1408889  1408889                 Clostridium tyrobutyricum DIVETGP
# 1238  1341157  1341157                    Ruminococcus flavefaciens 007c
# 1239  1421016  1421016          Thermoanaerobacterium aotearoense SCUT27
# 1240  1249627  1249627                              Imhoffiella purpurea
#
#                               Authority     Rank Basionym Basionym authority  \
# 0                                   NaN   STRAIN      NaN                NaN
# 1                  Vandamme et al. 2003  SPECIES      NaN                NaN
# 2                                   NaN  SPECIES      NaN                NaN
# 3     Reuter 1963 (Approved Lists 1980)  SPECIES      NaN                NaN
# 4                   Yanling et al. 1991  SPECIES      NaN                NaN
# ...                                 ...      ...      ...                ...
# 1236                                NaN   STRAIN      NaN                NaN
# 1237                                NaN   STRAIN      NaN                NaN
# 1238                                NaN   STRAIN      NaN                NaN
# 1239                                NaN   STRAIN      NaN                NaN
# 1240                  Nupur et al. 2017  SPECIES      NaN                NaN
#
#      Curator common name Has type material                       Group name  \
# 0                    NaN                no                       firmicutes
# 1                    NaN               yes                 b-proteobacteria
# 2                    NaN                no                    cyanobacteria
# 3                    NaN               yes  high G+C Gram-positive bacteria
# 4                    NaN               yes                       firmicutes
# ...                  ...               ...                              ...
# 1236                 NaN                no                 g-proteobacteria
# 1237                 NaN                no                       firmicutes
# 1238                 NaN                no                       firmicutes
# 1239                 NaN                no                       firmicutes
# 1240                 NaN               yes                 g-proteobacteria
#
#       ...              Order name Order taxid                    Family name  \
# 0     ...           Eubacteriales    186802.0               Oscillospiraceae
# 1     ...         Burkholderiales     80840.0               Burkholderiaceae
# 2     ...         Synechococcales   1890424.0               Synechococcaceae
# 3     ...       Bifidobacteriales     85004.0             Bifidobacteriaceae
# 4     ...           Eubacteriales    186802.0               Oscillospiraceae
# ...   ...                     ...         ...                            ...
# 1236  ...                     NaN         NaN  Candidatus Competibacteraceae
# 1237  ...           Eubacteriales    186802.0                 Clostridiaceae
# 1238  ...           Eubacteriales    186802.0               Oscillospiraceae
# 1239  ...  Thermoanaerobacterales     68295.0        Thermoanaerobacteraceae
# 1240  ...            Chromatiales    135613.0                  Chromatiaceae
#
#      Family taxid                Genus name Genus taxid  \
# 0        216572.0              Ruminococcus      1263.0
# 1        119060.0              Burkholderia     32008.0
# 2       1890426.0             Synechococcus      1129.0
# 3         31953.0           Bifidobacterium      1678.0
# 4        216572.0                       NaN         NaN
# ...           ...                       ...         ...
# 1236    1400857.0  Candidatus Competibacter    221279.0
# 1237      31979.0               Clostridium      1485.0
# 1238     216572.0              Ruminococcus      1263.0
# 1239     186814.0     Thermoanaerobacterium     28895.0
# 1240       1046.0               Imhoffiella   2018671.0
#
#                                 Species name Species taxid  \
# 0                         Ruminococcus albus          1264
# 1                   Burkholderia cenocepacia         95486
# 2                 Synechococcus sp. KORDI-52        585425
# 3               Bifidobacterium adolescentis          1680
# 4                    [Clostridium] cellulosi         29343
# ...                                      ...           ...
# 1236  Candidatus Competibacter denitrificans       1400862
# 1237               Clostridium tyrobutyricum          1519
# 1238               Ruminococcus flavefaciens          1265
# 1239       Thermoanaerobacterium aotearoense         47490
# 1240                    Imhoffiella purpurea       1249627
#
#      Scientific name is formal         ACC
# 0                        False  A0A011VUM0
# 1                         True  A0A071MCE1
# 2                        False  A0A076HQJ4
# 3                         True  A0A076JKV6
# 4                         True  A0A078KTQ4
# ...                        ...         ...
# 1236                     False      W6M9Z9
# 1237                     False      W6N3Z2
# 1238                     False      W7UI54
# 1239                     False      W9E8S8
# 1240                      True      W9V7B8
#
# [1241 rows x 28 columns]

# %%
#make taxa specific sub-dataframes for extracellular/secreted proteins
phylum_plot_df_secreted = get_taxa_ratios(combined_taxa_df_secreted, "Phylum name")
  
print(phylum_plot_df_secreted)
    
    
    
family_plot_df_secreted = get_taxa_ratios(combined_taxa_df_secreted, "Family name")
  
print(family_plot_df_secreted)
    
genus_plot_df_secreted = get_taxa_ratios(combined_taxa_df_secreted, "Genus name")
  
print(genus_plot_df_secreted)

species_plot_df_secreted = get_taxa_ratios(combined_taxa_df_secreted, "Species name")
  
print(species_plot_df_secreted)
# Out:
#           Level                          Label       Perc
# 0   Phylum name                      Bacillota  20.628525
# 1   Phylum name                 Pseudomonadota  23.690572
# 2   Phylum name                Cyanobacteriota  29.411765
# 3   Phylum name                 Actinomycetota   9.105560
# 4   Phylum name  Candidatus Collieribacteriota   0.483481
# 5   Phylum name        Thermodesulfobacteriota   3.626108
# 6   Phylum name              Verrucomicrobiota   4.593070
# 7   Phylum name                   Bacteroidota   1.772764
# 8   Phylum name                            NaN   1.369863
# 9   Phylum name                 Lentisphaerota   1.289283
# 10  Phylum name                  Spirochaetota   1.289283
# 11  Phylum name     Candidatus Melainabacteria   0.161160
# 12  Phylum name                Planctomycetota   0.161160
# 13  Phylum name                    Myxococcota   0.805802
# 14  Phylum name                   Thermotogota   0.564061
# 15  Phylum name     Candidatus Zixiibacteriota   0.080580
# 16  Phylum name   Candidatus Fermentibacterota   0.161160
# 17  Phylum name                    Chlamydiota   0.080580
# 18  Phylum name               Kiritimatiellota   0.322321
# 19  Phylum name                Acidobacteriota   0.080580
# 20  Phylum name                 Fibrobacterota   0.241741
# 21  Phylum name    Candidatus Rifleibacteriota   0.080580
#            Level               Label      Perc
# 0    Family name    Oscillospiraceae  4.995971
# 1    Family name    Burkholderiaceae  1.369863
# 2    Family name    Synechococcaceae  3.223207
# 3    Family name  Bifidobacteriaceae  8.541499
# 4    Family name     Lachnospiraceae  6.526994
# ..           ...                 ...       ...
# 114  Family name   Pseudanabaenaceae  0.080580
# 115  Family name   Chamaesiphonaceae  0.080580
# 116  Family name       Xenococcaceae  0.080580
# 117  Family name    Acetobacteraceae  0.080580
# 118  Family name   Thalassospiraceae  0.080580
#
# [119 rows x 3 columns]
#           Level                     Label       Perc
# 0    Genus name              Ruminococcus   2.256245
# 1    Genus name              Burkholderia   1.369863
# 2    Genus name             Synechococcus   3.062047
# 3    Genus name           Bifidobacterium   6.124093
# 4    Genus name                       NaN  25.302176
# ..          ...                       ...        ...
# 240  Genus name               Acetobacter   0.080580
# 241  Genus name       Alkalidesulfovibrio   0.080580
# 242  Genus name              Magnetospira   0.080580
# 243  Genus name  Candidatus Competibacter   0.080580
# 244  Genus name               Imhoffiella   0.080580
#
# [245 rows x 3 columns]
#             Level                                   Label      Perc
# 0    Species name                      Ruminococcus albus  0.402901
# 1    Species name                Burkholderia cenocepacia  0.161160
# 2    Species name              Synechococcus sp. KORDI-52  0.080580
# 3    Species name            Bifidobacterium adolescentis  0.080580
# 4    Species name                 [Clostridium] cellulosi  0.080580
# ..            ...                                     ...       ...
# 859  Species name                   Magnetospira sp. QH-2  0.080580
# 860  Species name  Candidatus Competibacter denitrificans  0.080580
# 861  Species name               Clostridium tyrobutyricum  0.080580
# 862  Species name       Thermoanaerobacterium aotearoense  0.080580
# 863  Species name                    Imhoffiella purpurea  0.080580
#
# [864 rows x 3 columns]
# /tmp/ipykernel_1199619/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /tmp/ipykernel_1199619/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /tmp/ipykernel_1199619/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /tmp/ipykernel_1199619/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
plot_taxa_distribution(phylum_plot_df_secreted, top_n=5, title_prefix='Phylum_Secreted')
# Out:
#          Level              Label       Perc
# 0  Phylum name    Cyanobacteriota  29.411765
# 1  Phylum name     Pseudomonadota  23.690572
# 2  Phylum name          Bacillota  20.628525
# 3  Phylum name     Actinomycetota   9.105560
# 4  Phylum name  Verrucomicrobiota   4.593070
# 5  Phylum name              Other  12.570508

# %%
df_dom_labels = pd.read_csv("tacc2domlabels", sep=" ", header=None)
df_dom_labels_filtered = df_dom_labels[df_dom_labels[0].isin(non_redun_list)]
df_dom_labels_filtered
# Out:
#               0                           1
# 0    A0A061JS76          3.30.429.10,1.20.5
# 1    A0A077F8T2          3.30.429.10,1.20.5
# 2    A0A095VF86     3.30.429.10,3.90.850.10
# 3    A0A060M7A0  unknown_domain,3.30.429.10
# 4    A0A096FN63  3.30.429.10,unknown_domain
# ..          ...                         ...
# 406      U2G0W3          3.30.429.10,1.20.5
# 407      W2EPI0  3.30.429.10,unknown_domain
# 408      W5TMV0  3.30.429.10,unknown_domain
# 409      X6GRG0      3.30.429.10,2.40.30.70
# 410      Z9JWI8  3.30.429.10,unknown_domain
#
# [411 rows x 2 columns]

# %%
cath_names = pd.read_csv("cathid2name", sep="\t", header=None)
cath_names


cath_names_dict = cath_names.astype(str).set_index(cath_names.columns[0])[cath_names.columns[1]].to_dict()


cath_names_dict
# Out:
# {'2': 'Mainly Beta',
#  '3': 'Alpha Beta',
#  '4': 'Few Secondary Structures',
#  '6': 'Special',
#  '1.10': 'Orthogonal Bundle',
#  '1.20': 'Up-down Bundle',
#  '1.25': 'Alpha Horseshoe',
#  '1.40': 'Alpha solenoid',
#  '1.50': 'Alpha/alpha barrel',
#  '2.10': 'Ribbon',
#  '2.20': 'Single Sheet',
#  '2.30': 'Roll',
#  '2.40': 'Beta Barrel',
#  '2.50': 'Clam',
#  '2.60': 'Sandwich',
#  '2.70': 'Distorted Sandwich',
#  '2.80': 'Trefoil',
#  '2.90': 'Orthogonal Prism',
#  '2.100': 'Aligned Prism',
#  '2.102': '3-layer Sandwich',
#  '2.105': '3 Propeller',
#  '2.110': '4 Propeller',
#  '2.115': '5 Propeller',
#  '2.120': '6 Propeller',
#  '2.130': '7 Propeller',
#  '2.140': '8 Propeller',
#  '2.150': '2 Solenoid',
#  '2.160': '3 Solenoid',
#  '2.170': 'Beta Complex',
#  '2.180': 'Shell',
#  '3.10': 'Roll',
#  '3.15': 'Super Roll',
#  '3.20': 'Alpha-Beta Barrel',
#  '3.30': '2-Layer Sandwich',
#  '3.40': '3-Layer(aba) Sandwich',
#  '3.50': '3-Layer(bba) Sandwich',
#  '3.55': '3-Layer(bab) Sandwich',
#  '3.60': '4-Layer Sandwich',
#  '3.65': 'Alpha-beta prism',
#  '3.70': 'Box',
#  '3.75': '5-stranded Propeller',
#  '3.80': 'Alpha-Beta Horseshoe',
#  '3.90': 'Alpha-Beta Complex',
#  '3.100': 'Ribosomal Protein L15; Chain K; domain 2',
#  '4.10': 'Irregular',
#  '6.10': 'Helix non-globular',
#  '6.20': 'Other non-globular',
#  '1.10.8': 'Helicase, Ruva Protein; domain 3',
#  '1.10.10': 'Arc Repressor Mutant, subunit A',
#  '1.10.12': 'Lyase 2-enoyl-coa Hydratase; Chain  A, domain 2',
#  '1.10.15': '3-methyladenine DNA Glycosylase II; Chain A, domain 3',
#  '1.10.20': 'Histone, subunit A',
#  '1.10.30': 'DNA Binding (I), subunit A',
#  '1.10.40': 'Ribonucleotide Reductase Protein R1; domain 1',
#  '1.10.45': 'Vanillyl-alcohol Oxidase; Chain A, domain 4',
#  '1.10.60': 'Diphtheria Toxin Repressor; domain 2',
#  '1.10.100': 'Insulin-like, subunit E',
#  '1.10.101': 'Muramoyl-pentapeptide Carboxypeptidase; domain 1',
#  '1.10.110': 'Hydrophobic Seed Protein',
#  '1.10.132': 'Topoisomerase I; Chain A, domain 4',
#  '1.10.135': 'Transferase Creatine Kinase; Chain A, domain 1',
#  '1.10.140': 'MET Apo-Repressor, subunit A',
#  '1.10.150': 'DNA polymerase; domain 1',
#  '1.10.155': 'Chemotaxis Receptor Methyltransferase Cher; domain 1',
#  '1.10.166': 'Tetrahydrodipicolinate-N-succinyltransferase; Chain A, domain 1',
#  '1.10.167': 'Regulator of G-protein Signalling 4; domain 2',
#  '1.10.168': 'Phosducin; domain 2',
#  '1.10.170': 'Bluetongue Virus 10, subunit 1; domain 3',
#  '1.10.185': 'Human T-cell Leukemia Virus Type II Matrix Protein',
#  '1.10.189': 'Pyruvate Phosphate di-kinase; domain 2',
#  '1.10.195': 'Cytoplasmic domain of VPU protein',
#  '1.10.196': 'Regulator of G-protein Signalling 4; domain 1',
#  '1.10.210': 'Uteroglobin',
#  '1.10.220': 'Annexin V; domain 1',
#  '1.10.225': 'NK-Lysin',
#  '1.10.230': 'Cytochrome p450-Terp; domain 2',
#  '1.10.238': 'Recoverin; domain 1',
#  '1.10.239': 'Beta-cryptogein',
#  '1.10.240': 'Tyrosyl-Transfer RNA Synthetase',
#  '1.10.245': 'MDM2',
#  '1.10.246': 'Serum Albumin; Chain A, Domain 1',
#  '1.10.250': 'Bluetongue Virus 10, subunit 1; domain 1',
#  '1.10.260': '434 Repressor (Amino-terminal Domain)',
#  '1.10.268': 'Topoisomerase; domain 3',
#  '1.10.269': 'Adenovirus Single-stranded Dna-binding Protein, domain 1',
#  '1.10.274': 'Enzyme I; Chain A, domain 2',
#  '1.10.275': 'Fumarase C; Chain B, domain 1',
#  '1.10.285': 'Glutamate Dehydrogenase; Chain A, domain 3',
#  '1.10.286': 'GTP Cyclohydrolase I; Chain A, domain 1',
#  '1.10.287': 'Helix Hairpins',
#  '1.10.288': 'Cobalamin-dependent Methionine Synthase; domain 2',
#  '1.10.290': 'Topoisomerase I; domain 4',
#  '1.10.300': 'Adenylosuccinate Synthetase, subunit A; domain 2',
#  '1.10.340': 'Endonuclease III; domain 1',
#  '1.10.357': 'Tetracycline Repressor; domain 2',
#  '1.10.375': 'Human Immunodeficiency Virus Type 1 Capsid Protein',
#  '1.10.390': 'Neutral Protease; domain 2',
#  '1.10.400': 'GI Alpha 1, domain 2-like',
#  '1.10.405': 'Guanine Nucleotide Dissociation Inhibitor; domain 1',
#  '1.10.418': 'Actin-binding Protein, T-fimbrin; domain 1',
#  '1.10.420': 'Peroxidase; domain 2',
#  '1.10.437': 'Apoptosis Regulator Bcl-x',
#  '1.10.439': 'Penicillin Amidohydrolase; domain 1',
#  '1.10.440': 'Endonuclease V',
#  '1.10.441': 'Phosphomannose Isomerase; domain 2',
#  '1.10.442': 'Cytochrome C Oxidase; Chain D',
#  '1.10.443': 'hpI Integrase; Chain A',
#  '1.10.455': 'Ribosomal Protein S7',
#  '1.10.460': 'Topoisomerase I; domain 2',
#  '1.10.468': 'Photosynthetic Reaction Center, subunit C; domain 2',
#  '1.10.470': 'Variant Surface Glycoprotein, subunit A; domain 2',
#  '1.10.472': 'Cyclin A; domain 1',
#  '1.10.486': 'PCRA; domain 4',
#  '1.10.489': 'Chloroperoxidase',
#  '1.10.490': 'Globin-like',
#  '1.10.506': 'GTPase Activation - p120GAP; domain 1',
#  '1.10.510': 'Transferase(Phosphotransferase); domain 1',
#  '1.10.520': 'Peroxidase; domain 1',
#  '1.10.530': 'Lysozyme',
#  '1.10.532': 'Transcription Factor, Stat-4',
#  '1.10.533': 'Death Domain, Fas',
#  '1.10.540': 'Butyryl-Coa Dehydrogenase, subunit A; domain 1',
#  '1.10.555': 'Phosphatidylinositol 3-kinase; Chain A',
#  '1.10.560': 'GROEL; domain 1',
#  '1.10.565': 'Retinoid X Receptor',
#  '1.10.569': 'Aldehyde Ferredoxin Oxidoreductase Protein, subunit A; domain 2',
#  '1.10.575': 'P1 Nuclease',
#  '1.10.579': 'DNA Cyclobutane Dipyrimidine Photolyase, subunit A; domain 3',
#  '1.10.580': 'Citrate Synthase; domain 1',
#  '1.10.590': 'Chorismate Mutase, subunit A',
#  '1.10.599': 'Aldehyde Ferredoxin Oxidoreductase Protein, subunit A; domain 3',
#  '1.10.600': 'Farnesyl Diphosphate Synthase',
#  '1.10.601': 'RNA Polymerase Primary Sigma Factor',
#  '1.10.606': 'Vanadium-containing Chloroperoxidase; domain 2',
#  '1.10.620': 'Ribonucleotide Reductase, subunit A',
#  '1.10.630': 'Cytochrome p450',
#  '1.10.640': 'Myeloperoxidase, subunit C',
#  '1.10.645': 'Cytochrome-c3 Hydrogenase; chain B',
#  '1.10.700': 'Protocatechuate 4,5-dioxygenase; Chain A',
#  '1.10.720': 'Transcription Termination Factor Rho, Rna-binding Domain; Chain A, Domain 1',
#  '1.10.730': 'Isoleucyl-tRNA Synthetase; Domain 1',
#  '1.10.740': 'Transferase Inhibitor Protein From Tn5; Chain A, domain2',
#  '1.10.750': 'Elongin C; Chain C, domain 1',
#  '1.10.760': 'Cytochrome Bc1 Complex; Chain D, domain 2',
#  '1.10.780': 'Hydroxylamine Oxidoreductase; Chain A, domain 1',
#  '1.10.790': 'Major Prion Protein',
#  '1.10.800': 'Phenylalanine Hydroxylase',
#  '1.10.820': 'RNA Helicase; Chain A, domain 3',
#  '1.10.840': 'Son of Sevenless (SoS) protein; Chain S, domain 2',
#  '1.10.860': 'DNAb Helicase; Chain A',
#  '1.10.870': 'HLA-dr Antigens Associated Invariant Chain; Chain A',
#  '1.10.880': 'Transcription Factor Skn-1; Chain P',
#  '1.10.890': '10k-s Protein, Hypothetical Protein A; Chain A',
#  '1.10.930': 'Syk Kinase; Chain A, domain 2',
#  '1.10.940': 'N-utilizing Substance Protein B Homolog; Chain A',
#  '1.10.950': 'Villin Headpiece Domain; Chain A',
#  '1.10.1000': 'Arf Nucleotide-binding Site Opener; domain 2',
#  '1.10.1020': 'Adenine-specific Methyltransferase; domain 2',
#  '1.10.1030': 'Carbamoyl Phosphate Synthetase; Chain A, domain 4',
#  '1.10.1040': 'N-(1-d-carboxylethyl)-l-norvaline Dehydrogenase; domain 2',
#  '1.10.1050': 'Ribosomal Protein S4 Delta 41; Chain A, domain 1',
#  '1.10.1060': 'Fumarate Reductase Iron-sulfur Protein; Chain B, domain 2',
#  '1.10.1070': 'Phosphatidylinositol 3-kinase Catalytic Subunit; Chain A, Domain 5',
#  '1.10.1080': 'Glutathione Synthetase; Chain A, domain 3',
#  '1.10.1090': 'Cytochrome Bc1 Complex; Chain F',
#  '1.10.1100': 'Transcription Initiation Factor IId 230k; Chain A',
#  '1.10.1130': 'Flavocytochrome C3; Chain A, domain 2',
#  '1.10.1140': 'Bovine Mitochondrial F1-ATPase, ATP Synthase Beta Chain; Chain D, domain3',
#  '1.10.1160': 'Glutamyl-tRNA Synthetase; domain 2',
#  '1.10.1170': 'Inhibitor Of Apoptosis Protein (2mihbC-IAP-1); Chain A',
#  '1.10.1180': 'DNA Transposition Protein; Chain A',
#  '1.10.1200': 'Non-ribosomal Peptide Synthetase Peptidyl Carrier Protein; Chain A',
#  '1.10.1220': 'Arc Repressor Mutant',
#  '1.10.1240': 'Methyltransferase, Methionine Synthase (B12-binding Domains); Chain A, domain 1',
#  '1.10.1270': 'Trp Operon Repressor; Chain A',
#  '1.10.1280': 'di-copper center containing domain from catechol oxidase',
#  '1.10.1290': 'Conserved core of transcriptional regulatory protein vp16',
#  '1.10.1300': 'Catalytic domain of cyclic nucleotide phosphodiesterase 4b2b',
#  '1.10.1320': 'T7 RNA polymerase; domain 1',
#  '1.10.1330': 'Type 1 dockerin domain',
#  '1.10.1350': 'Viral capsid alpha domain',
#  '1.10.1370': 'Neurolysin; domain 3',
#  '1.10.1380': 'Neutral endopeptidase; domain 2',
#  '1.10.1390': 'Phosphoglucose isomerase, C-terminal domain',
#  '1.10.1400': 'Penicillin amidase (Acylase) alpha subunit, N-terminal domain',
#  '1.10.1410': 'Poly(a)-polymerase, middle domain',
#  '1.10.1420': 'MutS, DNA mismatch repair protein; Chain A, domain 3',
#  '1.10.1440': 'Apolipoprotein Cii; Chain A; ',
#  '1.10.1450': 'Cd81 Antigen, Extracellular Domain; Chain A',
#  '1.10.1470': 'Protein Yjbj; Chain A; ',
#  '1.10.1490': 'Dna Fragmentation Factor Alpha Subunit; Chain A; ',
#  '1.10.1500': 'Probable Glutaminase Ybgj; Chain A, domain 2',
#  '1.10.1510': 'Hypothetical Protein Yqey; Chain A; domain1',
#  '1.10.1520': 'Ribonuclease iii, N-terminal Endonuclease Domain; Chain A',
#  '1.10.1530': 'Hypothetical Oxidoreductase Yiak; Chain A, domain 1',
#  '1.10.1540': 'Neurobeachin; Chain A, domain 1',
#  '1.10.1580': 'Conserved Hypothetical Protein Ylqf; Chain A; domain 2',
#  '1.10.1600': 'Ku70; Chain A; domain 4',
#  '1.10.1610': '5,6-Dimethylbenzimidazole Phosphoribosyltransferase; Chain A; domain 1',
#  '1.10.1620': 'Atp Synthase Epsilon Chain; Chain I; ',
#  '1.10.1630': 'Creb-binding Protein; Chain A',
#  '1.10.1650': '50s Ribosomal Protein L19e, Chain O, domain 1',
#  '1.10.1660': 'Multidrug-efflux Transporter Regulator; Chain A; Domain 2',
#  '1.10.1670': 'Endonuclease Iii, domain 2',
#  '1.10.1710': 'Fertility Inhibition Protein O; Chain A; Domain 1',
#  '1.10.1720': 'Proline Oxidase; Chain A,  Domain 2',
#  '1.10.1740': 'Rna Polymerase Sigma Factor; Chain A',
#  '1.10.1750': 'Chromosomal Replication Initiator Protein Dnaa; Chain A; ',
#  '1.10.1760': 'Arp2/3 complex 21 kDa subunit ARPC3',
#  '1.10.1780': 'Double Clp-N motif',
#  '1.10.1790': 'PTS-regulatory domain, PRD',
#  '1.10.1810': 'Anti-sigma factor AsiA',
#  '1.10.1820': 'protein kinase ck2 holoenzyme, chain C, domain 1',
#  '1.10.1840': 'main proteinase (3clpro) structure, domain 3',
#  '1.10.1850': 'Procapsid Of Bacteriophage Phix174, Chain 1',
#  '1.10.1870': 'Domain 3, Saccharopine reductase',
#  '1.10.1900': 'c-terminal domain of poly(a) binding protein',
#  '1.10.2000': 'Frizzled cysteine-rich domain',
#  '1.10.2010': 'Crustacean CHH/MIH/GIH neurohormone',
#  '1.10.2020': 'uronate isomerase, domain 2, chain A',
#  '1.10.2030': 'Anthrax toxin lethal factor, domain 3, chain A',
#  '1.10.2040': 'Protein mu-1, chain B, domain 2',
#  '1.10.2050': 'Protein mu-1, chain B, domain 3',
#  '1.10.2060': 'PutA proline dehydrogenase (PRODH), domain 2',
#  '1.10.2080': 'Antennal chemosensory protein a6',
#  '1.10.2090': 'orange carotenoid protein, domain 2',
#  '1.10.3020': 'alpha-amino acid ester hydrolase ( Helical cap domain)',
#  '1.10.3030': 'Gametocyte protein Pfg27',
#  '1.10.3040': 'borna disease virus nucleoprotein, domain 1',
#  '1.10.3050': 'borna disease virus nucleoprotein, domain 2',
#  '1.10.3060': 'Helical scaffold and wing domains of SecA',
#  '1.10.3070': 'Hypothetical protein MTH393',
#  '1.10.3080': 'Clc chloride channel',
#  '1.10.3090': 'cca-adding enzyme, domain 2',
#  '1.10.3100': 'Putative cytoplasmic protein',
#  '1.10.3110': 'protoporphyrinogen ix oxidase, domain 3',
#  '1.10.3120': 'Trigger factor, domain 2',
#  '1.10.3130': 'serine acetyltransferase, domain 1',
#  '1.10.3140': '4-hydroxybutyryl-coa dehydratase, domain 1',
#  '1.10.3160': 'Bbcrasp-1',
#  '1.10.3170': 'Recbcd, chain B, domain 2',
#  '1.10.3180': 'DNA-binding domain of ethylene- insensitive3-like3',
#  '1.10.3190': 'yfbu gene product, domain 2',
#  '1.10.3200': 'Hypothetical protein af0941',
#  '1.10.3210': 'Hypothetical protein af1432',
#  '1.10.3230': 'Hypothetical protein yqbg',
#  '1.10.3250': 'type ii restriction endonuclease, domain 1',
#  '1.10.3260': 'DNA ligase i, domain 1',
#  '1.10.3270': 'HMGR, N-terminal domain',
#  '1.10.3280': 'Siro heme synthase C-terminal domain-like',
#  '1.10.3290': 'Fic-like fold',
#  '1.10.3300': 'Jann2411-like fold',
#  '1.10.3320': 'pa2218 like fold',
#  '1.10.3330': 'UraD-like',
#  '1.10.3340': 'SMc04008-like fold',
#  '1.10.3350': 'HP0242-like fold',
#  '1.10.3360': 'VPA0735-like fold',
#  '1.10.3370': 'Preprotein translocase SecY subunit ',
#  '1.10.3380': 'Sec63 N-terminal domain-like fold',
#  '1.10.3390': 'YejL-like',
#  '1.10.3400': 'af_2093 domain like fold',
#  '1.10.3410': 'putative deoxyguanosinetriphosphate triphosphohydrolase fold',
#  '1.10.3420': 'putative ntp pyrophosphohydrolase like fold',
#  '1.10.3430': 'Ammonium transporter fold',
#  '1.10.3440': 'Sama2622-like fold',
#  '1.10.3450': 'Hyaluronidase domain-like',
#  '1.10.3460': 'Chlorophyll a-b binding protein ',
#  '1.10.3470': 'ABC transporter involved in vitamin B12 uptake, BtuC',
#  '1.10.3480': 'TorD-like',
#  '1.10.3490': 'PH0156-like',
#  '1.10.3500': 'Tex N-terminal region-like ',
#  '1.10.3510': 'NMB0513-like',
#  '1.10.3520': 'Glycolipid transfer protein, GLTP ',
#  '1.10.3530': 'Api92-like',
#  '1.10.3540': 'fold of a uncharacterized protein from magnetospirillum magneticum',
#  '1.10.3550': 'eoxyguanosinetriphosphate triphosphohydrolase fold',
#  '1.10.3560': 'yst0336 like fold',
#  '1.10.3570': 'Rhabdovirus nucleoprotein-like fold',
#  '1.10.3580': 'ATP12-like fold',
#  '1.10.3590': 'acid-sensing ion channel 1 fold',
#  '1.10.3600': 'uncharacterized protein encoded by cryptic prophage fold',
#  '1.10.3610': 'Rhabdovirus nucleoprotein-like',
#  '1.10.3620': 'YdcF fold',
#  '1.10.3630': 'yeast vps74-n-term truncation variant fold',
#  '1.10.3640': 'putative oxidoreductase fold',
#  '1.10.3650': 'nitrate reductase domain fold',
#  '1.10.3660': '6-phosphogluconate dehydrogenase C-terminal fold',
#  '1.10.3670': 'Putative xylanase fold',
#  '1.10.3680': 'TerB-like ',
#  '1.10.3690': 'PA2222-like fold',
#  '1.10.3700': 'AGR_C_984p-like',
#  '1.10.3710': 'post-AAA+ oligomerization domain-like ',
#  '1.10.3720': 'MetI-like fold',
#  '1.10.3730': 'ProC C-terminal domain-like fold',
#  '1.10.3740': 'SSO1389-like fold',
#  '1.10.3750': 'Hypothetical protein YhaI fold',
#  '1.10.3760': 'YutG-like',
#  '1.10.3780': 'TPR-like',
#  '1.10.3790': 'NinB fold',
#  '1.10.3800': 'ADP-ribosylation fold',
#  '1.10.3810': 'Penicillin binding protein transpeptidase fold',
#  '1.10.3820': 'Multiheme cytochrome fold',
#  '1.10.3830': 'Diacylglycerol kinase fold',
#  '1.10.3860': 'Proton glutamate symport protein ',
#  '1.10.3870': 'AF1437-like domain fold',
#  '1.10.3880': 'YggX-like',
#  '1.10.3890': 'YcfC-like',
#  '1.10.3900': 'YacF-like',
#  '1.10.3910': 'SP0561-like',
#  '1.10.3920': 'PA2201 C-terminal domain-like ',
#  '1.10.3930': 'Pentein',
#  '1.10.3940': 'AF_0924 fold',
#  '1.10.3950': 'putative ecf-type sigma factor negative effector from bacillus cereus',
#  '1.10.3960': 'Hypothetical protein MG354 fold',
#  '1.10.3970': 'BSD domain-like fold',
#  '1.10.3980': 'T-fold',
#  '1.10.3990': 'Ribbon-helix-helix fold',
#  '1.10.4000': 'Flagellar transcriptional activator fold',
#  '1.10.4010': 'all-alpha NTP pyrophosphatase fold',
#  '1.10.4020': 'DNA breaking-rejoining enzymes fold',
#  '1.10.4030': 'Triger factor/SurA peptide-binding fold',
#  '1.10.4040': 'Penicillinase repressor fold',
#  '1.10.4050': 'Nucleotidyltransferase substrate binding subunit/domain fold',
#  '1.10.4060': 'LON domain-like fold',
#  '1.10.4070': 'putative redox-enzyme maturation protein fold',
#  '1.10.4080': 'ADP-ribosylglycohydrolase fold',
#  '1.10.4090': 'Hepatitis B viral capsid (hbcag) fold',
#  '1.10.4100': '2-methylcitrate dehydratase PrpD',
#  '1.10.4110': 'Invasion protein A fold',
#  '1.10.4120': 'SopE-like GEF fold',
#  '1.10.4140': 'effector protein (NleL) fold',
#  '1.10.4150': 'SipA N-terminal domain-like ',
#  '1.10.4160': 'Hydantoin permease',
#  '1.10.4170': 'Glycosylphosphatidylinositol-anchored merozoite surface protein',
#  '1.10.4180': 'Protein LEAFY',
#  '1.10.4190': 'Urease accessory protein UreF',
#  '1.10.4200': 'Triphosphoribosyl-dephospho-CoA protein',
#  '1.20.5': 'Single alpha-helices involved in coiled-coils or other helix-helix interfaces',
#  '1.20.10': 'Heat-Stable Enterotoxin B',
#  '1.20.20': 'F1FO ATP Synthase',
#  '1.20.50': 'Pheromone ER-1',
#  '1.20.58': 'Methane Monooxygenase Hydroxylase; Chain G, domain 1',
#  '1.20.59': 'Chorismate Mutase Domain, subunit A',
#  '1.20.80': 'Acyl-CoA Binding Protein',
#  '1.20.81': 'Receptor-associated Protein',
#  '1.20.82': 'ADP Ribosyl Cyclase; Chain A, domain 1',
#  '1.20.85': 'Photosynthetic Reaction Center, subunit M; domain 1',
#  '1.20.89': 'Nitrogenase Molybdenum-iron Protein, subunit B; domain 4',
#  '1.20.90': 'Phospholipase A2',
#  '1.20.91': 'Influenza Virus Matrix Protein; Chain A, domain 1',
#  '1.20.120': 'Four Helix Bundle (Hemerythrin (Met), subunit A)',
#  '1.20.140': 'Butyryl-CoA Dehydrogenase, subunit A; domain 3',
#  '1.20.141': 'Chitosanase, subunit A; domain 1',
#  '1.20.142': 'Poly(ADP-ribose) Polymerase; domain 1',
#  '1.20.144': 'Vanadium-containing Chloroperoxidase; domain 1',
#  '1.20.150': 'Lysin',
#  '1.20.190': 'Delta-Endotoxin; domain 1',
#  '1.20.200': 'Fumarase C; Chain A, domain 2',
#  '1.20.210': 'Cytochrome C Oxidase; Chain A',
#  '1.20.225': 'Bacteriocin As-48; Chain A',
#  '1.20.245': 'Lipoxygenase-1; domain 5',
#  '1.20.250': 'Colicin Ia; domain 1',
#  '1.20.272': 'Zinc Finger, Delta Prime; domain 3',
#  '1.20.810': 'Cytochrome Bc1 Complex; Chain C',
#  '1.20.840': 'Methyl-coenzyme M Reductase; Chain B, domain 2',
#  '1.20.850': 'Hydroxylamine Oxidoreductase; Chain A, domain 2',
#  '1.20.860': 'Alpha-t-alpha',
#  '1.20.870': 'Son of sevenless (SoS) protein; Chain S, domain 1',
#  '1.20.890': 'cAMP-dependent Protein Kinase, Chain A',
#  '1.20.900': 'Dbl Homology Domain; Chain A',
#  '1.20.910': 'Heme Oxygenase; Chain A',
#  '1.20.920': 'Histone Acetyltransferase; Chain A',
#  '1.20.930': 'Transcription Elongation Factor S-II; Chain A',
#  '1.20.940': 'RNA Binding Protein, Prp18; Chain A',
#  '1.20.950': 'Fumarate Reductase Cytochrome B subunit',
#  '1.20.960': 'Mitochondrial Import Receptor Subunit Tom20; Chain A',
#  '1.20.970': 'Transferase, Pyrimidine Nucleoside Phosphorylase; Chain A, domain 3',
#  '1.20.990': 'NADPH-cytochrome p450 Reductase; Chain A, domain 3',
#  '1.20.1000': 'Signaling Protein - Interferon-induced Guanylate-binding Protein 1; Chain A, domain 1',
#  '1.20.1020': 'CREB-binding Protein; Chain A',
#  '1.20.1050': 'Glutathione S-transferase Yfyf (Class Pi); Chain A, domain 2',
#  '1.20.1060': 'Taq DNA Polymerase; Chain T, domain 4',
#  '1.20.1070': 'Rhopdopsin 7-helix transmembrane proteins',
#  '1.20.1080': 'Glycerol uptake facilitator protein',
#  '1.20.1090': 'Dehydroquinate synthase-like, alpha domain',
#  '1.20.1110': 'Calcium-transporting ATPase, transmembrane domain',
#  '1.20.1120': 'Clostridium botulinum neurotoxin B, "coiled-coil" domain',
#  '1.20.1130': 'Photosystem I p700 chlorophyll A apoprotein A1',
#  '1.20.1150': 'Endoplasmic reticulum protein erp29',
#  '1.20.1160': 'Paired amphipathic helix 2 (pah2 repeat)',
#  '1.20.1170': 'Hemolysin E; Chain A; ',
#  '1.20.1180': 'Udp N-acetylglucosamine O-acyltransferase; Domain 2',
#  '1.20.1200': 'Hypothetical Protein Ta1238; Chain A; ',
#  '1.20.1220': 'Malate Synthase G; Chain A; Domain 4',
#  '1.20.1230': 'Phospholipase C Beta; Chain A',
#  '1.20.1240': 'Photosystem 1 Reaction Centre Subunit Xi; Chain L; ',
#  '1.20.1250': 'Growth Hormone; Chain A; ',
#  '1.20.1260': 'Ferritin',
#  '1.20.1270': 'Substrate Binding Domain Of Dnak; ChainA; Domain 2',
#  '1.20.1280': 'Monooxygenase',
#  '1.20.1290': 'AhpD-like',
#  '1.20.1300': '3 helical TM bundles of succinate and fumarate reductases',
#  '1.20.1310': '5 helical Cullin repeat like',
#  '1.20.1320': 'phosphoenolpyruvate carboxylase, domain 3',
#  '1.20.1330': 'f41 fragment of flagellin, N-terminal domain',
#  '1.20.1340': 'dopa decarboxylase, N-terminal domain',
#  '1.20.1370': 'Hemocyanin, N-terminal domain',
#  '1.20.1380': 'Replication modulator SeqA, C-terminal DNA-binding domain',
#  '1.20.1390': 'PWI domain',
#  '1.20.1400': 'Mollusk pheromone',
#  '1.20.1410': 'I/LWEQ domain',
#  '1.20.1420': 'A middle domain of Talin 1',
#  '1.20.1430': 'immunoglobulin/albumin-binding domain-like',
#  '1.20.1440': 'de novo design (two linked rop proteins)',
#  '1.20.1450': 'particulate methane monooxygenase, chain B',
#  '1.20.1460': 'subunit c (vma5p) of the yeast v-atpase, domain 2',
#  '1.20.1480': 'hypothetical protein mp506/mpn330, domain 1',
#  '1.20.1500': 'YheA-like fold',
#  '1.20.1510': 'Alpha-lytic protease prodomain-like',
#  '1.20.1520': 'Adp-ribosylation factor-like protein 2-binding protein fold',
#  '1.20.1530': 'Na+/H+ antiporter like fold',
#  '1.20.1540': 'Rhomboid-like fold',
#  '1.20.1550': 'Bromodomain-like',
#  '1.20.1560': 'ABC transporter transmembrane region fold',
#  '1.20.1570': 'dip2346 fold',
#  '1.20.1580': 'ABC transporter ATPase like fold',
#  '1.20.1590': 'YP_001051499.1 fold like',
#  '1.20.1600': 'Outer membrane efflux proteins (OEP)',
#  '1.20.1610': 'Glycosyl hydrolase family fold',
#  '1.20.1630': 'Formate dehydrogenase/DMSO reductase fold',
#  '1.20.1640': 'Multidrug efflux transporter AcrB transmembrane fold',
#  '1.20.1650': 'PLP-dependent transferase-like',
#  '1.20.1660': 'ARM repeat  fold',
#  '1.20.1670': 'all-alpha NTP pyrophosphatase',
#  '1.20.1680': 'all-alpha NTP pyrophosphatases',
#  '1.20.1690': 'V-type ATP synthase subunit C fold',
#  '1.20.1700': 'AF1104-like',
#  '1.20.1710': 'IpaD-like ',
#  '1.20.1720': 'Multidrug resistance protein D',
#  '1.20.1730': 'Sodium/glucose cotransporter',
#  '1.20.1740': 'Amino acid/polyamine transporter I',
#  '1.25.10': 'Leucine-rich Repeat Variant',
#  '1.25.20': '70-kda Soluble Lytic Transglycosylase; domain 1',
#  '1.25.40': 'Serine Threonine Protein Phosphatase 5, Tetratricopeptide repeat',
#  '1.25.50': 'Zincin-like fold',
#  '1.25.60': 'MgtE N-terminal fold',
#  '1.25.70': 'Transcription termination factor 3, mitochondrial',
#  '1.40.10': 'Peridinin-chlorophyll Protein, Chain M',
#  '1.40.20': 'CHAD domain',
#  '1.50.10': 'Glycosyltransferase',
#  '1.50.40': 'Mitochondrial carrier fold',
#  '2.10.10': 'Seminal Fluid Protein  PDC-109 (Domain B)',
#  '2.10.22': 'Antistasin; domain 1',
#  '2.10.25': 'Laminin',
#  '2.10.50': 'Tumor Necrosis Factor Receptor, subunit A; domain 2',
#  '2.10.55': 'Leishmanolysin; domain 3',
#  '2.10.60': 'CD59',
#  '2.10.69': 'Cysteine Protease (Bromelain) Inhibitor, subunit H',
#  '2.10.70': 'Complement Module; domain 1',
#  '2.10.77': 'Hemagglutinin; Chain A, domain 2',
#  '2.10.80': 'Lipase, subunit A',
#  '2.10.90': 'Cystine Knot Cytokines, subunit B',
#  '2.10.109': 'Umud Fragment, subunit A',
#  '2.10.110': 'Cysteine Rich Protein',
#  '2.10.150': 'Urease, subunit B',
#  '2.10.160': 'Vascular Endothelial Growth Factor-165, Heparin-binding Domain',
#  '2.10.210': 'Cytochrome Bc1 Complex; Chain I',
#  '2.10.220': 'Hormone Receptor, Insulin-like Growth Factor Receptor 1; Chain A domain 2',
#  '2.10.230': 'Chaperone, DNAj Protein; Chain A',
#  '2.10.240': 'Dihydroorotate dehydrogenase B (pyrk subunit); domain 3',
#  '2.10.250': 'Calnexin lumenal domain, non-globular proline-rich hairpin domain',
#  '2.10.260': 'Pemi-like Protein 1; Chain D',
#  '2.10.270': 'left handed beta-beta-3-solenoid',
#  '2.10.280': 'heat- and protease-stable fragment of the bacteriophage t4 short fibre, domain 1',
#  '2.10.290': 'Rubredoxin-like',
#  '2.10.300': 'Porin MspA ribbon fold',
#  '2.10.310': 'Serpins fold',
#  '2.20.20': 'Anthopleurin-A',
#  '2.20.25': 'N-terminal domain of TfIIb',
#  '2.20.28': 'Rubrerythrin, domain 2',
#  '2.20.50': 'Outer Surface Protein A; domain 2',
#  '2.20.60': 'Heparin-binding Growth Factor, Midkine; Chain A',
#  '2.20.70': 'Ubiquitin Ligase Nedd4; Chain W; ',
#  '2.20.80': 'Lipovitellin-phosvitin complex, chain A, domain 4',
#  '2.20.90': 'Lipovitellin-phosvitin complex; beta-sheet shell regions',
#  '2.20.100': 'TSP-1 type 1 repeat',
#  '2.20.110': 'Histone H3 K4-specific methyltransferase SET7/9 N-terminal domain',
#  '2.20.120': 'Multimodular pneumococcal cell wall endolysin, domain 3',
#  '2.20.130': 'S-adenosyl-L-methionine-dependent methyltransferases',
#  '2.20.140': 'q64v53_bacfr protein fold',
#  '2.20.150': 'putative 5-dehydro-2- deoxygluconokinase like fold',
#  '2.20.160': 'titin filament fold',
#  '2.20.170': 'GTPase activation domain, GAP fold',
#  '2.20.180': 'putative fmn-dependent nitroreductase like fold',
#  '2.20.200': 'Outer membrane efflux proteins (OEP)',
#  '2.20.210': 'ubp-family deubiquitinating enzyme fold',
#  '2.20.220': 'Glycosyl hydrolase fold',
#  '2.20.230': 'Resuscitation-promoting factor rpfb fold',
#  '2.30.18': 'TATA box binding Protein, subunit D; domain 2',
#  '2.30.22': 'Nucleotide Exchange Factor Grpe; Chain A, domain 2',
#  '2.30.24': 'Transcription Regulation, Sacy; Chain A',
#  '2.30.26': 'Dihydroorotate Dehydrogenase A; chain A, domain 2',
#  '2.30.27': 'Phage FD Coat Protein, Membrane penetration domain',
#  '2.30.29': 'PH-domain like',
#  '2.30.30': 'SH3 type barrels.',
#  '2.30.31': 'Transcriptional Co-activator pc4; Chain A',
#  '2.30.32': 'Xylanase; Chain A',
#  '2.30.33': '10 Kd Chaperonin, Protein Cpn10; Chain O',
#  '2.30.34': 'Leishmanolysin; domain 4',
#  '2.30.36': 'Actin; Chain A, domain 2',
#  '2.30.38': 'Luciferase; domain 3',
#  '2.30.39': 'Alpha-1-antitrypsin; domain 1',
#  '2.30.40': 'Urease, subunit C; domain 1',
#  '2.30.42': 'Pdz3 Domain',
#  '2.30.60': 'HIV-inactivating Protein, Cyanovirin-n',
#  '2.30.90': 'Heparin-binding Growth Factor, Midkine; Chain A, C-terminal Domain;',
#  '2.30.110': 'Pnp Oxidase; Chain A',
#  '2.30.120': 'Penicillin G acylase, beta-roll domain ',
#  '2.30.130': 'Archaeosine Trna-guanine Transglycosylase; Chain A, domain 4',
#  '2.30.140': 'Spermidine Synthase; Chain A, domain 2',
#  '2.30.150': 'Rna Polymerase Beta Subunit; Chain C, domain 4',
#  '2.30.160': 'Methuselah Ectodomain; Chain A, domain 1',
#  '2.30.170': 'Ribosomal Protein L24e; Chain T;',
#  '2.30.180': 'FAS1 domain',
#  '2.30.210': 'Leucyl-tRNA synthetase, domain 3',
#  '2.30.220': 'f41 fragment of flagellin, C-terminal domain',
#  '2.30.230': 'Lipovitellin-phosvitin complex; beta-sheet shell regions',
#  '2.30.240': 'at5g01610, DUF538 DOMAIN',
#  '2.30.250': 'Aminopeptidase i, Domain 2',
#  '2.30.260': 'putative xylanase like fold',
#  '2.30.270': 'duf1285 protein fold',
#  '2.30.280': 'PUA domain-like',
#  '2.30.290': 'BH3618-like',
#  '2.30.300': 'Phage tail proteins - horseshoe like beta roll fold ',
#  '2.30.310': 'ibrinogen binding protein from staphylococcus aureus fold',
#  '2.30.320': 'Hypothetical protein YwqG fold',
#  '2.30.330': 'Surface presentation of antigens (SPOA) ',
#  '2.30.340': 'PAZ domain fold',
#  '2.40.10': 'Thrombin, subunit H',
#  '2.40.15': 'Proto-oncogene - Oncogene Product P14tcl1',
#  '2.40.20': 'Plasminogen Kringle 4',
#  '2.40.30': 'Elongation Factor Tu (Ef-tu); domain 3',
#  '2.40.33': 'M1 Pyruvate Kinase; Domain 3',
#  '2.40.37': 'Lyase, Ornithine Decarboxylase; Chain A, domain 1',
#  '2.40.40': 'Barwin-like endoglucanases',
#  '2.40.50': 'OB fold (Dihydrolipoamide Acetyltransferase, E2P)',
#  '2.40.70': 'Cathepsin D, subunit A; domain 1',
#  '2.40.100': 'Cyclophilin',
#  '2.40.110': 'Butyryl-CoA Dehydrogenase, subunit A; domain 2',
#  '2.40.128': 'Lipocalin',
#  '2.40.150': 'Ribosomal Protein L14',
#  '2.40.155': 'Green Fluorescent Protein',
#  '2.40.160': 'Porin',
#  '2.40.170': 'Maltoporin; Chain A',
#  '2.40.180': 'Catalase HpII,  Chain A, domain 1',
#  '2.40.200': 'Telomere-binding Protein Beta Subunit; Chain B',
#  '2.40.220': 'Intramolecular trans-sialidase; domain 3',
#  '2.40.230': 'Outer membrane phospholipase (ompla); Chain C',
#  '2.40.240': 'Ribosomal Protein L25; Chain P',
#  '2.40.250': 'Polyomavirus Enhancer Binding Protein 2; Chain A; ',
#  '2.40.260': 'Sortase; Chain A; ',
#  '2.40.270': 'Dna-directed Rna Polymerase Ii 140kd Polypeptide; Chain B; Domain 6',
#  '2.40.280': 'Small Protein B; Chain A; ',
#  '2.40.290': 'Ku70; Chain A; Domain 2',
#  '2.40.300': 'Virus Head Decoration Protein; Chain A,',
#  '2.40.310': 'Staphostatins',
#  '2.40.320': 'Hypothetical Protein Pfu-838710-001',
#  '2.40.330': 'At1g16640 B3 domain',
#  '2.40.340': 'Beta-clip',
#  '2.40.350': 'AOC barrel-like',
#  '2.40.360': 'YmcC-like fold',
#  '2.40.370': 'AttH-like fold',
#  '2.40.380': 'FomD barrel-like fold',
#  '2.40.390': 'CV3147-like',
#  '2.40.400': 'Acetoacetate decarboxylase-like',
#  '2.40.410': 'putative membrane protein from Corynebacterium diphtheriae fold',
#  '2.40.420': 'conserved putative lor/sdh protein from methanococcus maripaludis s2 fold',
#  '2.40.430': 'Periplasmic binding protein-like II',
#  '2.40.440': 'L,D-transpeptidase catalytic domain-like',
#  '2.40.450': 'PUA domain-like fold',
#  '2.40.460': 'ClpP/crotonase fold',
#  '2.40.470': 'catalase hpii fold',
#  '2.40.480': 'AOC barrel-like',
#  '2.40.490': 'Head and neck region of the ectodomain of NDV fusion glycoprotein',
#  '2.40.500': 'Upper collar protein gp10 (connector protein) fold',
#  '2.40.510': 'Nucleoplasmin-like/VP (viral coat and capsid proteins) ',
#  '2.50.10': 'Bacteriochlorophyll-a Protein',
#  '2.50.20': 'outer membrane lipoprotein receptor (LolB), chain A',
#  '2.60.9': 'Neurophysin II; Chain A',
#  '2.60.11': 'Cytochrome C Oxidase; Chain F',
#  '2.60.15': 'ATP Synthase; domain 1',
#  '2.60.20': 'Gamma-B Crystallin; domain 1',
#  '2.60.30': 'Electron Transport Ethylamine Dehydrogenase',
#  '2.60.34': 'Substrate Binding Domain Of DNAk; Chain A, domain 1',
#  '2.60.40': 'Immunoglobulin-like',
#  '2.60.60': 'Lipoxygenase-1',
#  '2.60.90': 'Adenovirus Type 5 Fiber Protein (Receptor Binding Domain)',
#  '2.60.98': 'Tick-borne Encephalitis virus Glycoprotein; domain 1',
#  '2.60.110': 'Thaumatin',
#  '2.60.120': 'Jelly Rolls',
#  '2.60.130': 'Protocatechuate 3,4-Dioxygenase, subunit A',
#  '2.60.169': 'Bacteriophage G4 Capsid Proteins Gpf, Gpg, Gpj, subunit 1',
#  '2.60.175': 'Polyomavirus Vp1; Chain A',
#  '2.60.200': 'Tumour Suppressor Smad4',
#  '2.60.210': 'Apoptosis, Tumor Necrosis Factor Receptor Associated Protein 2; Chain A',
#  '2.60.220': 'Chondroitinase Ac; Chain A, domain 3',
#  '2.60.240': 'Viral Chemokine Inhibitor; Chain A',
#  '2.60.250': 'Baculovirus p35',
#  '2.60.260': 'HSP40/DNAj peptide-binding domain',
#  '2.60.270': 'Mutm (Fpg) Protein; Chain A, domain 2 ',
#  '2.60.290': 'Hypothetical Protein Tm1070; Chain A',
#  '2.60.300': 'Hypothetical Protein Aq_1857; Chain A; ',
#  '2.60.310': 'Hemocyanin; Chain A, domain 2',
#  '2.60.320': 'mini-chromosome maintenance (MCM) complex, domain 2',
#  '2.60.330': 'receptor-binding protein prd1-p2, domain 2',
#  '2.60.340': 'baseplate structural protein gp8, domain 1',
#  '2.60.350': 'Dex49a from penicillium minioluteum complex, domain 1',
#  '2.60.370': 'Ctag/Cox11 (Pfam 04442)',
#  '2.60.390': 'beta-galactosidase, domain 3',
#  '2.60.410': 'Peptidoglycan synthesis regulatory factor (PBP3), Domain 2',
#  '2.60.420': 'Maltose phosphorylase, domain 3',
#  '2.60.430': 'YopX-like fold',
#  '2.60.440': 'YacF-like ',
#  '2.60.450': 'lipopolysaccharide transport protein A fold',
#  '2.60.460': 'protein yfey like fold',
#  '2.60.470': 'Acid-sensing ion channels like fold',
#  '2.60.480': 'eubacterium ventriosum atcc fold',
#  '2.60.490': 'atp-gated p2x4 ion channel fold',
#  '2.60.500': 'Surface Active Protein fold',
#  '2.60.510': 'EV matrix protein fold',
#  '2.60.520': 'Triple-stranded beta-helix ',
#  '2.60.530': 'Major cell-surface adhesin PAc',
#  '2.70.9': 'Adenovirus Type 2 Hexon; domain 4',
#  '2.70.10': 'Thrombin Inhibitor (Hirudin); Chain I',
#  '2.70.20': 'Topoisomerase I; domain 3',
#  '2.70.40': "Deoxyuridine 5'-Triphosphate Nucleotidohydrolase; Chain A",
#  '2.70.50': 'Coagulation Factor XIII; Chain A, domain 1',
#  '2.70.70': 'Glucose Permease (Domain IIA)',
#  '2.70.98': 'Beta-galactosidase; Chain A, domain 5',
#  '2.70.100': '1,4-Beta-D-Glucan Cellobiohydrolase I; Chain A',
#  '2.70.130': 'Cation-dependent Mannose-6-phosphate Receptor; Chain A',
#  '2.70.150': 'Calcium-transporting ATPase, cytoplasmic transduction domain A',
#  '2.70.160': 'Hnrnp arginine n-methyltransferase1',
#  '2.70.170': 'Acetylcholine Binding Protein; Chain A, ',
#  '2.70.180': 'Protein Yojf; Chain A; ',
#  '2.70.210': 'Spo0b-associated Gtp-binding Protein; Chain A, ',
#  '2.70.220': 'Ganglioside M2 Activator Protein; Chain A, ',
#  '2.70.230': 'Glycoprotein D; Chain A; ',
#  '2.70.240': 'Leukocidin-like',
#  '2.70.250': 'receptor-binding protein prd1-p2, domain 3',
#  '2.80.10': 'Trefoil (Acidic Fibroblast Growth Factor, subunit A)',
#  '2.80.20': 'Tail fiber receptor-binding protein',
#  '2.90.10': 'Agglutinin, subunit A',
#  '2.90.20': 'Plasmodium vivax P25 fold',
#  '2.100.10': 'Vitelline Membrane Outer Layer Protein I, subunit A',
#  '2.102.10': 'Rieske Iron-sulfur Protein',
#  '2.102.20': 'beta-galactosidase, domain 2',
#  '2.102.30': 'tm1086 (SG structure) fold',
#  '2.105.10': 'Pseudo beta propeller',
#  '2.110.10': 'Hemopexin',
#  '2.115.10': 'Tachylectin-2; Chain A',
#  '2.120.10': 'Neuraminidase',
#  '2.130.10': 'Methylamine Dehydrogenase; Chain H',
#  '2.140.10': 'Methanol Dehydrogenase; Chain A',
#  '2.150.10': 'Alkaline Protease, subunit P, domain 1',
#  '2.160.10': 'UDP N-Acetylglucosamine Acyltransferase; domain 1',
#  '2.160.20': 'Pectate Lyase C-like',
#  '2.160.30': 'heat- and protease-stable fragment of the bacteriophage t4 short fibre, domain 2',
#  '2.170.8': 'Phosphoenolpyruvate Carboxykinase; domain 2',
#  '2.170.9': 'Adenovirus Type 2 Hexon; domain 1',
#  '2.170.11': 'DNA Topoisomerase I; domain 2',
#  '2.170.14': 'Tailspike Protein; Chain',
#  '2.170.15': 'Proaerolysin; Chain A, domain 3',
#  '2.170.16': 'Endonuclease - Pi-scei; Chain A, domain 1',
#  '2.170.30': 'Empty Capsid Viral Protein 2',
#  '2.170.40': 'HIV Envelope Protein Gp120; Chain G',
#  '2.170.120': 'RNA Polymerase Alpha Subunit; Chain A, domain 2',
#  '2.170.130': 'Ferric Hydroxamate Uptake Protein; Chain A, domain 1',
#  '2.170.140': 'Antimicrobial Protein, Tachycitin; Chain A',
#  '2.170.150': 'Metal Binding Protein, Guanine Nucleotide Exchange Factor; Chain A',
#  '2.170.160': 'Endo-1,4-beta-glucanase f; domain 2',
#  '2.170.170': 'Malate synthase G - maily-beta sub-domain',
#  '2.170.180': 'Methuselah ectodomain, domain 2',
#  '2.170.190': 'Molybdopterin biosynthesis moeA protein; domain 3',
#  '2.170.200': 'Regulatory Protein E2; Chain A; Domain 2',
#  '2.170.210': 'Dna Repair Protein Xrcc4; Chain A, domain 1',
#  '2.170.220': 'Methionyl-trna Synthetase; domain 2',
#  '2.170.230': 'Signal Peptidase I; Chain A, domain 2',
#  '2.170.240': 'Noncollagenous (NC1) domain of collagen IV',
#  '2.170.260': 'paz domain',
#  '2.170.270': 'Beta-clip-like',
#  '2.170.280': 'f41 fragment of flagellin, middle domain',
#  '2.170.290': 'baseplate structural protein gp8, domain 2',
#  '2.170.300': 'Tie2 ligand-binding domain fold',
#  '2.180.10': 'RHS repeat-associated core',
#  '3.10.10': 'HIV Type 1 Reverse Transcriptase; Chain A, domain 1',
#  '3.10.20': 'Ubiquitin-like (UB roll)',
#  '3.10.25': 'Methionyl-tRNA Fmet Formyltransferase; Chain A, domain 2',
#  '3.10.28': 'Endonuclease I-creI',
#  '3.10.40': 'Pertussis Toxin; Chain B, domain 1',
#  '3.10.50': 'Chitinase A; domain 3',
#  '3.10.100': 'Mannose-Binding Protein A; Chain A',
#  '3.10.105': 'Dipeptide-binding Protein; domain 3',
#  '3.10.110': 'Ubiquitin Conjugating Enzyme',
#  '3.10.120': 'Flavocytochrome B2; Chain A, domain 1',
#  '3.10.129': 'Thiol Ester Dehydrase; Chain A',
#  '3.10.130': 'P-30 Protein',
#  '3.10.150': 'DNA Polymerase III; Chain A, domain 2',
#  '3.10.170': 'Elastase; domain 1',
#  '3.10.180': '2,3-Dihydroxybiphenyl 1,2-Dioxygenase; domain 1',
#  '3.10.196': 'Cobalamin-dependent Methionine Synthase; domain 1',
#  '3.10.200': 'Carbonic Anhydrase II',
#  '3.10.250': 'Mac-2 Binding Protein',
#  '3.10.260': 'Mlu1-box Binding Protein; DNA-binding Domain',
#  '3.10.270': 'Urate Oxidase',
#  '3.10.280': 'Mitochondrial Matrix Protein; Chain A',
#  '3.10.290': 'Structural Genomics Hypothetical 15.5 Kd Protein In mrcA-pckA Intergenic Region; Chain A',
#  '3.10.300': '3-methyladenine DNA Glycosylase; Chain A',
#  '3.10.310': 'Diaminopimelate Epimerase; Chain A, domain 1',
#  '3.10.320': 'Class II Histocompatibility Antigen, M Beta Chain; Chain B, domain 1',
#  '3.10.330': 'Vcp-like ATPase; Chain A, domain 2',
#  '3.10.340': 'Methenyltetrahydromethanopterin Cyclohydrolase; Chain A, domain 1',
#  '3.10.350': 'Membrane-bound Lytic Murein Transglycosylase D; Chain A',
#  '3.10.360': 'Antimicrobial Peptide, Beta-defensin 2; Chain A',
#  '3.10.380': 'Ribonuclease domain of colicin e3 (Residues 456-551)',
#  '3.10.390': 'SAND domain',
#  '3.10.400': 'Sulfate adenylyltransferase',
#  '3.10.410': 'Formyltetrahydrofolate synthetase; domain 3',
#  '3.10.420': 'Bacterial Protein-export protein SecB',
#  '3.10.430': 'Ribosomal Protein L9; domain 2',
#  '3.10.440': 'Ribosomal Protein L31e; Chain W; ',
#  '3.10.450': 'Nuclear Transport Factor 2; Chain A, ',
#  '3.10.460': 'VSV matrix protein',
#  '3.10.470': 'chromosomal protein mc1',
#  '3.10.490': 'Hypothetical upf0131 protein ytfp',
#  '3.10.500': 'prostaphopain b, domain 1',
#  '3.10.510': 'NE1680-like fold',
#  '3.10.520': 'T-fold',
#  '3.10.530': 'CPE0013-like fold',
#  '3.10.540': 'duf1285 like fold',
#  '3.10.550': 'Atu2299-like',
#  '3.10.560': 'Outer membrane lipoprotein wza fold like',
#  '3.10.570': 'sex pheromone staph- cam373 precursor fold',
#  '3.10.580': 'CBS-domain',
#  '3.10.590': 'ph1033 like fold',
#  '3.10.600': 'pyruvate carboxylase f1077a mutant fold',
#  '3.10.610': 'Pili subunits',
#  '3.10.620': 'C8orf32 fold',
#  '3.10.630': 'dip2346 fold like',
#  '3.10.640': 'Restriction endonuclease-like alpha-beta roll fold',
#  '3.10.650': 'MalF N-terminal region-like ',
#  '3.10.660': 'Microbial ribonuclease fold',
#  '3.10.670': 'Secreted effector protein ssei fold',
#  '3.10.680': 'Photosystem II CP47 reaction center protein',
#  '3.10.690': 'Bifunctional nuclease domain',
#  '3.15.10': 'Bactericidal permeability-increasing protein; domain 1',
#  '3.15.20': 'Bactericidal permeability-increasing protein; domain 2',
#  '3.15.30': 'putative capsid protein of prophage fold',
#  '3.20.10': 'D-amino Acid Aminotransferase; Chain A, domain 2',
#  '3.20.14': 'L-fucose Isomerase; Chain A, domain 3',
#  '3.20.16': 'Serine Protease, Human Cytomegalovirus Protease; Chain A',
#  '3.20.19': 'Aconitase; domain 4',
#  '3.20.20': 'TIM Barrel',
#  '3.20.70': 'Anaerobic Ribonucleotide-triphosphate Reductase Large Chain',
#  '3.20.80': 'Multidrug-efflux Transporter 1 Regulator Bmrr; Chain A',
#  '3.20.90': 'Tubby Protein; Chain A',
#  '3.20.100': 'mRNA Triphosphatase Cet1; Chain A',
#  '3.20.110': '7-stranded beta/alpha barrel',
#  '3.20.120': 'hfbii hydrophobin',
#  '3.20.130': 'fumarase',
#  '3.20.140': 'nicotinate phosphoribosyltransferase',
#  '3.20.160': 'pseudo Tubby roll',
#  '3.20.170': 'ADP-ribosylation fold',
#  '3.20.180': 'Split barrel-like',
#  '3.20.190': 'N-terminal domain of MutM-like DNA repair proteins',
#  '3.20.200': 'Protein kinase-like fold',
#  '3.30.9': 'D-Amino Acid Oxidase; Chain A, domain 2',
#  '3.30.10': 'Trypsin Inhibitor V; Chain A',
#  '3.30.20': 'Endochitinase; domain 2',
#  '3.30.30': 'Defensin A-like',
#  '3.30.40': 'Herpes Virus-1',
#  '3.30.43': 'Uridine Diphospho-n-acetylenolpyruvylglucosamine Reductase; domain 2',
#  '3.30.44': 'Smk Toxin, Beta chain',
#  '3.30.46': 'Glycine N-methyltransferase; chain A, domain 1',
#  '3.30.50': 'Erythroid Transcription Factor GATA-1; Chain A',
#  '3.30.54': 'Replication Terminator Protein; Chain A, domain 2',
#  '3.30.56': 'Phenylalanyl-tRNA Synthetase; Chain B, domain 1',
#  '3.30.60': 'Wheat Germ Agglutinin (Isolectin 2); domain 1',
#  '3.30.62': 'Nef Regulatory Factor',
#  '3.30.63': 'Guanylate Kinase phosphate binding domain',
#  '3.30.65': 'Bacterial Topoisomerase I; domain 1',
#  '3.30.66': 'Viral Topoisomerase I',
#  '3.30.67': 'Viral Envelope Glycoprotein; domain 2',
#  '3.30.70': 'Alpha-Beta Plaits',
#  '3.30.110': 'Translation Initiation Factor IF3',
#  '3.30.160': 'Double Stranded RNA Binding Domain',
#  '3.30.170': 'Cyclin-Dependent Kinase Subunit Type 2',
#  '3.30.190': 'Ribulose 1,5 Bisphosphate Carboxylase/Oxygenase',
#  '3.30.200': 'Phosphorylase Kinase; domain 1',
#  '3.30.210': 'Beta Polymerase; domain 3',
#  '3.30.230': 'Ribosomal Protein S5; domain 2',
#  '3.30.240': 'CRO Repressor',
#  '3.30.250': 'Rec A Protein; domain 2',
#  '3.30.260': 'GROEL; domain 2',
#  '3.30.280': 'Urease; subunit A',
#  '3.30.300': 'GMP Synthetase; Chain A, domain 3',
#  '3.30.305': 'Colicin Ia; domain 2',
#  '3.30.310': 'TATA-Binding Protein',
#  '3.30.342': 'DNA Polymerase; Chain A, domain 1',
#  '3.30.350': 'Subtilisin Inhibitor',
#  '3.30.360': 'Dihydrodipicolinate Reductase; domain 2',
#  '3.30.365': 'Aldehyde Oxidoreductase; domain 4',
#  '3.30.370': 'Barnase; Chain D',
#  '3.30.379': 'Chitobiase; domain 2',
#  '3.30.380': 'MS2 Viral Coat Protein',
#  '3.30.386': 'Chitosanase; Chain A, domain 2',
#  '3.30.387': 'Viral Envelope Glycoprotein; domain 3',
#  '3.30.390': 'Enolase-like; domain 1',
#  '3.30.410': 'Cholesterol Oxidase; domain 2',
#  '3.30.412': 'Proaerolysin; Chain A, domain 2',
#  '3.30.413': 'Sulfite Reductase Hemoprotein; domain 1',
#  '3.30.420': 'Nucleotidyltransferase; domain 5',
#  '3.30.428': 'HIT family, subunit A',
#  '3.30.429': 'Macrophage Migration Inhibitory Factor',
#  '3.30.430': 'Killer Toxin P4; Chain A',
#  '3.30.450': 'Beta-Lactamase',
#  '3.30.457': 'Copper Amine Oxidase; Chain A, domain 1',
#  '3.30.460': 'Beta Polymerase; domain 2',
#  '3.30.465': 'Uridine Diphospho-n-acetylenolpyruvylglucosamine Reductase; domain 3',
#  '3.30.470': 'D-amino Acid Aminotransferase; Chain A, domain 1',
#  '3.30.479': 'Tetrahydropterin Synthase; Chain A',
#  '3.30.497': 'Antithrombin; Chain I, domain 2',
#  '3.30.499': 'Aconitase; domain 3',
#  '3.30.500': 'Murine Class I Major Histocompatibility Complex, H2-DB; Chain A, domain 1',
#  '3.30.505': 'SHC Adaptor Protein',
#  '3.30.519': 'Guanine Nucleotide Dissociation Inhibitor; domain 2',
#  '3.30.530': 'Alpha-D-Glucose-1,6-Bisphosphate; Chain A, domain 4',
#  '3.30.540': 'Fructose-1,6-Bisphosphatase; Chain A, domain 1',
#  '3.30.559': 'Chloramphenicol Acetyltransferase',
#  '3.30.560': 'Glucose Oxidase; domain 3',
#  '3.30.565': 'Heat Shock Protein 90',
#  '3.30.572': 'Thymidylate Synthase; Chain A',
#  '3.30.590': 'Creatine Kinase; Chain A, domain 2',
#  '3.30.700': 'Glycoprotein, Type 4 Pilin',
#  '3.30.710': 'Potassium Channel Kv1.1; Chain A',
#  '3.30.720': 'Signal recognition particle alu RNA binding heterodimer, srp9/1',
#  '3.30.730': 'GCC-box Binding Domain',
#  '3.30.740': 'Protein Inhibitor Of Neuronal Nitric Oxide Synthase',
#  '3.30.750': 'Transcription Regulator spoIIAA',
#  '3.30.760': 'RNA Cap, Translation Initiation Factor Eif4e',
#  '3.30.780': 'Translation Initiation Factor Eif1',
#  '3.30.800': 'Phosphatidylinositol Phosphate Kinase II Beta',
#  '3.30.810': 'Phosphatidylinositol Phosphate Kinase Iibeta; Chain A, domain 2',
#  '3.30.830': 'Cytochrome Bc1 Complex; Chain A, domain 1',
#  '3.30.860': '30s Ribosomal Protein S19; Chain A',
#  '3.30.870': 'Endonuclease; Chain A',
#  '3.30.890': 'Methyl-cpg-binding Protein 2; Chain A',
#  '3.30.900': 'Cell Cycle, Spindle Assembly Checkpoint Protein; Chain A',
#  '3.30.910': 'Protein Binding, DinI Protein; Chain A',
#  '3.30.920': 'Metal Transport, Frataxin; Chain A',
#  '3.30.930': 'BirA Bifunctional Protein; domain 2',
#  '3.30.950': 'Methyltransferase, Cobalt-precorrin-4 Transmethylase; Domain 2',
#  '3.30.960': 'Translation, Eukaryotic Peptide Chain Release Factor Subunit 1; Chain A',
#  '3.30.980': 'Threonyl-tRNA Synthetase; Chain A, domain 2',
#  '3.30.990': 'Formiminotransferase-cyclodeaminase; Chain B, domain 1',
#  '3.30.1010': 'Phosphatidylinositol 3-kinase Catalytic Subunit; Chain A, domain 4',
#  '3.30.1020': 'Antioxidant, Horf6; Chain A, domain 2',
#  '3.30.1030': 'Methenyltetrahydromethanopterin Cyclohydrolase; Chain A, domain 2',
#  '3.30.1040': 'Carboxypeptidase Inhibitor; Chain A',
#  '3.30.1050': 'Nonspecific Lipid-transfer Protein; Chain A',
#  '3.30.1060': 'Peptide Methionine Sulfoxide Reductase; Chain A',
#  '3.30.1070': 'Cell Cycle; Chain A',
#  '3.30.1110': 'Adenosine kinase, small domain',
#  '3.30.1120': 'Arylsulfatase, C-terminal domain',
#  '3.30.1130': 'GTP Cyclohydrolase I, domain 2',
#  '3.30.1140': 'Ribosomal protein S3 C-terminal domain ',
#  '3.30.1150': 'Fusion Protein Consisting Of Minor Coat Protein, Glycine Rich Linker, Tola, And A His Tag; Chain A; Domain 2',
#  '3.30.1160': 'Cyanate Lyase; Chain A, domain 2',
#  '3.30.1170': 'Valyl-trna Synthetase; Chain A, domain 4',
#  '3.30.1180': 'Hypothetical Protein Tm841; Chain A;domain 3',
#  '3.30.1190': 'Dna-binding Protein Tfx; Chain A; ',
#  '3.30.1200': 'Conserved Hypothetical Protein Mth637; Chain A; ',
#  '3.30.1220': 'Hypothetical Protein Yjia; Chain A;domain 2',
#  '3.30.1230': 'Hypothetical Cytosolic Protein; Chain A; ',
#  '3.30.1240': 'Hypothetical Protein, Haloacid Dehalogenase-like Hydrolase; Chain A; domain 2',
#  '3.30.1250': 'Hypothetical 12.0 Kda Protein In Nam8-gar1 Intergenic Region; Chain A; ',
#  '3.30.1280': 'Mth169; Chain A , ',
#  '3.30.1300': 'Pantoate--beta-alanine Ligase; Chain A,domain 2',
#  '3.30.1310': 'Ybab; Chain A; ',
#  '3.30.1320': 'S16 Ribosomal Protein; Chain A; ',
#  '3.30.1330': '60s Ribosomal Protein L30; Chain A; ',
#  '3.30.1340': 'Histidine-containing Protein; Chain A; ',
#  '3.30.1350': 'Crambin',
#  '3.30.1360': 'Gyrase A; domain 2',
#  '3.30.1370': 'Ribosomal Protein S8; Chain A, domain 1',
#  '3.30.1380': 'Muramoyl-pentapeptide Carboxypeptidase; domain 2',
#  '3.30.1390': 'Ribosomal Protein L30; Chain A, ',
#  '3.30.1400': 'Cell Division Protein Zipa; Chain A,',
#  '3.30.1410': 'Gtp Cyclohydrolase I Feedback Regulatory Protein; Chain K',
#  '3.30.1420': 'Dissimilatory Siroheme-sulfite Reductase; Chain A; domain 1',
#  '3.30.1430': 'Ribosomal Protein L3; Chain B; domain 2,',
#  '3.30.1440': '50s Ribosomal Protein L5; Chain A, ',
#  '3.30.1450': 'Beta-lactamase Inhibitory Protein; ChainB, domain 1',
#  '3.30.1460': 'Yope Regulator; Chain A, ',
#  '3.30.1470': 'Photosystem 1 Reaction Centre Subunit Ii; Chain D; ',
#  '3.30.1480': 'N Utilization Substance Protein A; ChainP; domain 4',
#  '3.30.1490': 'Dna Ligase; domain 1',
#  '3.30.1500': 'Heme-binding Protein A; Chain A; ',
#  '3.30.1510': 'Domain 2, N(10)-formyltetrahydrofolate synthetase',
#  '3.30.1520': 'PX Domain',
#  '3.30.1530': 'manganese catalase, domain 2, chain A',
#  '3.30.1540': 'formyl-coa transferase, domain 3',
#  '3.30.1550': 'Ribosomal protein L11, N-terminal domain',
#  '3.30.1560': 'Mago nashi protein',
#  '3.30.1570': 'YopH tyrosine phosphatase N-terminal domain',
#  '3.30.1580': 'Head-to-tail joining protein W, gpW',
#  '3.30.1590': 'Maltooligosyl trehalose synthase, domain 2',
#  '3.30.1600': "SIR2/SIRT2 'Small Domain'",
#  '3.30.1610': 'c-terminal autoproteolytic domain of nucleoporin nup98',
#  '3.30.1620': 'b-12 dependent (class ii) ribonucleotide reductase, Chain A, Domain 2',
#  '3.30.1640': 'mini-chromosome maintenance (MCM) complex, chain A, domain 1',
#  '3.30.1650': 'Bifunctional carbon monoxide dehydrogenase/acetyl-coa synthase(codh/acs), Chain M, domain 3',
#  '3.30.1660': 'Dodecin subunit-like',
#  '3.30.1670': '3-mercaptopyruvate sulfurtransferase, domain 3',
#  '3.30.1680': 'ligand-binding face of the semaphorins, domain 2',
#  '3.30.1690': 'TcpA-like pilin',
#  '3.30.1700': 'lpxc deacetylase, domain 1',
#  '3.30.1710': 'top7, de novo designed protein',
#  '3.30.1730': 'amp nucleosidase, domain 1',
#  '3.30.1740': 'first zn-finger domain of poly(adp-ribose) polymerase-1',
#  '3.30.1750': 'hemolytic lectin cel-iii, domain 3',
#  '3.30.1760': 'Conserved hypothetical protein from pyrococcus furiosus pfu- 392566-001, domain 2',
#  '3.30.1770': 'TPR 1 domain of DNA polymerase',
#  '3.30.1780': 'ornithine cyclodeaminase, domain 1',
#  '3.30.1790': 'hypothetical protein mp506/mpn330, domain 2',
#  '3.30.1810': 'YdfO-like fold',
#  '3.30.1820': 'Lp2179-like fold',
#  '3.30.1830': 'YehR-like fold',
#  '3.30.1840': 'polyphosphate kinase like',
#  '3.30.1850': 'MCP/YpsA-like',
#  '3.30.1860': 'uncharacterized conserved protein from methanopyrus kandleri fold like',
#  '3.30.1870': 'EreA/ChaN-like, small alpha-beta sandwich',
#  '3.30.1880': 'protein ne1242 fold',
#  '3.30.1890': 'Bacterial polysaccharide co-polymerase-like',
#  '3.30.1900': 'glyoxalase-related enzyme like fold',
#  '3.30.1910': 'so0334 like fold',
#  '3.30.1920': 'Phage tail proteins - 2 layer sandwich fold',
#  '3.30.1930': 'capsid protein of prophage fold',
#  '3.30.1940': 'Nucleic acid-binding protein fold',
#  '3.30.1950': 'wza like fold',
#  '3.30.1960': 'SSo0622-like fold',
#  '3.30.1970': 'AF2331-like fold',
#  '3.30.1980': 'Hypothetical protein Ta1206 fold',
#  '3.30.1990': 'CbiD-like',
#  '3.30.2000': 'STM4215-like',
#  '3.30.2010': 'Zincin-like',
#  '3.30.2020': 'NE0471 N-terminal domain-like',
#  '3.30.2030': 'TBP-like',
#  '3.30.2040': 'PSTPO5379-like fold',
#  '3.30.2050': 'photosynthetic oxygen evolving center fold',
#  '3.30.2060': 'Penicillin-binding protein 1b fold',
#  '3.30.2070': 'Formate dehydrogenase/DMSO reductase,',
#  '3.30.2080': 'GH92 mannosidase fold',
#  '3.30.2090': 'Multidrug efflux transporter AcrB TolC docking domain; DN and DC subdomains ',
#  '3.30.2110': 'CbiD-like',
#  '3.30.2120': 'Bacillus phage protein',
#  '3.30.2130': 'VC0802-like',
#  '3.30.2140': 'Arylamine N-acetyltransferase fold',
#  '3.30.2150': 'S-adenosyl-L-methionine-dependent methyltransferases',
#  '3.30.2160': 'Hect, E3 ligase catalytic domain',
#  '3.30.2170': 'archaeoglobus fulgidus dsm 4304 fold',
#  '3.30.2180': 'ATP12-like',
#  '3.30.2190': 'PG1857-like ',
#  '3.30.2200': 'histidine kinase doma clostridium symbiosum atcc 14940',
#  '3.30.2210': 'Integron cassette protein  fold',
#  '3.30.2220': 'rbstp2171 ',
#  '3.30.2230': 'DUSP-like',
#  '3.30.2240': 'mRNA decapping enzyme DcpS N-terminal fold',
#  '3.30.2250': 'Prim-pol fold',
#  '3.30.2260': 'ERH-like fold',
#  '3.30.2270': 'Folate-binding fold',
#  '3.30.2280': 'copper amine oxidase-like fold',
#  '3.30.2290': 'PmbA/TldD fold',
#  '3.30.2300': 'THUMP fold',
#  '3.30.2310': 'YaeB-like fold',
#  '3.30.2320': 'hypothetical protein PF0899 fold',
#  '3.30.2330': 'arginine biosynthesis bifunctional protein fold',
#  '3.30.2340': 'Pseudouridine synthase',
#  '3.30.2350': 'Pseudouridine synthase',
#  '3.30.2360': 'Glyceraldehyde-3-phosphate dehydrogenase-like fold',
#  '3.30.2370': 'putative pyruvate dehydrogenase fold',
#  '3.30.2380': 'PF0523-like',
#  '3.30.2390': 'TTHA1013/TTHA0281-like',
#  '3.30.2400': 'Major capsid protein gp5 fold',
#  '3.30.2410': 'Hect, E3 ligase catalytic fold',
#  '3.30.2420': 'TolA/TonB C-terminal domain ',
#  '3.30.2430': 'Phosphothreonine lyase fold',
#  '3.30.2440': 'Secreted effector protein SifA fold',
#  '3.30.2450': 'Secreted effector protein pipB2 fold',
#  '3.30.2460': 'Endo-n-acetylneuraminidase fold',
#  ...}

# %%
print(f"Unique CATH IDs: {len(cath_names_dict)}")
# Out:
# Unique CATH IDs: 8150

# %%
def map_labels_to_names(label_str):
    labels = label_str.split(",")
    return [
        cath_names_dict.get(label, "unknown_domain") if label != "unknown_domain" else "unknown_domain"
        for label in labels
    ]

acc2cathnames = df_dom_labels_filtered.set_index(df_dom_labels_filtered.columns[0])[df_dom_labels_filtered.columns[1]].apply(map_labels_to_names).to_dict()
acc2cathnames
# Out:
# {'A0A061JS76': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A077F8T2': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A095VF86': ['Macrophage Migration Inhibitory Factor',
#   'Fumarylacetoacetase-like, C-terminal domain'],
#  'A0A060M7A0': ['unknown_domain', 'Macrophage Migration Inhibitory Factor'],
#  'A0A096FN63': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A0C3RBI9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A098BVI1': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A0B2B229': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A0C5IY25': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A0G0GKY3': ['Macrophage Migration Inhibitory Factor', 'Helix Hairpins'],
#  'A0A0G0J3Y8': ['Macrophage Migration Inhibitory Factor', 'Helix Hairpins'],
#  'A0A0G3BHE0': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A0G3SJ65': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A0H5P302': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A0L8KU01': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A0M7F4V2': ['Macrophage Migration Inhibitory Factor',
#   'Fumarylacetoacetase-like, C-terminal domain'],
#  'A0A0M9WPB0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A0N6ZDZ5': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A0P0RFI7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A0P8XNG2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A
': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A2U3NMH8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A2V2Z113': ['Macrophage Migration Inhibitory Factor', 'AhpD-like'],
#  'A0A2V4B1A2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A2Z3IDD4': ['Macrophage Migration Inhibitory Factor',
#   'Winged helix-like DNA-binding domain superfamily/Winged helix DNA-binding domain'],
#  'A0A2Z6CM10': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A317NBT0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A318LQZ8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A323UQ31': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A345T3J9': ['Dimeric alpha+beta barrel',
#   'Macrophage Migration Inhibitory Factor'],
#  'A0A354BI70': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A365ZYQ7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A366LEE8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A366LJS2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A367F7V2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A368LF31': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A370GL22': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A372M560': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A378X0N0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A379Y1Q8': ['2,3-Dihydroxybiphenyl 1,2-Dioxygenase, domain 1',
#   'Macrophage Migration Inhibitory Factor'],
#  'A0A383RJR9': ['Macrophage Migration Inhibitory Factor', 'AhpD-like'],
#  'A0A398CU70': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A3A5HFP2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A3A9YRL6': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A3B7AAQ1': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A3D9I5M7': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A3D9JRF2': ['Macrophage Migration Inhibitory Factor',
#   'Double Stranded RNA Binding Domain'],
#  'A0A3D9MUL4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A3E0C5D1': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A3G3JTI7': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A3G8M6X7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A3L7A6Q4': ['Macrophage Migration Inhibitory Factor',
#   'unknown_domain',
#   'unknown_domain'],
#  'A0A3L7AH30': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A3L7AIJ2': ['Macrophage Migration Inhibitory Factor',
#   'unknown_domain',
#   'unknown_domain'],
#  'A0A3N4GPQ6': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A3N5I8N0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A3Q8VQL9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A3S0Z2U5': ['Macrophage Migration Inhibitory Factor',
#   'Rhopdopsin 7-helix transmembrane proteins'],
#  'A0A3S4CAA7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A3T1DBD5': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A402CMN7': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A434A3K8': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A443YHU1': ['Macrophage Migration Inhibitory Factor',
#   'acylaminoacyl peptidase',
#   'Alpha/Beta hydrolase fold, catalytic domain',
#   'unknown_domain'],
#  'A0A446C4T0': ['Macrophage Migration Inhibitory Factor',
#   'Fumarylacetoacetase-like, C-terminal domain'],
#  'A0A446C7Q9': ['Macrophage Migration Inhibitory Factor',
#   'Fumarylacetoacetase-like, C-terminal domain'],
#  'A0A449H4U2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A485BHJ3': ['AhpD-like', 'Macrophage Migration Inhibitory Factor'],
#  'A0A494X7J8': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A495T6U2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4P6GY15': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A4P6U933': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4P7H578': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4P7Y904': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A4Q8TBQ4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R0XP45': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R1M9P5': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R3Q5P1': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R4N5K2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R4V7E7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R5E392': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R5M1T3': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R5XC03': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R6EJV7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R8K300': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4R8SX64': ['Aldolase class I', 'Macrophage Migration Inhibitory Factor'],
#  'A0A4S2IXL7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4S3K9T6': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A4S4BLA2': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A4U0FD57': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A4U5WQV3': ['Macrophage Migration Inhibitory Factor', 'YaeB-like'],
#  'A0A4U6QAR0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4U8WD87': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4U9DBS0': ['unknown_domain', 'Macrophage Migration Inhibitory Factor'],
#  'A0A4V3CVX0': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A4V3URC4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4V3YUZ8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4Y3G052': ['Macrophage Migration Inhibitory Factor',
#   'unknown_domain',
#   'unknown_domain'],
#  'A0A4Y3QSZ5': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4Y8LVH9': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A4Y8MX30': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4Y8Y7Z7': ['Macrophage Migration Inhibitory Factor',
#   'unknown_domain',
#   'nan'],
#  'A0A4Y9UZ02': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A4Z0N909': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A502E667': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A510IYE8': ['Macrophage Migration Inhibitory Factor',
#   '30s ribosomal protein s13; domain 2'],
#  'A0A511MTR3': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A519GUR3': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A519LLT1': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A520FQD7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A522A1S7': ['Macrophage Migration Inhibitory Factor',
#   'Isochorismatase-like'],
#  'A0A522QTT4': ['Macrophage Migration Inhibitory Factor',
#   'Macrophage Migration Inhibitory Factor',
#   'unknown_domain',
#   'unknown_domain',
#   'unknown_domain',
#   'unknown_domain'],
#  'A0A522RKB3': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A525VF74': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A525VSS6': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A525W9K8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A532C164': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A532CGQ9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A532CT24': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A532EUI2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A533BIV0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A533XSG4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A543DZX0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A542KQP6': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A543F9A5': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A544YF28': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A544Z0Z2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A554LGR8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A558DKV4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A559JSU1': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A561SVK8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A562VAI0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A562VCI9': ['Macrophage Migration Inhibitory Factor', 'Herpes Virus-1'],
#  'A0A5B0H8E7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A5C4LRP7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A5C4WQX2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A5C5Q5A2': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A5C7RKH2': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A5C7UGW8': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A5C9C0N6': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A5C9CTP2': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A5J6L1G9': ['lambda repressor-like DNA-binding domains',
#   'Response regulator',
#   'Response regulator',
#   'Macrophage Migration Inhibitory Factor'],
#  'A0A5J6UCM9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A5N6BQ34': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A5N7XFC4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A5N7ZH83': ['Macrophage Migration Inhibitory Factor',
#   'Fumarylacetoacetase-like, C-terminal domain'],
#  'A0A5P9WIL7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A5R8MCY4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A5R8NG81': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A5R9BE79': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A643MA16': ['Macrophage Migration Inhibitory Factor',
#   'unknown_domain',
#   'AhpD-like'],
#  'A0A5S4G1U0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6A0IFM2': ['Macrophage Migration Inhibitory Factor',
#   'START domain',
#   'START domain'],
#  'A0A650GDB7': ['Macrophage Migration Inhibitory Factor',
#   'Isochorismatase-like'],
#  'A0A6B3Q9V8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6C1KM14': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6G3D1D0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6G4TVX8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6G4WXG9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6G6YTZ2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6G9A0Q9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6G9GTI5': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A6G9GUF7': ['Macrophage Migration Inhibitory Factor', 'nan'],
#  'A0A6G9Y9M4': ['Winged helix-like DNA-binding domain superfamily/Winged helix DNA-binding domain',
#   'unknown_domain',
#   'Macrophage Migration Inhibitory Factor'],
#  'A0A6H1BWM9': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A6H9GKI9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6I3A0R5': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6I6LX30': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6I6WTY2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6J5AGH9': ['Macrophage Migration Inhibitory Factor',
#   'Fumarylacetoacetase-like, C-terminal domain'],
#  'A0A6J5DTK3': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A6N6N5J6': ['unknown_domain',
#   'Macrophage Migration Inhibitory Factor',
#   'Alpha/Beta hydrolase fold, catalytic domain'],
#  'A0A6N6W4V4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6N7HGA4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6N7IGG6': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6N8G680': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6N8JB46': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A6N8S5H1': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A6N9UAZ3': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6P1CNJ9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6P1D6E9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6P1HRB0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6P1HUQ6': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A6S7BZD6': ['Macrophage Migration Inhibitory Factor',
#   'Fumarylacetoacetase-like, C-terminal domain'],
#  'A0A6S7EIY2': ['Macrophage Migration Inhibitory Factor',
#   'Fumarylacetoacetase-like, C-terminal domain'],
#  'A0A6S7FAJ4': ['Macrophage Migration Inhibitory Factor',
#   'Fumarylacetoacetase-like, C-terminal domain'],
#  'A0A6V8LVP4': ['Macrophage Migration Inhibitory Factor',
#   'acylaminoacyl peptidase',
#   'Alpha/Beta hydrolase fold, catalytic domain',
#   'unknown_domain'],
#  'A0A7C1HUT6': ['Macrophage Migration Inhibitory Factor',
#   'acylaminoacyl peptidase',
#   'Alpha/Beta hydrolase fold, catalytic domain',
#   'unknown_domain'],
#  'A0A7C5F1B3': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7G1KPC0': ['Macrophage Migration Inhibitory Factor', 'NADH Oxidase'],
#  'A0A7G5BW09': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A7H8M5F0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7I8BU40': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7I8CLN9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7J9XT32': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7K0NZG2': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A7K2X0N4': ['Macrophage Migration Inhibitory Factor', 'nan'],
#  'A0A7K3NH57': ['Macrophage Migration Inhibitory Factor',
#   'acylaminoacyl peptidase',
#   'Alpha/Beta hydrolase fold, catalytic domain',
#   'unknown_domain'],
#  'A0A7K3PX01': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7M2SH56': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7R7DMC9': ['Macrophage Migration Inhibitory Factor', 'nan'],
#  'A0A7S8FDY0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7U8GQS2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7W0CGN2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7W3NIL8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7W7LD08': ['Macrophage Migration Inhibitory Factor', 'RutC-like'],
#  'A0A7W7QB93': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7W7W3Z2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7W8Q590': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7W8Q6X1': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A7W8QHV8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7X0P1J9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7X0RXB3': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A7X1J7V4': ['Macrophage Migration Inhibitory Factor', 'YaeB-like'],
#  'A0A7X5ZSB2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7X6RKR6': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7X7JGP9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7Y0JT92': ['Macrophage Migration Inhibitory Factor', 'nan'],
#  'A0A7Y4KXM4': ['Macrophage Migration Inhibitory Factor', 'nan'],
#  'A0A7Y4SBS4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7Y4SEU1': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7Y6JWV9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7Y7Y241': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A7Y9DXP1': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7Y9JEZ2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7Y9XFM4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7Z1AX07': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A7Z2VK08': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A7Z7FFK7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A839HU41': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A840HVK9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A841BMH0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A841FGG0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A841JJF3': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A841SS30': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A841TCX2': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A841U416': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A842K7Z9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A846XCG1': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A846Y3X1': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A846YH43': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A848DCH3': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'A0A848KJ94': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A848KRY9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A848RVB0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'A0A849TJU5': ['Macrophage Migration Inhibitory Factor',
#   'lambda repressor-like DNA-binding domains'],
#  'A0A852W7U0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'C1AVF9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'C5C4V9': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'C7QGF3': ['Macrophage Migration Inhibitory Factor', 'nan'],
#  'D1AMD1': ['Macrophage Migration Inhibitory Factor', 'AhpD-like'],
#  'E3HV55': ['Macrophage Migration Inhibitory Factor',
#   'Fumarylacetoacetase-like, C-terminal domain'],
#  'E6VTG4': ['Macrophage Migration Inhibitory Factor',
#   'acylaminoacyl peptidase',
#   'Alpha/Beta hydrolase fold, catalytic domain',
#   'unknown_domain'],
#  'E9UUU0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'F4D231': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'F9ZW79': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'G0VRI1': ['Macrophage Migration Inhibitory Factor', 'nan'],
#  'G7M9J4': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'G8T938': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'H5U3I1': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'H5WWF4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'H6R1H2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'H8IMD3': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'I8I494': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'I3CGR5': ['Macrophage Migration Inhibitory Factor',
#   'Gcn5-related N-acetyltransferase (GNAT)'],
#  'J7LCQ7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'K4QTH1': ['Macrophage Migration Inhibitory Factor', 'YaeB-like'],
#  'K9UDU2': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'L8P517': ['Macrophage Migration Inhibitory Factor', 'Herpes Virus-1'],
#  'M2ZWZ5': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'N6YBH1': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'N6YEQ4': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'Q0SD71': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'Q0SD79': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'Q5YPK7': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'Q826M0': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'U2G0W3': ['Macrophage Migration Inhibitory Factor',
#   'Single alpha-helices involved in coiled-coils or other helix-helix interfaces'],
#  'W2EPI0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'W5TMV0': ['Macrophage Migration Inhibitory Factor', 'unknown_domain'],
#  'X6GRG0': ['Macrophage Migration Inhibitory Factor', 'YaeB-like'],
#  'Z9JWI8': ['Macrophage Migration Inhibitory Factor', 'unknown_domain']}

# %%
# Step 1: Remove 'Macrophage Migration Inhibitory Factor' if it's alone in the list
cleaned_labels = []
for labels in acc2cathnames.values():
    if labels.count('Macrophage Migration Inhibitory Factor') == 1 and len(labels) > 1:
        filtered = [l for l in labels if l != 'Macrophage Migration Inhibitory Factor']
    else:
        filtered = labels
    cleaned_labels.extend(filtered)

# Count frequency and sort
freq = Counter(cleaned_labels)
freq_sorted = dict(sorted(freq.items(), key=lambda x: x[1], reverse=True))

# Plot using matplotlib
plt.figure(figsize=(10, 6))
plt.barh(list(freq_sorted.keys()), list(freq_sorted.values()), color='skyblue')
plt.xlabel("Frequency")
plt.ylabel("Domain Name")
plt.title("Frequency of Domain Labels (Cleaned)")
plt.gca().invert_yaxis()  # Highest frequency at top
plt.tight_layout()
plt.savefig("Co-occuring-domains.svg")
plt.show()

# %%
df_dom_counts
# Out:
#         Accession Count
# 0      A0A009H1Z0     1
# 1      A0A009HCT7     1
# 2      A0A009I523     1
# 3      A0A009HRD8     1
# 4      A0A009PD57     1
# ...           ...   ...
# 18317      X8GZX3     1
# 18318      X8HN85     1
# 18319      X8I072     1
# 18320      Z9JR86     1
# 18321      Z9JWI8     2
#
# [18322 rows x 2 columns]

# %%
# Load the file
df_dom_counts = pd.read_csv("tacc2domcounts", header=None, names=["Accession", "Count"])
df_dom_counts_filtered = df_dom_counts[df_dom_counts['Accession'].isin(non_redun_list)]
df_dom_counts_filtered["Count"] = pd.to_numeric(df_dom_counts_filtered["Count"], errors="coerce")
df_dom_counts_filtered = df_dom_counts_filtered.dropna(subset=["Count"])
df_dom_counts_filtered["Count"] = df_dom_counts_filtered["Count"].astype(int)

# Main histogram
fig, ax = plt.subplots(figsize=(8, 6))
ax.hist(df_dom_counts_filtered["Count"], bins=range(df_dom_counts_filtered["Count"].min(), df_dom_counts_filtered["Count"].max() + 2), edgecolor="black", align="left", color="skyblue")
ax.set_xlabel("Domain Count")
ax.set_ylabel("Frequency")
ax.set_title("Histogram of Domain Counts")

# Remove grid background
ax.grid(False)
ax.set_facecolor('white')

# Add inset for domain counts > 1
inset_ax = inset_axes(ax, width="40%", height="40%", loc="upper right", borderpad=2)
inset_ax.grid(False)
df_gt1 = df_dom_counts_filtered[df_dom_counts_filtered["Count"] > 1]
if not df_gt1.empty:
    inset_ax.hist(df_gt1["Count"], bins=range(df_gt1["Count"].min(), df_gt1["Count"].max() + 2), edgecolor="black", align="left", color="skyblue")
    inset_ax.set_title("Counts > 1", fontsize=10)
    inset_ax.set_xticks(range(df_gt1["Count"].min(), df_gt1["Count"].max() + 1))
else:
    inset_ax.text(0.5, 0.5, "No entries >1", ha="center", va="center", fontsize=10)
    inset_ax.axis("off")

plt.tight_layout()
plt.savefig("Domain_Frequency_Hist.svg")
plt.show()
# Out:
# /tmp/ipykernel_1199619/3980360469.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_1199619/3980360469.py:31: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.

# %%
def print_multiple_mif_entries(acc2cathnames, target="Macrophage Migration Inhibitory Factor"):
    """
    Print entries in acc2labels where 'Macrophage Migration Inhibitory Factor' appears more than once.
    
    Parameters:
    - acc2labels: dict, mapping from accession to list of labels
    - target: str, the label to search for multiple occurrences of
    """
    for acc, labels in acc2cathnames.items():
        if labels.count(target) > 1:
            print(f"{acc}: {labels}")
            
print_multiple_mif_entries(acc2cathnames)
# Out:
# A0A522QTT4: ['Macrophage Migration Inhibitory Factor', 'Macrophage Migration Inhibitory Factor', 'unknown_domain', 'unknown_domain', 'unknown_domain', 'unknown_domain']
