# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
import pandas as pd
import numpy as np
from collections import Counter
from plotnine import ggplot, aes, geom_bar, coord_flip, labs, theme_classic, scale_y_continuous, scale_color_discrete, guides, geom_col, scale_fill_manual 
import seaborn as sns
from upsetplot import from_memberships, UpSet

# %%
### Read the unique identifier files from FoldSeek and HMMER search, display overlap as venn diagram

def read_identifiers(file):
    with open(file, 'r') as f:
        lis = []
        lines = f.readlines()
        for line in lines:
            identifier = line.strip()
            lis.append(identifier)
        return set(lis)
        


# Read identifiers from the two files
fs_identifiers = read_identifiers("FS_tacc_Qcov80.u") # Target accessions of foldseekk hits (after quality filtering)
hmmer_identifiers = read_identifiers("HMMER_tacc.u")# Target accessions of hmmer hits (after quality filtering)


# Create a Venn diagram
venn2([fs_identifiers, hmmer_identifiers], ('', ''), set_colors=("Blue", "steelblue"))


# Display the plot
plt.title("")
plt.savefig("Foldseek_HMMER_venn.svg")
plt.show()

# %%
### Read and graph uniprot protein name annotations for each MIF

# Load data
names = pd.read_csv("combined_uniprot_protnames_Qcov80", sep="\t")

# Count occurrences of each protein name
protein_counts = names['Protein names'].value_counts()

# Optional: Limit to top N to avoid clutter
top_n = 20
protein_counts_top = protein_counts.nlargest(top_n)
other_count = protein_counts.iloc[top_n:].sum()
protein_counts_top['Other'] = other_count

# Plot horizontal bar chart
plt.figure(figsize=(20, 10))
protein_counts_top.sort_values().plot.barh(color='skyblue', fontsize=16)  # sort for visual clarity

plt.xlabel("Count")
#plt.title("Top Protein Names in Dataset", fontsize=16)
plt.tight_layout()
plt.savefig("protein_names_bar.svg")
plt.show()

print(protein_counts_top)
# Out:
# Protein names
# 5-carboxymethyl-2-hydroxymuconate isomerase                                                                  2850
# Tautomerase family protein                                                                                   2649
# 4-oxalocrotonate tautomerase                                                                                 2549
# L-dopachrome isomerase (EC 5.3.2.1) (EC 5.3.3.12) (L-dopachrome tautomerase) (Phenylpyruvate tautomerase)    1195
# 5-carboxymethyl-2-hydroxymuconate Delta-isomerase                                                             962
# Tautomerase enzyme                                                                                            850
# Tautomerase                                                                                                   721
# Uncharacterized protein                                                                                       676
# 5-carboxymethyl-2-hydroxymuconate Delta-isomerase (EC 5.3.3.10)                                               506
# DUF1904 domain-containing protein                                                                             502
# Phenylpyruvate tautomerase PptA (4-oxalocrotonate tautomerase family)                                         476
# Isomerase                                                                                                     359
# 4-oxalocrotonate tautomerase-like domain-containing protein                                                   271
# Tautomerase-like protein                                                                                      260
# 4-oxalocrotonate tautomerase domain-containing protein                                                        259
# Phenylpyruvate tautomerase PptA, 4-oxalocrotonate tautomerase family                                          241
# 4-oxalocrotonate tautomerase family protein                                                                   225
# Tautomerase cis-CaaD-like domain-containing protein                                                           217
# DUF1904 family protein                                                                                        210
# 5-carboxymethyl-2-hydroxymuconate delta-isomerase                                                             164
# Other                                                                                                        2180
# Name: count, dtype: int64

# %%
## Get Taxa  data for each accesion


acc2taxid = {}
df_taxa = pd.read_csv("tmp.tacc2txid.qcov80.u", sep="\t") #target accession (Uniref90 Representative) to NCBI_identifier mapping, from UniProts Mapping Tool


#Turn UniProt Mapping to Python Dict
for index, row in df_taxa.iterrows():
    acc = row[0]
    tax_id = row[2]
    acc2taxid[acc] = tax_id
acc2taxid
# Out:
# /tmp/ipykernel_2878486/1996403804.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /tmp/ipykernel_2878486/1996403804.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# {'A0A009H1Z0': 1310608,
#  'A0A009HCT7': 1310608,
#  'A0A009HRD8': 1310613,
#  'A0A009I523': 1310613,
#  'A0A009N468': 1310652,
#  'A0A009N6V0': 1310652,
#  'A0A009PD57': 1310607,
#  'A0A009QCK8': 1310607,
#  'A0A009R8H0': 1310637,
#  'A0A009RT57': 1310637,
#  'A0A009SI62': 1310630,
#  'A0A009TGX8': 1310630,
#  'A0A009YTH9': 1310601,
#  'A0A009ZCB5': 1310601,
#  'A0A010INF0': 1310681,
#  'A0A010JMD3': 1310681,
#  'A0A010RN88': 1042209,
#  'A0A011MJ67': 85402,
#  'A0A011UXL5': 1341156,
#  'A0A011VUM0': 1341156,
#  'A0A013T945': 1310791,
#  'A0A013TCJ8': 1310791,
#  'A0A013TSB9': 1310764,
#  'A0A013UUB9': 1310764,
#  'A0A014KZH8': 1158056,
#  'A0A014L8W3': 1158056,
#  'A0A014MBQ3': 69222,
#  'A0A014ME04': 1158056,
#  'A0A014MEZ2': 1158056,
#  'A0A014Q9J3': 1457173,
#  'A0A016XD06': 1458275,
#  'A0A016XKK4': 1458275,
#  'A0A017HPD5': 442562,
#  'A0A017RWW7': 1403537,
#  'A0A017T4D9': 1192034,
#  'A0A021VSG6': 948458,
#  'A0A021X158': 1410620,
#  'A0A021X2N5': 1410620,
#  'A0A022FWJ5': 574750,
#  'A0A022G2K5': 574750,
#  'A0A022GKV3': 574750,
#  'A0A022J069': 1310723,
#  'A0A022J4K3': 1310723,
#  'A0A022MDJ3': 1470557,
#  'A0A022MDU0': 1470557,
#  'A0A022MH87': 1470557,
#  'A0A022PFT7': 2805098,
#  'A0A023BSF7': 1317122,
#  'A0A023CVN5': 1423806,
#  'A0A023D1X9': 1231351,
#  'A0A023DEV7': 1220594,
#  'A0A023X4L8': 42256,
#  'A0A024E5B7': 1147786,
#  'A0A024H5T4': 861266,
#  'A0A024HH19': 1301098,
#  'A0A024HIJ7': 1301098,
#  'A0A024HN66': 1301098,
#  'A0A024L7E2': 562,
#  'A0A024QEY5': 1462526,
#  'A0A031FVN4': 273677,
#  'A0A031G0T6': 1470589,
#  'A0A031G830': 1470589,
#  'A0A031IC33': 1470592,
#  'A0A031IP61': 1470593,
#  'A0A031IUD7': 1470593,
#  'A0A031J2X1': 1470593,
#  'A0A031LYC4': 466088,
#  'A0A037ZGW4': 1454373,
#  'A0A051TS54': 1324261,
#  'A0A051TYU7': 1324261,
#  'A0A058ZK49': 1461693,
#  'A0A059DL83': 1280944,
#  'A0A059F9W8': 1280952,
#  'A0A059KNG9': 1286631,
#  'A0A059KRX4': 1286631,
#  'A0A059L839': 1419583,
#  'A0A059L9G3': 1419583,
#  'A0A059VUS5': 1971,
#  'A0A059WQ78': 77133,
#  'A0A059ZJX3': 470,
#  'A0A060I0A4': 1432050,
#  'A0A060I300': 1432050,
#  'A0A060I4W5': 1432050,
#  'A0A060M7A0': 1246626,
#  'A0A060QHN3': 91915,
#  'A0A060ZDC6': 576784,
#  'A0A060ZNL3': 576784,
#  'A0A060ZPW1': 576784,
#  'A0A060ZWJ1': 576784,
#  'A0A061A285': 576784,
#  'A0A061JS76': 1218352,
#  'A0A061JVI9': 1218352,
#  'A0A061NEY0': 1460649,
#  'A0A061NGY1': 1460634,
#  'A0A061NMW9': 1460634,
#  'A0A061NZC9': 1460635,
#  'A0A061P830': 1460636,
#  'A0A061PCL1': 1460636,
#  'A0A061ST83': 83219,
#  'A0A061SWM6': 83219,
#  'A0A062GLE5': 1310685,
#  'A0A062GSM9': 1310685,
#  'A0A062IJ32': 1310697,
#  'A0A062IMT2': 1310697,
#  'A0A062UJE8': 1280946,
#  'A0A062VCH4': 1280954,
#  'A0A063Y4P0': 267850,
#  'A0A063YQR4': 1482739,
#  'A0A066RJX4': 1654360,
#  'A0A066RSX5': 1654360,
#  'A0A066TBT4': 3120254,
#  'A0A066UCN7': 743974,
#  'A0A066UQ93': 212667,
#  'A0A066UZ63': 212667,
#  'A0A066YH34': 1348663,
#  'A0A066Z6Z2': 1348663,
#  'A0A066Z8Y8': 1348663,
#  'A0A066ZQM3': 28885,
#  'A0A067BH39': 1481663,
#  'A0A067Z2L5': 1288313,
#  'A0A068NNG0': 661478,
#  'A0A068QSF8': 351671,
#  'A0A068SMN0': 1028800,
#  'A0A068SP51': 1028800,
#  'A0A068T3X3': 1028801,
#  'A0A068THI9': 1028801,
#  'A0A068YMW5': 1504672,
#  'A0A069AWA8': 1496,
#  'A0A069D1H6': 1329250,
#  'A0A069E5H1': 1280949,
#  'A0A069I1K8': 1470558,
#  'A0A069I592': 1470558,
#  'A0A069I817': 1470558,
#  'A0A069IG28': 1470558,
#  'A0A069IKR9': 1470558,
#  'A0A069INU2': 1495854,
#  'A0A069P8Q9': 1071679,
#  'A0A069PEA1': 60547,
#  'A0A069PJD5': 60547,
#  'A0A069PPJ4': 60547,
#  'A0A069Q2Z8': 287,
#  'A0A069RFV0': 1121324,
#  'A0A071LSG8': 1224318,
#  'A0A071M4Q4': 95486,
#  'A0A071MC55': 95486,
#  'A0A071MCE1': 95486,
#  'A0A071MEQ0': 95486,
#  'A0A071MF79': 95486,
#  'A0A071MKL8': 95486,
#  'A0A071ML38': 95486,
#  'A0A071MRR9': 95486,
#  'A0A072H8A2': 670,
#  'A0A072N637': 1137280,
#  'A0A072NJ63': 1348973,
#  'A0A073J262': 1402135,
#  'A0A073K075': 1598,
#  'A0A073KEC1': 574375,
#  'A0A074J685': 1353528,
#  'A0A074LUR1': 1157490,
#  'A0A074MGL1': 1157490,
#  'A0A074TNJ2': 1185766,
#  'A0A075JXQ3': 1217721,
#  'A0A075K5M0': 1217721,
#  'A0A086BLJ3': 558152,
#  'A0A086D195': 1492922,
#  'A0A086FNU9': 615,
#  'A0A086MP78': 1549810,
#  'A0A086MQ47': 1549810,
#  'A0A086N3Z2': 67332,
#  'A0A086N710': 67332,
#  'A0A086XVS8': 1105367,
#  'A0A086Z1W8': 1437605,
#  'A0A086ZF21': 1437606,
#  'A0A086ZLH3': 78343,
#  'A0A086ZLU8': 1437608,
#  'A0A086ZQZ5': 1437608,
#  'A0A086ZTC4': 1437608,
#  'A0A087A6T5': 1437609,
#  'A0A087AHD6': 35760,
#  'A0A087AN00': 1688,
#  'A0A087AP32': 78344,
#  'A0A087BAW5': 1692,
#  'A0A087BED7': 78345,
#  'A0A087BPI1': 1695,
#  'A0A087BRD1': 1693,
#  'A0A087C4Q1': 1437603,
#  'A0A087CLV0': 218140,
#  'A0A087CVX1': 78346,
#  'A0A087CYB6': 1437610,
#  'A0A087CZE3': 1437611,
#  'A0A087DBD1': 1437607,
#  'A0A087DJ22': 158787,
#  'A0A087DLE9': 1437612,
#  'A0A087DRC9': 762211,
#  'A0A087E301': 79262,
#  'A0A087E877': 77635,
#  'A0A087ECW3': 356829,
#  'A0A087KX53': 1524467,
#  'A0A087N4C8': 1473546,
#  'A0A087PR10': 178901,
#  'A0A087VSX0': 1341694,
#  'A0A089HK53': 44251,
#  'A0A089HK82': 44251,
#  'A0A089I007': 1536774,
#  'A0A089I3Q2': 1536774,
#  'A0A089I9G0': 1536774,
#  'A0A089IBP5': 1536775,
#  'A0A089PFU3': 1501269,
#  'A0A089PRV5': 61647,
#  'A0A089PTX1': 158822,
#  'A0A089PXK9': 158822,
#  'A0A089XA80': 1907,
#  'A0A089YH66': 157783,
#  'A0A089YR12': 216142,
#  'A0A090DDV4': 69974,
#  'A0A090DHU3': 69974,
#  'A0A090DQL1': 69974,
#  'A0A090DR71': 408180,
#  'A0A090E378': 408184,
#  'A0A090E459': 1437425,
#  'A0A090EUQ7': 1505946,
#  'A0A090F1R1': 69974,
#  'A0A090GAY1': 69974,
#  'A0A090GFG4': 69974,
#  'A0A090GJJ1': 69974,
#  'A0A090GNW0': 1505946,
#  'A0A090KLU4': 80852,
#  'A0A090MN27': 1035,
#  'A0A090QGS3': 754436,
#  'A0A090QU53': 754436,
#  'A0A090RM16': 754436,
#  'A0A090RRQ5': 990268,
#  'A0A090S440': 990268,
#  'A0A090S6T6': 990268,
#  'A0A090T3Y5': 990268,
#  'A0A090TEP3': 990268,
#  'A0A090Y5K6': 44252,
#  'A0A090YTU1': 2338372,
#  'A0A094JGL9': 1515746,
#  'A0A094K1V0': 1515746,
#  'A0A095HDC3': 28450,
#  'A0A095T0D2': 642227,
#  'A0A095VF86': 1532557,
#  'A0A095W9S7': 28095,
#  'A0A095XAN5': 28095,
#  'A0A095XJP6': 1532557,
#  'A0A095XLI0': 1532557,
#  'A0A095YFQ5': 28095,
#  'A0A096B5Q1': 742738,
#  'A0A096B5W9': 742738,
#  'A0A096DKZ4': 363952,
#  'A0A0E1W0F2': 320371,
#  'A0A0E1X032': 520462,
#  'A0A0E2NA52': 1287287,
#  'A0A0E2NAQ2': 1287287,
#  'A0A0E2NSK5': 1287273,
#  'A0A0E2NU74': 1287273,
#  'A0A0E2Z6W9': 1681,
#  'A0A0E3C1I6': 363952,
#  'A0A0E3JMW4': 1548,
#  'A0A0E3MAY1': 1548,
#  'A0A0E3U8L5': 573737,
#  'A0A0E3YA67': 573737,
#  'A0A0E3ZT46': 1379870,
#  'A0A0E4BU12': 1355477,
#  'A0A0E4CUR3': 1073571,
#  'A0A0E4G170': 1355477,
#  'A0A0E4GVS2': 141349,
#  'A0A0E4GY28': 141349,
#  'A0A0E7V2R9': 520,
#  'A0A0E9MVY4': 1220578,
#  'A0A0E9ZL15': 1546029,
#  'A0A0F0CN72': 1609975,
#  'A0A0F0DD39': 1619951,
#  'A0A0F0DES0': 1619951,
#  'A0A0F0DHN8': 1619951,
#  'A0A0F0DUN7': 1619951,
#  'A0A0F0DXL3': 1619951,
#  'A0A0F0E7W1': 1619951,
#  'A0A0F0EQD9': 1619952,
#  'A0A0F0FLE1': 1619952,
#  'A0A0F0FNM4': 1619952,
#  'A0A0F0FTS6': 1619952,
#  'A0A0F0GTK4': 68170,
#  'A0A0F0GVI5': 68170,
#  'A0A0F0HHY3': 1427391,
#  'A0A0F0HPE5': 1427391,
#  'A0A0F0KG86': 582680,
#  'A0A0F0KTT2': 582680,
#  'A0A0F0LUX7': 400772,
#  'A0A0F1AJ77': 2071710,
#  'A0A0F1UX81': 548,
#  'A0A0F2C4C8': 1263625,
#  'A0A0F2GZ51': 1616781,
#  'A0A0F2JDZ4': 1617025,
#  'A0A0F2PYD9': 1629712,
#  'A0A0F2QQ90': 1629720,
#  'A0A0F2T436': 359131,
#  'A0A0F2TAA3': 359131,
#  'A0A0F2TDG8': 359131,
#  'A0A0F3IKW6': 1632867,
#  'A0A0F3IWG1': 552518,
#  'A0A0F3K4M0': 345309,
#  'A0A0F3K6T2': 345309,
#  'A0A0F3WCL7': 562,
#  'A0A0F4KQP9': 1218508,
#  'A0A0F4L0F5': 1684,
#  'A0A0F4L4M4': 1684,
#  'A0A0F4LW15': 1218492,
#  'A0A0F4NKX6': 579748,
#  'A0A0F4NPK9': 579748,
#  'A0A0F4PRQ8': 151081,
#  'A0A0F4PU34': 151081,
#  'A0A0F4QT15': 43658,
#  'A0A0F4QXQ9': 579484,
#  'A0A0F4R271': 579484,
#  'A0A0F4R6J1': 579484,
#  'A0A0F4R7Q2': 579484,
#  'A0A0F4R8Y6': 579484,
#  'A0A0F4STL8': 294,
#  'A0A0F4SZY4': 294,
#  'A0A0F4TM92': 294,
#  'A0A0F4U4Z5': 294,
#  'A0A0F4V4U8': 294,
#  'A0A0F4VE64': 294,
#  'A0A0F4XFL4': 132476,
#  'A0A0F4XGY8': 132476,
#  'A0A0F4XJ93': 132476,
#  'A0A0F4XRP7': 132476,
#  'A0A0F5APZ4': 1406902,
#  'A0A0H2KP91': 264251,
#  'A0A0H2LPF1': 34073,
#  'A0A0H2LUI0': 34073,
#  'A0A0H2LVT4': 34073,
#  'A0A0H2LWZ8': 34073,
#  'A0A0H2M8D0': 34073,
#  'A0A0H2MGA6': 1489064,
#  'A0A0H2MGS3': 1489064,
#  'A0A0H2MK11': 1647102,
#  'A0A0H2MTH6': 1489064,
#  'A0A0H2MX72': 1647102,
#  'A0A0H2NAP9': 1647102,
#  'A0A0H2WBH1': 243160,
#  'A0A0H2WBZ1': 243160,
#  'A0A0H2WR47': 295319,
#  'A0A0H2XXS1': 331271,
#  'A0A0H2XYT0': 331271,
#  'A0A0H2Y0W4': 331271,
#  'A0A0H2YK54': 377628,
#  'A0A0H2ZA53': 208963,
#  'A0A0H2ZFU1': 208963,
#  'A0A0H3A3S7': 243243,
#  'A0A0H3AGU1': 345073,
#  'A0A0H3AM57': 345073,
#  'A0A0H3AUB4': 444178,
#  'A0A0H3B3U9': 502800,
#  'A0A0H3BWS6': 423368,
#  'A0A0H3CFA8': 716541,
#  'A0A0H3E833': 702459,
#  'A0A0H3F9R1': 2703885,
#  'A0A0H3FES2': 2703885,
#  'A0A0H3FHE3': 2703885,
#  'A0A0H3FJ33': 2703885,
#  'A0A0H3FNI1': 1028307,
#  'A0A0H3GC19': 204722,
#  'A0A0H3GPQ0': 1125630,
#  'A0A0H3GR74': 1125630,
#  'A0A0H3GSF1': 1125630,
#  'A0A0H3H5D2': 1006551,
#  'A0A0H3HDZ7': 1006551,
#  'A0A0H3HSZ7': 884204,
#  'A0A0H3HZ17': 884204,
#  'A0A0H3JAW9': 1262449,
#  'A0A0H3K6C5': 269084,
#  'A0A0H3KPK5': 395019,
#  'A0A0H3KQY3': 395019,
#  'A0A0H3KT69': 395019,
#  'A0A0H3L3X7': 932677,
#  'A0A0H3LHY8': 257310,
#  'A0A0H3LXL3': 257310,
#  'A0A0H3MZ16': 645462,
#  'A0A0H3NJZ7': 216597,
#  'A0A0H3PD76': 375177,
#  'A0A0H3WT63': 656179,
#  'A0A0H3WTU0': 656179,
#  'A0A0H3XJZ4': 315358,
#  'A0A0H4BZD9': 1577075,
#  'A0A0H4IWC1': 1623450,
#  'A0A0H5A894': 200450,
#  'A0A0H5ADT0': 200450,
#  'A0A0H5CYS1': 1653480,
#  'A0A0H5D5G1': 481446,
#  'A0A0H5NG18': 37329,
#  'A0A0H5NHU0': 37329,
#  'A0A0H5P302': 37329,
#  'A0A0H5RLF8': 146018,
#  'A0A0H5SUZ0': 1564487,
#  'A0A0H7DB44': 666,
#  'A0A0I2G3G5': 624,
#  'A0A0J0UP34': 680496,
#  'A0A0J0V7W6': 1659191,
#  'A0A0J0ZVB8': 1409923,
#  'A0A0J1A9W1': 1409923,
#  'A0A0J1BNL8': 1663685,
#  'A0A0J1BQR6': 1660349,
#  'A0A0J1CSP9': 908627,
#  'A0A0J1CUM9': 908627,
#  'A0A0J1D153': 908627,
#  'A0A0J1FMI5': 476652,
#  'A0A0K1U6S9': 1671721,
#  'A0A0K1W0H5': 216942,
#  'A0A0K1ZIC9': 305,
#  'A0A0K2AQG8': 278992,
#  'A0A0K2RKR7': 1588023,
#  'A0A0K2VWT5': 69974,
#  'A0A0K2W6B0': 69974,
#  'A0A0K2ZRZ3': 227946,
#  'A0A0K2ZTK1': 1195923,
#  'A0A0K3A283': 1195923,
#  'A0A0K3A303': 487906,
#  'A0A0K3BSG5': 703222,
#  'A0A0K6GX55': 375574,
#  'A0A0K6HNU6': 466044,
#  'A0A0K6HZQ9': 339866,
#  'A0A0K6HZY2': 339866,
#  'A0A0K6I0B1': 339866,
#  'A0A0K6IHK1': 1137284,
#  'A0A0K6IHP5': 1137284,
#  'A0A0K6IM19': 1137284,
#  'A0A0K8MJA8': 157463,
#  'A0A0K8P1G1': 1547922,
#  'A0A0K8PBM3': 146537,
#  'A0A0K8PGH2': 146537,
#  'A0A0K8Q5A5': 1588022,
#  'A0A0K8QM43': 1475481,
#  'A0A0K9GCA8': 1679169,
#  'A0A0K9H8D7': 1679168,
#  'A0A0K9UR04': 412614,
#  'A0A0K9UVC9': 412614,
#  'A0A0K9XAM3': 1678637,
#  ...}

# %%
### Get taxonomy summary file for each MIF NCBI id and combine into one dataframe; save output so we don't have to repeat

"""
cols = [
    "Query", "Taxid", "Tax name", "Authority", "Rank", "Basionym", "Basionym authority",
    "Curator common name", "Has type material", "Group name", "Superkingdom name", "Superkingdom taxid",
    "Kingdom name", "Kingdom taxid", "Phylum name", "Phylum taxid", "Class name", "Class taxid",
    "Order name", "Order taxid", "Family name", "Family taxid", "Genus name", "Genus taxid",
    "Species name", "Species taxid", "Scientific name is formal"
]

# List to collect each DataFrame for better performance
df_list = []
accs = []
exceptions = []

for key, value in acc2taxid.items():
    try:
        path = f'/workdir/djl294/NCBI_tax_MIF/{value}/ncbi_dataset/data/taxonomy_summary.tsv'
        summary_df = pd.read_csv(path, sep="\t")
        summary_df["ACC"] = key  # Add ACC column directly here
        df_list.append(summary_df)
        accs.append(key)
    except Exception as e:
        print(f'{value} error: {e}')
        exceptions.append(value)

# Concatenate all DataFrames and write to CSV
combined_taxa_df = pd.concat(df_list, ignore_index=True)
combined_taxa_df.to_csv("combined_taxa_output.csv", index=False)

# Optional: show or return the DataFrame if desired
combined_taxa_df

"""

combined_taxa_df = pd.read_csv("combined_taxa_output.csv")
combined_taxa_df
# Out:
#          Query    Taxid                          Tax name         Authority  \
# 0      1310608  1310608         Acinetobacter sp. 1295259               NaN
# 1      1310608  1310608         Acinetobacter sp. 1295259               NaN
# 2      1310613  1310613   Acinetobacter baumannii 1295743               NaN
# 3      1310613  1310613   Acinetobacter baumannii 1295743               NaN
# 4      1310652  1310652         Acinetobacter sp. 1475718               NaN
# ...        ...      ...                               ...               ...
# 18307   936563   936563            Fusobacterium sp. CM22               NaN
# 18308  1032505  1032505           Fusobacterium sp. OBRC1               NaN
# 18309   936561   936561             Fusobacterium sp. CM1               NaN
# 18310   396014   396014  Brachybacterium phenoliresistens  Chou et al. 2007
# 18311   396014   396014  Brachybacterium phenoliresistens  Chou et al. 2007
#
#           Rank Basionym Basionym authority Curator common name  \
# 0      SPECIES      NaN                NaN                 NaN
# 1      SPECIES      NaN                NaN                 NaN
# 2       STRAIN      NaN                NaN                 NaN
# 3       STRAIN      NaN                NaN                 NaN
# 4      SPECIES      NaN                NaN                 NaN
# ...        ...      ...                ...                 ...
# 18307  SPECIES      NaN                NaN                 NaN
# 18308  SPECIES      NaN                NaN                 NaN
# 18309  SPECIES      NaN                NaN                 NaN
# 18310  SPECIES      NaN                NaN                 NaN
# 18311  SPECIES      NaN                NaN                 NaN
#
#       Has type material                       Group name  ...  \
# 0                    no                 g-proteobacteria  ...
# 1                    no                 g-proteobacteria  ...
# 2                    no                 g-proteobacteria  ...
# 3                    no                 g-proteobacteria  ...
# 4                    no                 g-proteobacteria  ...
# ...                 ...                              ...  ...
# 18307                no                     fusobacteria  ...
# 18308                no                     fusobacteria  ...
# 18309                no                     fusobacteria  ...
# 18310               yes  high G+C Gram-positive bacteria  ...
# 18311               yes  high G+C Gram-positive bacteria  ...
#
#             Order name  Order taxid       Family name  Family taxid  \
# 0         Moraxellales    2887326.0     Moraxellaceae         468.0
# 1         Moraxellales    2887326.0     Moraxellaceae         468.0
# 2         Moraxellales    2887326.0     Moraxellaceae         468.0
# 3         Moraxellales    2887326.0     Moraxellaceae         468.0
# 4         Moraxellales    2887326.0     Moraxellaceae         468.0
# ...                ...          ...               ...           ...
# 18307  Fusobacteriales     203491.0  Fusobacteriaceae      203492.0
# 18308  Fusobacteriales     203491.0  Fusobacteriaceae      203492.0
# 18309  Fusobacteriales     203491.0  Fusobacteriaceae      203492.0
# 18310    Micrococcales      85006.0  Dermabacteraceae       85020.0
# 18311    Micrococcales      85006.0  Dermabacteraceae       85020.0
#
#             Genus name  Genus taxid                      Species name  \
# 0        Acinetobacter        469.0         Acinetobacter sp. 1295259
# 1        Acinetobacter        469.0         Acinetobacter sp. 1295259
# 2        Acinetobacter        469.0           Acinetobacter baumannii
# 3        Acinetobacter        469.0           Acinetobacter baumannii
# 4        Acinetobacter        469.0         Acinetobacter sp. 1475718
# ...                ...          ...                               ...
# 18307    Fusobacterium        848.0            Fusobacterium sp. CM22
# 18308    Fusobacterium        848.0           Fusobacterium sp. OBRC1
# 18309    Fusobacterium        848.0             Fusobacterium sp. CM1
# 18310  Brachybacterium      43668.0  Brachybacterium phenoliresistens
# 18311  Brachybacterium      43668.0  Brachybacterium phenoliresistens
#
#        Species taxid Scientific name is formal         ACC
# 0            1310608                     False  A0A009H1Z0
# 1            1310608                     False  A0A009HCT7
# 2                470                     False  A0A009HRD8
# 3                470                     False  A0A009I523
# 4            1310652                     False  A0A009N468
# ...              ...                       ...         ...
# 18307         936563                     False      X8GZX3
# 18308        1032505                     False      X8HN85
# 18309         936561                     False      X8I072
# 18310         396014                      True      Z9JR86
# 18311         396014                      True      Z9JWI8
#
# [18312 rows x 28 columns]

# %%
### For a given taxanomic level, make a sub-dataframe for plotting

def get_taxa_ratios(df, Target_Taxa):
    Target_Taxa_List = []
    level_index = df.columns.get_loc(Target_Taxa)
    for i, row in df.iterrows():
        tax_name = row[level_index]
        Target_Taxa_List.append(tax_name)
        
          
    counts = Counter(Target_Taxa_List)
    #print(Target_Taxa_List)

    total_counts = sum(list(counts.values()))
    
    
    
    percent_dict = {}
    for key, value in counts.items():
        percent = value/total_counts * 100
        percent_dict[key] = percent
    #print(percent_dict)
        
    n = len(percent_dict.keys())
    Levels = [Target_Taxa] * n
    sub_df = pd.DataFrame({
        "Level": Levels,
        "Label": percent_dict.keys(),
        "Perc": percent_dict.values()
    })
    
    return sub_df
    


phylum_plot_df = get_taxa_ratios(combined_taxa_df, "Phylum name")
  
print(phylum_plot_df)
    
    
    
family_plot_df = get_taxa_ratios(combined_taxa_df, "Family name")
  
print(family_plot_df)
    
genus_plot_df = get_taxa_ratios(combined_taxa_df, "Genus name")
  
print(genus_plot_df)

species_plot_df = get_taxa_ratios(combined_taxa_df, "Species name")
  
print(species_plot_df)
# Out:
# /tmp/ipykernel_2878486/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#           Level                              Label       Perc
# 0   Phylum name                     Pseudomonadota  60.752512
# 1   Phylum name                          Bacillota  10.326562
# 2   Phylum name                     Actinomycetota  18.184797
# 3   Phylum name                        Myxococcota   0.447794
# 4   Phylum name                       Bacteroidota   2.561162
# ..          ...                                ...        ...
# 66  Phylum name                     Fibrobacterota   0.016383
# 67  Phylum name                    Fidelibacterota   0.005461
# 68  Phylum name  Candidatus Handelsmaniibacteriota   0.005461
# 69  Phylum name        Candidatus Rifleibacteriota   0.005461
# 70  Phylum name                      Chrysiogenota   0.005461
#
# [71 rows x 3 columns]
# /tmp/ipykernel_2878486/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#            Level                       Label      Perc
# 0    Family name               Moraxellaceae  2.839668
# 1    Family name            Pseudomonadaceae  6.269113
# 2    Family name             Pasteurellaceae  0.578855
# 3    Family name            Oscillospiraceae  0.540629
# 4    Family name           Streptomycetaceae  6.280035
# ..           ...                         ...       ...
# 415  Family name          Geitlerinemataceae  0.005461
# 416  Family name               Xenococcaceae  0.005461
# 417  Family name  Candidatus Korobacteraceae  0.005461
# 418  Family name          Symbiobacteriaceae  0.005461
# 419  Family name             Microthrixaceae  0.005461
#
# [420 rows x 3 columns]
# /tmp/ipykernel_2878486/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#            Level                     Label      Perc
# 0     Genus name             Acinetobacter  2.386413
# 1     Genus name               Pseudomonas  6.028834
# 2     Genus name                Mannheimia  0.043687
# 3     Genus name              Ruminococcus  0.212975
# 4     Genus name              Streptomyces  5.897772
# ...          ...                       ...       ...
# 1446  Genus name  Candidatus Competibacter  0.010922
# 1447  Genus name          Commensalibacter  0.005461
# 1448  Genus name           Intrasporangium  0.005461
# 1449  Genus name               Imhoffiella  0.005461
# 1450  Genus name         Agrilactobacillus  0.005461
#
# [1451 rows x 3 columns]
# /tmp/ipykernel_2878486/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#              Level                             Label      Perc
# 0     Species name         Acinetobacter sp. 1295259  0.010922
# 1     Species name           Acinetobacter baumannii  0.267584
# 2     Species name         Acinetobacter sp. 1475718  0.010922
# 3     Species name          Acinetobacter sp. 809848  0.010922
# 4     Species name          Acinetobacter sp. 479375  0.010922
# ...            ...                               ...       ...
# 8285  Species name           Marinomonas ushuaiensis  0.010922
# 8286  Species name            Fusobacterium sp. CM22  0.005461
# 8287  Species name           Fusobacterium sp. OBRC1  0.005461
# 8288  Species name             Fusobacterium sp. CM1  0.005461
# 8289  Species name  Brachybacterium phenoliresistens  0.010922
#
# [8290 rows x 3 columns]

# %%
def plot_taxa_distribution(df, top_n=5, title_prefix=''):
    # Ensure 'Perc' is numeric
    df['Perc'] = pd.to_numeric(df['Perc'], errors='coerce')
    df = df.dropna(subset=['Perc'])

    valid_df = df.dropna(subset=['Label'])
    nan_label_perc = df[df['Label'].isna()]['Perc'].sum()

    df_sorted = valid_df.sort_values('Perc', ascending=False).reset_index(drop=True)
    top_df = df_sorted.iloc[:top_n].copy()
    other_perc = df_sorted.iloc[top_n:]['Perc'].sum() + nan_label_perc

    if other_perc > 0:
        other_row = pd.DataFrame([{
            'Level': top_df['Level'].iloc[0] if 'Level' in top_df.columns else '',
            'Label': 'Other',
            'Perc': other_perc
        }])
        top_df = pd.concat([top_df, other_row], ignore_index=True)

    # Define a consistent color palette
    colors = sns.color_palette('pastel', n_colors=len(top_df))
    
    # Polar Pie-style Plot (no label clutter, legend instead)
    plt.figure(figsize=(8, 6))
    ax = plt.subplot(111, polar=True)
    perc = top_df['Perc']
    labels = top_df['Label']
    total = perc.sum()
    angles = perc.cumsum() / total * 2 * np.pi
    widths = perc / total * 2 * np.pi
    start_angles = np.concatenate(([0], angles[:-1]))

    bars = ax.bar(x=start_angles + widths / 2, height=1, width=widths,
                  bottom=0.0, linewidth=1, edgecolor='white', color=colors)

    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_title(f'{title_prefix}Taxa Distribution (Pie Chart)', y=1.1)

    # Add legend with percentages
    legend_labels = [f"{label}: {value:.1f}%" for label, value in zip(labels, perc)]
    ax.legend(bars, legend_labels, loc='center left', bbox_to_anchor=(1.05, 0.5), fontsize=15)

    plt.tight_layout()
    out_pie = f'{title_prefix}_pie.svg'
    plt.savefig(out_pie)
    plt.show()

    # Horizontal Bar Chart using same colors
    plt.figure(figsize=(10, 6))
    sns.barplot(data=top_df, y='Label', x='Perc', palette=colors)
    plt.xlabel('Percentage')
    plt.title(f'{title_prefix}Taxa Distribution (Bar Chart)')
    plt.tight_layout()
    plt.show()

    return top_df

# %%
plot_taxa_distribution(species_plot_df, top_n=5, title_prefix='Species')
# Out:
#           Level                          Label       Perc
# 0  Species name            Salmonella enterica   2.042377
# 1  Species name        Pseudomonas fluorescens   0.819135
# 2  Species name        Chloroflexota bacterium   0.622543
# 3  Species name  Gammaproteobacteria bacterium   0.584316
# 4  Species name              Mesorhizobium sp.   0.535168
# 5  Species name                          Other  95.396461

# %%
# Original deeplocpro run
df_deeplocpro = pd.read_csv("deeplocpro_out/results_20250726-030536.csv")

# Run with added results from qcov80 run
df_deeplocpro_newqcov80 = pd.read_csv("deeplocpro_out_newqcov80/results_20250801-145618.csv")  # Replace with actual filename

# Concatenate the two DataFrames
df_deeplocpro = pd.concat([df_deeplocpro, df_deeplocpro_newqcov80], ignore_index=True)

# Extract accession numbers for "Extracellular" proteins
deeplocpro_secreted = []
for i, r in df_deeplocpro.iterrows():
    acc = str(r['ACC']).split("|")[1]
    if r['Localization'] == "Extracellular":
        print(acc)
        deeplocpro_secreted.append(acc)
        
deeplocpro_secreted = list(set(deeplocpro_secreted))        
print(len(deeplocpro_secreted))
# Out:
# A0A071MCE1
# A0A0G1K7I5
# A0A0G1RRC5
# A0A0J5ZZK7
# A0A106DBC2
# A0A107QBE1
# A0A1J4RVD8
# A0A1W7D0T3
# A0A2A4CKA2
# A0A2A4R048
# A0A2H0DT84
# A0A2H0VK31
# A0A2W4LB07
# A0A364GZR7
# A0A3D4CNU7
# A0A3M2KYU5
# A0A3N8HZI0
# A0A3P0MLW5
# A0A3P0NKS1
# A0A495YQF8
# A0A4R4AFZ5
# A0A6L3NEU5
# A0A6P2GE12
# A0A6P3B8N2
# A0A7C9BQH6
# A0A7T1MH78
# A0A7T6VLR4
# A0A853B724
# B4EL67
# W0E6T2
# A0A1B1K7R9
# A0A1G0X3Z4
# A0A1H9E726
# A0A1M5JVI2
# A0A1Q3H4W8
# A0A3Q9KB29
# A0A522QTT4
# A0A6L9EX20
# A0A6P2J7C1
# A0A7H1B137
# H5WP24
# 41

# %%
### Parse the output from DEEPTMHMM, if any residues are outside of the cell, print the whole per-residue localization
def parse_file_into_blocks(filename):
    with open(filename, 'r') as file:
        block = []
        for counter, line in enumerate(file, start=1):
            block.append(line.rstrip('\n'))  # Append the line without the newline character
            if counter % 3 == 0:
                yield block
                block = []
        
        # If there are remaining lines that do not form a complete block at the end
        if block:
            yield block

            
            
            
deeptmhmm_outside = []
#Parse First deeptmhmm run
blocks = []
for block in parse_file_into_blocks("deeptmhmm_results/predicted_topologies.3line"):
    id_string = str(block[0].split(" |")[0]).split(">")[1]
    residue_locs = block[2]
    if 'O' in residue_locs:
        print(id_string, residue_locs)
        acc = id_string.split("|")[1]
        deeptmhmm_outside.append(acc)

        
# parse second deeptmhmmrun with added results from qcov80 run               
blocks = []    
for block in parse_file_into_blocks("deeptmhmm_results_newqcov80/predicted_topologies.3line"):
    id_string = str(block[0].split(" |")[0]).split(">")[1]
    residue_locs = block[2]
    if 'O' in residue_locs:
        print(id_string, residue_locs)
        acc = id_string.split("|")[1]
        deeptmhmm_outside.append(acc)
        
        
print(deeptmhmm_outside)       
print(len(deeptmhmm_outside))
# Out:
# tr|A0A1B1K7R9|A0A1B1K7R9_RHOOP 
# tr|A0A1M6NB40|A0A1M6NB40_9BRAD SSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSSOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# tr|A0A443YHU1|A0A443YHU1_9BACT ...
# tr|A0A496UGQ0|A0A496UGQ0_UNCFE SSSSSSSSSSSSSSSSSSSSSSSOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOOO
# tr|A0A6N6N5J6|A0A6N6N5J6_9BACT ...
# tr|A0A6V8LVP4|A0A6V8LVP4_9BACT ...
# tr|A0A7C1HUT6|A0A7C1HUT6_9BACT ...
# tr|A0A7K3NH57|A0A7K3NH57_9BACT ...
# tr|E6VTG4|E6VTG4_PSEA9 ...
# ['A0A1B1K7R9', 'A0A1M6NB40', 'A0A443YHU1', 'A0A496UGQ0', 'A0A6N6N5J6', 'A0A6V8LVP4', 'A0A7C1HUT6', 'A0A7K3NH57', 'E6VTG4']
# 9

# %%
#Read in the secreted uniprot identifiers
uniprot_secreted = []
with open("MIFs_UniProt_Secreted", 'r') as f:
    lines = f.readlines()
    for line in lines:
        acc = line.strip()
        uniprot_secreted.append(acc)
        
#Read in the secreted uniprot identifiers from qcov80 run        
with open("MIFs_UniProt_Secreted_newqcov80", 'r') as f:
    lines = f.readlines()
    for line in lines:
        acc = line.strip()
        uniprot_secreted.append(acc)
        
print(uniprot_secreted)  
print(len(uniprot_secreted))
# Out:
# ['A0A011VUM0', 'A0A076HQJ4', 'A0A076JKV6', 'A0A078KTQ4', 'A0A084JL76', 'A0A086Z1W8', 'A0A086ZF21', 'A0A087AHD6', 'A0A087AN00', 'A0A087AP32', 'A0A087BRD1', 'A0A087C4Q1', 'A0A087CVX1', 'A0A087CYB6', 'A0A087CZE3', 'A0A087DRC9', 'A0A087E301', 'A0A087VSX0', 'A0A089PFU3', 'A0A096B5Q1', 'A0A096B5W9', 'A0A0A0BCX7', 'A0A0A1GR13', 'A0A0A1VZT2', 'A0A0A1ZAT1', 'A0A0A1ZYB9', 'A0A0A2A886', 'A0A0A2A8L2', 'A0A0A2AHU2', 'A0A0A2B5J2', 'A0A0A2BCY2', 'A0A0A2BGG5', 'A0A0A2BN57', 'A0A0A2C661', 'A0A0A2CF60', 'A0A0A6PHM1', 'A0A0A7I3P3', 'A0A0A7I624', 'A0A0B5QUH5', 'A0A0C1QV00', 'A0A0C1YCU0', 'A0A0D6AJX7', 'A0A0D6KNU9', 'A0A0D8IUR7', 'A0A0D8ZXV6', 'A0A0E2Z6W9', 'A0A0E3JMW4', 'A0A0F0CN72', 'A0A0F3IKW6', 'A0A0F4L0F5', 'A0A0F4L4M4', 'A0A0G3G3A4', 'A0A0H3E833', 'A0A0H3K6C5', 'A0A0H5SUZ0', 'A0A0J1G3E5', 'A0A0J8FDB6', 'A0A0J9C317', 'A0A0K1S7V7', 'A0A0M0VL25', 'A0A0M1JXU5', 'A0A0M2PQX8', 'A0A0N0V262', 'A0A0N8KMQ4', 'A0A0P7ZA40', 'A0A0P9EMF1', 'A0A0R2XLC5', 'A0A0S2HXF2', 'A0A0S2MG90', 'A0A0S2TE81', 'A0A0S3U0K2', 'A0A0S8BL48', 'A0A0S8EVJ7', 'A0A0S8F3S2', 'A0A0T5YSR4', 'A0A0T7BML8', 'A0A0V7ZQ50', 'A0A126QMZ1', 'A0A126T5F5', 'A0A133KK40', 'A0A133NNS5', 'A0A133P353', 'A0A135Z478', 
22', 'A0A1Q6LQB0', 'A0A1Q6Q2Q0', 'A0A1S1Y779', 'A0A1S8LPH1', 'A0A1S8RTX8', 'A0A1S8S9C9', 'A0A1S8TEN2', 'A0A1S9NBC9', 'A0A1T2KR94', 'A0A1T2L8Z3', 'A0A1T4JHJ5', 'A0A1T4N778', 'A0A1T4VVX1', 'A0A1T4W186', 'A0A1T4WES0', 'A0A1T4YD93', 'A0A1U7HFD1', 'A0A1U7HPN0', 'A0A1U7I4D0', 'A0A1U7J9V1', 'A0A1U7NBY2', 'A0A1V1PGV1', 'A0A1V3A0X6', 'A0A1V3JIM7', 'A0A1V3NL71', 'A0A1V4BSU2', 'A0A1V4IZ21', 'A0A1V4MU53', 'A0A1V5GLA3', 'A0A1V5L9T7', 'A0A1V5NLG8', 'A0A1V5S6P1', 'A0A1V5V7H9', 'A0A1V5WHZ1', 'A0A1V5XPG0', 'A0A1V6HFV6', 'A0A1V8M9M7', 'A0A1V8PRZ8', 'A0A1W1X2N6', 'A0A1W9LBW8', 'A0A1W9X203', 'A0A1X2FXF0', 'A0A1X7CJ20', 'A0A1Y0RTF9', 'A0A1Y1CN56', 'A0A1Y3WCU0', 'A0A1Y3XQD5', 'A0A1Y4EWL6', 'A0A1Y4I959', 'A0A1Y4J0V7', 'A0A1Y4J3W6', 'A0A1Y4KXD2', 'A0A1Y4SXT1', 'A0A1Y4T9W9', 'A0A1Y5DL89', 'A0A1Y5F282', 'A0A1Z3HM62', 'A0A1Z4GHB6', 'A0A1Z4ICU9', 'A0A1Z4KX29', 'A0A1Z4LV63', 'A0A1Z4N4V9', 'A0A1Z4NDI0', 'A0A1Z4QFH8', 'A0A1Z4QXY7', 'A0A1Z4RQL1', 'A0A1Z5HAP9', 'A0A1Z7WS55', 'A0A1Z8NNZ0', 'A0A1Z8UIG6', 'A0A1Z9AGM8', 'A0A1Z9LHP9', 'A0A218PXA8', 'A0A218QL89', 'A0A231VN06', 'A0A235HP39', 'A0A235IAR1', 'A0A235J5M2', 'A0A239REU0', 'A0A250L024', 'A0A251WC ...
# 1195

# %%
#Parse the original signalP output , print the prediction types
df_signalp = pd.read_csv('signal_p/prediction_results.txt', sep="\t", skiprows=1)
#Parse the signalP output from  from qcov80 run  , print the prediction types
df_signalp_newqcov80 = pd.read_csv('signal_p_newqcov80/prediction_results.txt', sep="\t", skiprows=1)

df_signalp = pd.concat([df_signalp, df_signalp_newqcov80], ignore_index=True)



signal_p_positive = []
signal_p_positive_dict = {}
for i, r in df_signalp.iterrows():
    if r['Prediction'] != "OTHER":
        ACC = r['# ID'].split("|")[1]
        print(ACC, r['Prediction'])
        signal_p_positive.append(ACC)
        signal_p_positive_dict[ACC] = r['Prediction']


print(len(signal_p_positive))
# Out:
# A0A1M5XW76 TAT
# A0A1M6NB40 TAT
# A0A317CF94 SP
# A0A496UGQ0 SP
# A0A6N6N5J6 SP
# A0A6V8LVP4 SP
# A0A7C1HUT6 SP
# E6VTG4 SP
# 8

# %%
# Define set labels and sets
labels = ['DeepLocPro', 'UniProt', 'DeepTMHMM', 'SignalP']
sets = [
    set(deeplocpro_secreted),
    set(uniprot_secreted),
    set(deeptmhmm_outside),
    set(signal_p_positive)
]

# Get union of all accessions
all_accs = set.union(*sets)

# Build memberships using label names
memberships = []
for acc in all_accs:
    membership = [labels[i] for i, s in enumerate(sets) if acc in s]
    memberships.append(membership)

# Create the data for the UpSet plot
data = from_memberships(memberships)

# Plot
upset = UpSet(data, subset_size='count', show_counts=True)
upset.plot()

plt.suptitle("Overlap of Secretion Prediction Methods", fontsize=14)
plt.savefig("Secretion_Prediction_UpSet.svg")
plt.show()
# Out:
# /home/djl294/anaconda3/lib/python3.10/site-packages/upsetplot/data.py:303: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# /home/djl294/anaconda3/lib/python3.10/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# /home/djl294/anaconda3/lib/python3.10/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# /home/djl294/anaconda3/lib/python3.10/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# /home/djl294/anaconda3/lib/python3.10/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
### Combine all extracellular/secreted annotations, create a subset of the taxanomy df above for extracellular/secreted proteins

comnbined_secreted_accs = list(set(deeplocpro_secreted + uniprot_secreted + deeptmhmm_outside + signal_p_positive))
comnbined_secreted_accs

combined_taxa_df_secreted = pd.DataFrame()  

for i, r in combined_taxa_df.iterrows():
    if r['ACC'] in comnbined_secreted_accs:
        combined_taxa_df_secreted = pd.concat([combined_taxa_df_secreted, r.to_frame().T], ignore_index=True)
        
combined_taxa_df_secreted
# Out:
#         Query    Taxid                                          Tax name  \
# 0     1341156  1341156                            Ruminococcus albus SY3
# 1       95486    95486                          Burkholderia cenocepacia
# 2      585425   585425                        Synechococcus sp. KORDI-52
# 3        1680     1680                      Bifidobacterium adolescentis
# 4       29343    29343                           [Clostridium] cellulosi
# ...       ...      ...                                               ...
# 1236  1400863  1400863  Candidatus Competibacter denitrificans Run_A_D11
# 1237  1408889  1408889                 Clostridium tyrobutyricum DIVETGP
# 1238  1341157  1341157                    Ruminococcus flavefaciens 007c
# 1239  1421016  1421016          Thermoanaerobacterium aotearoense SCUT27
# 1240  1249627  1249627                              Imhoffiella purpurea
#
#                               Authority     Rank Basionym Basionym authority  \
# 0                                   NaN   STRAIN      NaN                NaN
# 1                  Vandamme et al. 2003  SPECIES      NaN                NaN
# 2                                   NaN  SPECIES      NaN                NaN
# 3     Reuter 1963 (Approved Lists 1980)  SPECIES      NaN                NaN
# 4                   Yanling et al. 1991  SPECIES      NaN                NaN
# ...                                 ...      ...      ...                ...
# 1236                                NaN   STRAIN      NaN                NaN
# 1237                                NaN   STRAIN      NaN                NaN
# 1238                                NaN   STRAIN      NaN                NaN
# 1239                                NaN   STRAIN      NaN                NaN
# 1240                  Nupur et al. 2017  SPECIES      NaN                NaN
#
#      Curator common name Has type material                       Group name  \
# 0                    NaN                no                       firmicutes
# 1                    NaN               yes                 b-proteobacteria
# 2                    NaN                no                    cyanobacteria
# 3                    NaN               yes  high G+C Gram-positive bacteria
# 4                    NaN               yes                       firmicutes
# ...                  ...               ...                              ...
# 1236                 NaN                no                 g-proteobacteria
# 1237                 NaN                no                       firmicutes
# 1238                 NaN                no                       firmicutes
# 1239                 NaN                no                       firmicutes
# 1240                 NaN               yes                 g-proteobacteria
#
#       ...              Order name Order taxid                    Family name  \
# 0     ...           Eubacteriales    186802.0               Oscillospiraceae
# 1     ...         Burkholderiales     80840.0               Burkholderiaceae
# 2     ...         Synechococcales   1890424.0               Synechococcaceae
# 3     ...       Bifidobacteriales     85004.0             Bifidobacteriaceae
# 4     ...           Eubacteriales    186802.0               Oscillospiraceae
# ...   ...                     ...         ...                            ...
# 1236  ...                     NaN         NaN  Candidatus Competibacteraceae
# 1237  ...           Eubacteriales    186802.0                 Clostridiaceae
# 1238  ...           Eubacteriales    186802.0               Oscillospiraceae
# 1239  ...  Thermoanaerobacterales     68295.0        Thermoanaerobacteraceae
# 1240  ...            Chromatiales    135613.0                  Chromatiaceae
#
#      Family taxid                Genus name Genus taxid  \
# 0        216572.0              Ruminococcus      1263.0
# 1        119060.0              Burkholderia     32008.0
# 2       1890426.0             Synechococcus      1129.0
# 3         31953.0           Bifidobacterium      1678.0
# 4        216572.0                       NaN         NaN
# ...           ...                       ...         ...
# 1236    1400857.0  Candidatus Competibacter    221279.0
# 1237      31979.0               Clostridium      1485.0
# 1238     216572.0              Ruminococcus      1263.0
# 1239     186814.0     Thermoanaerobacterium     28895.0
# 1240       1046.0               Imhoffiella   2018671.0
#
#                                 Species name Species taxid  \
# 0                         Ruminococcus albus          1264
# 1                   Burkholderia cenocepacia         95486
# 2                 Synechococcus sp. KORDI-52        585425
# 3               Bifidobacterium adolescentis          1680
# 4                    [Clostridium] cellulosi         29343
# ...                                      ...           ...
# 1236  Candidatus Competibacter denitrificans       1400862
# 1237               Clostridium tyrobutyricum          1519
# 1238               Ruminococcus flavefaciens          1265
# 1239       Thermoanaerobacterium aotearoense         47490
# 1240                    Imhoffiella purpurea       1249627
#
#      Scientific name is formal         ACC
# 0                        False  A0A011VUM0
# 1                         True  A0A071MCE1
# 2                        False  A0A076HQJ4
# 3                         True  A0A076JKV6
# 4                         True  A0A078KTQ4
# ...                        ...         ...
# 1236                     False      W6M9Z9
# 1237                     False      W6N3Z2
# 1238                     False      W7UI54
# 1239                     False      W9E8S8
# 1240                      True      W9V7B8
#
# [1241 rows x 28 columns]

# %%
#make taxa specific sub-dataframes for extracellular/secreted proteins
phylum_plot_df_secreted = get_taxa_ratios(combined_taxa_df_secreted, "Phylum name")
  
print(phylum_plot_df_secreted)
    
    
    
family_plot_df_secreted = get_taxa_ratios(combined_taxa_df_secreted, "Family name")
  
print(family_plot_df_secreted)
    
genus_plot_df_secreted = get_taxa_ratios(combined_taxa_df_secreted, "Genus name")
  
print(genus_plot_df_secreted)

species_plot_df_secreted = get_taxa_ratios(combined_taxa_df_secreted, "Species name")
  
print(species_plot_df_secreted)
# Out:
#           Level                          Label       Perc
# 0   Phylum name                      Bacillota  20.628525
# 1   Phylum name                 Pseudomonadota  23.690572
# 2   Phylum name                Cyanobacteriota  29.411765
# 3   Phylum name                 Actinomycetota   9.105560
# 4   Phylum name  Candidatus Collieribacteriota   0.483481
# 5   Phylum name        Thermodesulfobacteriota   3.626108
# 6   Phylum name              Verrucomicrobiota   4.593070
# 7   Phylum name                   Bacteroidota   1.772764
# 8   Phylum name                            NaN   1.369863
# 9   Phylum name                 Lentisphaerota   1.289283
# 10  Phylum name                  Spirochaetota   1.289283
# 11  Phylum name     Candidatus Melainabacteria   0.161160
# 12  Phylum name                Planctomycetota   0.161160
# 13  Phylum name                    Myxococcota   0.805802
# 14  Phylum name                   Thermotogota   0.564061
# 15  Phylum name     Candidatus Zixiibacteriota   0.080580
# 16  Phylum name   Candidatus Fermentibacterota   0.161160
# 17  Phylum name                    Chlamydiota   0.080580
# 18  Phylum name               Kiritimatiellota   0.322321
# 19  Phylum name                Acidobacteriota   0.080580
# 20  Phylum name                 Fibrobacterota   0.241741
# 21  Phylum name    Candidatus Rifleibacteriota   0.080580
#            Level               Label      Perc
# 0    Family name    Oscillospiraceae  4.995971
# 1    Family name    Burkholderiaceae  1.369863
# 2    Family name    Synechococcaceae  3.223207
# 3    Family name  Bifidobacteriaceae  8.541499
# 4    Family name     Lachnospiraceae  6.526994
# ..           ...                 ...       ...
# 114  Family name   Pseudanabaenaceae  0.080580
# 115  Family name   Chamaesiphonaceae  0.080580
# 116  Family name       Xenococcaceae  0.080580
# 117  Family name    Acetobacteraceae  0.080580
# 118  Family name   Thalassospiraceae  0.080580
#
# [119 rows x 3 columns]
#           Level                     Label       Perc
# 0    Genus name              Ruminococcus   2.256245
# 1    Genus name              Burkholderia   1.369863
# 2    Genus name             Synechococcus   3.062047
# 3    Genus name           Bifidobacterium   6.124093
# 4    Genus name                       NaN  25.302176
# ..          ...                       ...        ...
# 240  Genus name               Acetobacter   0.080580
# 241  Genus name       Alkalidesulfovibrio   0.080580
# 242  Genus name              Magnetospira   0.080580
# 243  Genus name  Candidatus Competibacter   0.080580
# 244  Genus name               Imhoffiella   0.080580
#
# [245 rows x 3 columns]
#             Level                                   Label      Perc
# 0    Species name                      Ruminococcus albus  0.402901
# 1    Species name                Burkholderia cenocepacia  0.161160
# 2    Species name              Synechococcus sp. KORDI-52  0.080580
# 3    Species name            Bifidobacterium adolescentis  0.080580
# 4    Species name                 [Clostridium] cellulosi  0.080580
# ..            ...                                     ...       ...
# 859  Species name                   Magnetospira sp. QH-2  0.080580
# 860  Species name  Candidatus Competibacter denitrificans  0.080580
# 861  Species name               Clostridium tyrobutyricum  0.080580
# 862  Species name       Thermoanaerobacterium aotearoense  0.080580
# 863  Species name                    Imhoffiella purpurea  0.080580
#
# [864 rows x 3 columns]
# /tmp/ipykernel_2878486/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /tmp/ipykernel_2878486/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /tmp/ipykernel_2878486/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /tmp/ipykernel_2878486/330031078.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
plot_taxa_distribution(species_plot_df_secreted, top_n=5, title_prefix='Species_Secreted')
# Out:
#           Level                          Label       Perc
# 0  Species name  Gammaproteobacteria bacterium   2.739726
# 1  Species name         Microcystis aeruginosa   2.417405
# 2  Species name        Prochlorococcus marinus   1.772764
# 3  Species name             Opitutia bacterium   1.128122
# 4  Species name          Gardnerella vaginalis   0.886382
# 5  Species name                          Other  91.055600
